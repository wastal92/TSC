# %%
# %matplotlib inline

import numpy as np
import matplotlib
from matplotlib import pyplot
import tensorflow as tf

# %%
import pickle

def load_pickled_data(file, columns):
    """
    Loads pickled training and test data.
    
    Parameters
    ----------
    file    : 
              Name of the pickle file.
    columns : list of strings
              List of columns in pickled data we're interested in.

    Returns
    -------
    A tuple of datasets for given columns.    
    """

    with open(file, mode='rb') as f:
        dataset = pickle.load(f)
    return tuple(map(lambda c: dataset[c], columns))

# %%
from pandas.io.parsers import read_csv

signnames = read_csv("signnames.csv").values[:, 1]
train_dataset_file = "data/train.p"
test_dataset_file = "data/test.p"
#train_balanced_dataset_file = "traffic-signs-data/train_balanced.p"

X_train, y_train = load_pickled_data(train_dataset_file, ['features', 'labels'])
X_test, y_test = load_pickled_data(test_dataset_file, ['features', 'labels'])

n_train = y_train.shape[0]
n_test = y_test.shape[0]
image_shape = X_train[0].shape
image_size = image_shape[0]
sign_classes, class_indices, class_counts = np.unique(y_train, return_index = True, return_counts = True)
n_classes = class_counts.shape[0]

print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
print(y_train.shape)
# Out:
# Number of training examples = 39209
# Number of testing examples = 12630
# Image data shape = (32, 32, 3)
# Number of classes = 43
# (39209,)

# %%
import sys
import time

def get_time_hhmmss(start = None):
    """
    Calculates time since `start` and formats as a string.
    """
    if start is None:
        return time.strftime("%Y/%m/%d %H:%M:%S")
    end = time.time()
    m, s = divmod(end - start, 60)
    h, m = divmod(m, 60)
    time_str = "%02d:%02d:%02d" % (h, m, s)
    return time_str   

# Print iterations progress
def print_progress(iteration, total):
    """
    Call in a loop to create terminal progress bar
    
    Parameters
    ----------
        
    iteration : 
                Current iteration (Int)
    total     : 
                Total iterations (Int)
    """
    str_format = "{0:.0f}"
    percents = str_format.format(100 * (iteration / float(total)))
    filled_length = int(round(100 * iteration / float(total)))
    bar = '█' * filled_length + '-' * (100 - filled_length)

    sys.stdout.write('\r |%s| %s%%' % (bar, percents)),

    if iteration == total:
        sys.stdout.write('\n')
    sys.stdout.flush()

# %%
from sklearn.utils import shuffle
from skimage import exposure
import warnings 

num_classes = 43

def preprocess_dataset(X, y = None, shuffle=True):
    """
    Performs feature scaling, one-hot encoding of labels and shuffles the data if labels are provided.
    Assumes original dataset is sorted by labels.
    
    Parameters
    ----------
    X                : ndarray
                       Dataset array containing feature examples.
    y                : ndarray, optional, defaults to `None`
                       Dataset labels in index form.
    Returns
    -------
    A tuple of X and y.    
    """
    print("Preprocessing dataset with {} examples:".format(X.shape[0]))

    #Convert to grayscale, e.g. single channel Y
    X = 0.299 * X[:, :, :, 0] + 0.587 * X[:, :, :, 1] + 0.114 * X[:, :, :, 2]
    #Scale features to be in [0, 1]
    X = (X / 255.).astype(np.float32)
        
    for i in range(X.shape[0]):
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            X[i] = exposure.equalize_adapthist(X[i])
        print_progress(i + 1, X.shape[0])
        
    if y is not None:  
        # Convert to one-hot encoding. Convert back with `y = y.nonzero()[1]`
        y = np.eye(num_classes)[y]
        if shuffle:
            X, y = shuffle(X, y)


    # Add a single grayscale channel
    X = X.reshape(X.shape + (1,)) 
    return X, y

def class_name(one_hot):
    return signnames[one_hot.nonzero()[0][0]]

def load_and_process_data(pickled_data_file):
    """
    Loads pickled data and preprocesses images and labels by scaling features, 
    shuffling the data and applying one-hot encoding to labels.
    
    Parameters
    ----------
    pickled_data_file  : string
                         Pickled data file name.
    Returns
    -------
    A tuple of X and y containing preloaded and preprocessed features and labels respectively.    
    """
    X, y = load_pickled_data(pickled_data_file, columns = ['features', 'labels'])
    X, y = preprocess_dataset(X, y)
    return (X, y)

# %%
from nolearn.lasagne import BatchIterator
from skimage.transform import rotate
from skimage.transform import warp
from skimage.transform import ProjectiveTransform
import random

class AugmentedSignsBatchIterator(BatchIterator):
    """
    Iterates over dataset in batches. 
    Allows images augmentation by randomly rotating, applying projection, 
    adjusting gamma, blurring, adding noize and flipping horizontally.
    """
        
    def __init__(self, batch_size, shuffle = False, seed = 42, p = 0.5, intensity = 0.5):
        """
        Initialises an instance with usual iterating settings, as well as data augmentation coverage
        and augmentation intensity.
        
        Parameters
        ----------
        batch_size:
                    Size of the iteration batch.
        shuffle   :
                    Flag indicating if we need to shuffle the data.
        seed      :
                    Random seed.
        p         :
                    Probability of augmenting a single example, should be in a range of [0, 1] .
                    Defines data augmentation coverage.
        intensity :
                    Augmentation intensity, should be in a [0, 1] range.
        
        Returns
        -------
        New batch iterator instance.
        """
        super(AugmentedSignsBatchIterator, self).__init__(batch_size, shuffle, seed)
        self.p = p
        self.intensity = intensity

    def transform(self, Xb, yb):
        """
        Applies a pipeline of randomised transformations for data augmentation.
        """
        Xb, yb = super(AugmentedSignsBatchIterator, self).transform(
            Xb if yb is None else Xb.copy(), 
            yb
        )
        
        if yb is not None:
            batch_size = Xb.shape[0]
            image_size = Xb.shape[1]
            
            Xb = self.rotate(Xb, batch_size)
            Xb = self.apply_projection_transform(Xb, batch_size, image_size)

        return Xb, yb
        
    def rotate(self, Xb, batch_size):
        """
        Applies random rotation in a defined degrees range to a random subset of images. 
        Range itself is subject to scaling depending on augmentation intensity.
        """
        for i in np.random.choice(batch_size, int(batch_size * self.p), replace = False):
            delta = 30. * self.intensity # scale by self.intensity
            Xb[i] = rotate(Xb[i], random.uniform(-delta, delta), mode = 'edge')
        return Xb   
    
    def apply_projection_transform(self, Xb, batch_size, image_size):
        """
        Applies projection transform to a random subset of images. Projection margins are randomised in a range
        depending on the size of the image. Range itself is subject to scaling depending on augmentation intensity.
        """
        d = image_size * 0.3 * self.intensity
        for i in np.random.choice(batch_size, int(batch_size * self.p), replace = False):        
            tl_top = random.uniform(-d, d)     # Top left corner, top margin
            tl_left = random.uniform(-d, d)    # Top left corner, left margin
            bl_bottom = random.uniform(-d, d)  # Bottom left corner, bottom margin
            bl_left = random.uniform(-d, d)    # Bottom left corner, left margin
            tr_top = random.uniform(-d, d)     # Top right corner, top margin
            tr_right = random.uniform(-d, d)   # Top right corner, right margin
            br_bottom = random.uniform(-d, d)  # Bottom right corner, bottom margin
            br_right = random.uniform(-d, d)   # Bottom right corner, right margin

            transform = ProjectiveTransform()
            transform.estimate(np.array((
                    (tl_left, tl_top),
                    (bl_left, image_size - bl_bottom),
                    (image_size - br_right, image_size - br_bottom),
                    (image_size - tr_right, tr_top)
                )), np.array((
                    (0, 0),
                    (0, image_size),
                    (image_size, image_size),
                    (image_size, 0)
                )))
            Xb[i] = warp(Xb[i], transform, output_shape=(image_size, image_size), order = 1, mode = 'edge')

        return Xb
# Out:
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# /home/wastaljoey/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
X_train, y_train = load_pickled_data("data/train.p", columns = ['features', 'labels'])
X_train = X_train / 255.

batch_iterator = AugmentedSignsBatchIterator(batch_size = 5, p = 1.0, intensity = 0.75)
for x_batch, y_batch in batch_iterator(X_train, y_train):
    for i in range(5): 
        # plot two images:
        fig = pyplot.figure(figsize=(3, 1))
        axis = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
        axis.imshow(X_train[i])
        axis = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
        axis.imshow(x_batch[i])
        pyplot.show()
    break

# %%
def flip_extend(X, y):
    """
    Extends existing images dataset by flipping images of some classes. As some images would still belong
    to same class after flipping we extend such classes with flipped images. Images of other would toggle 
    between two classes when flipped, so for those we extend existing datasets as well.
    
    Parameters
    ----------
    X       : ndarray
              Dataset array containing feature examples.
    y       : ndarray, optional, defaults to `None`
              Dataset labels in index form.

    Returns
    -------
    A tuple of X and y.    
    """
    # Classes of signs that, when flipped horizontally, should still be classified as the same class
    self_flippable_horizontally = np.array([11, 12, 13, 15, 17, 18, 22, 26, 30, 35])
    # Classes of signs that, when flipped vertically, should still be classified as the same class
    self_flippable_vertically = np.array([1, 5, 12, 15, 17])
    # Classes of signs that, when flipped horizontally and then vertically, should still be classified as the same class
    self_flippable_both = np.array([32, 40])
    # Classes of signs that, when flipped horizontally, would still be meaningful, but should be classified as some other class
    cross_flippable = np.array([
        [19, 20], 
        [33, 34], 
        [36, 37], 
        [38, 39],
        [20, 19], 
        [34, 33], 
        [37, 36], 
        [39, 38],   
    ])
    num_classes = 43
    
    X_extended = np.empty([0, X.shape[1], X.shape[2], X.shape[3]], dtype = X.dtype)
    y_extended = np.empty([0], dtype = y.dtype)
    
    for c in range(num_classes):
        # First copy existing data for this class
        X_extended = np.append(X_extended, X[y == c], axis = 0)
        # If we can flip images of this class horizontally and they would still belong to said class...
        if c in self_flippable_horizontally:
            # ...Copy their flipped versions into extended array.
            X_extended = np.append(X_extended, X[y == c][:, :, ::-1, :], axis = 0)
        # If we can flip images of this class horizontally and they would belong to other class...
        if c in cross_flippable[:, 0]:
            # ...Copy flipped images of that other class to the extended array.
            flip_class = cross_flippable[cross_flippable[:, 0] == c][0][1]
            X_extended = np.append(X_extended, X[y == flip_class][:, :, ::-1, :], axis = 0)
        # Fill labels for added images set to current class.
        y_extended = np.append(y_extended, np.full((X_extended.shape[0] - y_extended.shape[0]), c, dtype = int))
        
        # If we can flip images of this class vertically and they would still belong to said class...
        if c in self_flippable_vertically:
            # ...Copy their flipped versions into extended array.
            X_extended = np.append(X_extended, X_extended[y_extended == c][:, ::-1, :, :], axis = 0)
        # Fill labels for added images set to current class.
        y_extended = np.append(y_extended, np.full((X_extended.shape[0] - y_extended.shape[0]), c, dtype = int))
        
        # If we can flip images of this class horizontally AND vertically and they would still belong to said class...
        if c in self_flippable_both:
            # ...Copy their flipped versions into extended array.
            X_extended = np.append(X_extended, X_extended[y_extended == c][:, ::-1, ::-1, :], axis = 0)
        # Fill labels for added images set to current class.
        y_extended = np.append(y_extended, np.full((X_extended.shape[0] - y_extended.shape[0]), c, dtype = int))
    
    return (X_extended, y_extended)

def extend_balancing_classes(X, y, aug_intensity = 0.5, counts = None):
    """
    Extends dataset by duplicating existing images while applying data augmentation pipeline.
    Number of generated examples for each class may be provided in `counts`.
    
    Parameters
    ----------
    X             : ndarray
                    Dataset array containing feature examples.
    y             : ndarray, optional, defaults to `None`
                    Dataset labels in index form.
    aug_intensity :
                    Intensity of augmentation, must be in [0, 1] range.
    counts        :
                    Number of elements for each class.
                    
    Returns
    -------
    A tuple of X and y.    
    """
    num_classes = 43

    _, class_counts = np.unique(y, return_counts = True)
    max_c = max(class_counts)
    total = max_c * num_classes if counts is None else np.sum(counts)
    
    X_extended = np.empty([0, X.shape[1], X.shape[2], X.shape[3]], dtype = np.float32)
    y_extended = np.empty([0], dtype = y.dtype)
    print("Extending dataset using augmented data (intensity = {}):".format(aug_intensity))
    
    for c, c_count in zip(range(num_classes), class_counts):
        # How many examples should there be eventually for this class:
        max_c = max_c if counts is None else counts[c]
        # First copy existing data for this class
        X_source = (X[y == c] / 255.).astype(np.float32)
        y_source = y[y == c]
        X_extended = np.append(X_extended, X_source, axis = 0)
        for i in range((max_c // c_count) - 1):
            batch_iterator = AugmentedSignsBatchIterator(batch_size = X_source.shape[0], p = 1.0, intensity = aug_intensity)
            for x_batch, _ in batch_iterator(X_source, y_source):
                X_extended = np.append(X_extended, x_batch, axis = 0)
                print_progress(X_extended.shape[0], total)
        batch_iterator = AugmentedSignsBatchIterator(batch_size = max_c % c_count, p = 1.0, intensity = aug_intensity)
        for x_batch, _ in batch_iterator(X_source, y_source):
            X_extended = np.append(X_extended, x_batch, axis = 0)
            print_progress(X_extended.shape[0], total)
            break
        # Fill labels for added images set to current class.
        added = X_extended.shape[0] - y_extended.shape[0]
        y_extended = np.append(y_extended, np.full((added), c, dtype = int))
        
    return ((X_extended * 255.).astype(np.uint8), y_extended)

# %%
from collections import namedtuple

Parameters = namedtuple('Parameters', [
        # Data parameters
        'num_classes', 'image_size', 
        # Training parameters
        'batch_size', 'max_epochs', 'log_epoch', 'print_epoch',
        # Optimisations
        'learning_rate_decay', 'learning_rate',
        'l2_reg_enabled', 'l2_lambda', 
        'early_stopping_enabled', 'early_stopping_patience', 
        'resume_training', 
        # Layers architecture
        'conv1_k', 'conv1_d', 'conv1_p', 
        'conv2_k', 'conv2_d', 'conv2_p', 
        'conv3_k', 'conv3_d', 'conv3_p', 
        'conv4_k', 'conv4_d', 'conv4_p',         
        'fc4_size', 'fc4_p',
        #Adversarial Training
        'adv_training',
        'perturbed_ratio'
    
    ])

# %%
import os

class Paths(object):
    """
    Provides easy access to common paths we use for persisting 
    the data associated with model training.
    """
    
    def __init__(self, params):
        """
        Initialises a new `Paths` instance and creates corresponding folders if needed.

        Parameters
        ----------
        params  : Parameters
                  Structure (`namedtuple`) containing model parameters.
        """
        self.model_name = self.get_model_name(params)
        self.var_scope = self.get_variables_scope(params)
        self.root_path = os.getcwd() + "/models/" + self.model_name + "/"
        self.model_path = self.get_model_path()
        self.train_history_path = self.get_train_history_path()
        self.learning_curves_path = self.get_learning_curves_path()
        os.makedirs(self.root_path, exist_ok = True)

    def get_model_name(self, params):
        """
        Generates a model name with some of the crucial model parameters encoded into the name.

        Parameters
        ----------
        params  : Parameters
                  Structure (`namedtuple`) containing model parameters.
                  
        Returns
        -------
        Model name.
        """
        # We will encode model settings in its name: architecture, optimisations applied, etc.
        model_name = "4layers_k{}d{}p{}_k{}d{}p{}_k{}d{}p{}_fc{}p{}".format(
            params.conv1_k, params.conv1_d, params.conv1_p, 
            params.conv2_k, params.conv2_d, params.conv2_p, 
            params.conv3_k, params.conv3_d, params.conv3_p, 
            params.fc4_size, params.fc4_p
        )
        model_name += "_lrdec" if params.learning_rate_decay else "_no-lrdec"
        model_name += "_l2" if params.l2_reg_enabled else "_no-l2"
        if params.adv_training:
            model_name += "_advtrain" 
        if params.perturbed_ratio:
            model_name += "_{}%_perturbed".format(params.perturbed_ratio)
        
        return model_name

    def get_variables_scope(self, params):
        """
        Generates a model variable scope with some of the crucial model parameters encoded.

        Parameters
        ----------
        params  : Parameters
                  Structure (`namedtuple`) containing model parameters.
                  
        Returns
        -------
        Variables scope name.
        """
        # We will encode model settings in its name: architecture, optimisations applied, etc.
        var_scope = "k{}d{}_k{}d{}_k{}d{}_fc{}_fc0".format(
            params.conv1_k, params.conv1_d,
            params.conv2_k, params.conv2_d,
            params.conv3_k, params.conv3_d, 
            params.fc4_size
        )
        return var_scope

    def get_model_path(self):
        """
        Generates path to the model file.
   
        Returns
        -------
        Model file path.
        """
        return self.root_path + "model.ckpt"

    def get_train_history_path(self):
        """
        Generates path to the train history file.
   
        Returns
        -------
        Train history file path.
        """
        return self.root_path + "train_history"
    
    def get_learning_curves_path(self):
        """
        Generates path to the learning curves graph file.
   
        Returns
        -------
        Learning curves file path.
        """
        return self.root_path + "learning_curves.png"

# %%
class EarlyStopping(object):
    """
    Provides early stopping functionality. Keeps track of model accuracy, 
    and if it doesn't improve over time restores last best performing 
    parameters.
    """
    
    def __init__(self, saver, session, patience = 100, minimize = True):
        """
        Initialises a `EarlyStopping` isntance.

        Parameters
        ----------
        saver     : 
                    TensorFlow Saver object to be used for saving and restoring model.
        session   : 
                    TensorFlow Session object containing graph where model is restored.
        patience  : 
                    Early stopping patience. This is the number of epochs we wait for 
                    accuracy to start improving again before stopping and restoring 
                    previous best performing parameters.
                  
        Returns
        -------
        New instance.
        """
        self.minimize = minimize
        self.patience = patience
        self.saver = saver
        self.session = session
        self.best_monitored_value = np.inf if minimize else 0.
        self.best_monitored_epoch = 0
        self.restore_path = None

    def __call__(self, value, epoch):
        """
        Checks if we need to stop and restores the last well performing values if we do.

        Parameters
        ----------
        value     : 
                    Last epoch monitored value.
        epoch     : 
                    Last epoch number.
                  
        Returns
        -------
        `True` if we waited enough and it's time to stop and we restored the 
        best performing weights, or `False` otherwise.
        """
        if (self.minimize and value < self.best_monitored_value) or (not self.minimize and value > self.best_monitored_value):
            self.best_monitored_value = value
            self.best_monitored_epoch = epoch
            self.restore_path = self.saver.save(self.session, os.getcwd() + "/early_stopping_checkpoint")
        elif self.best_monitored_epoch + self.patience < epoch:
            if self.restore_path != None:
                self.saver.restore(self.session, self.restore_path)
            else:
                print("ERROR: Failed to restore session")
            return True
        
        return False

# %%
from cloudlog import CloudLog

class ModelCloudLog(CloudLog):
        
    def log_parameters(self, params, train_size, valid_size, test_size):
        """
        Logs model parameters to console and appends the same text representation to the log file.

        Parameters
        ----------
        params    : Parameters
                    Structure (`namedtuple`) containing model parameters.
        train_size: int
                    Size of the training dataset.
        valid_size: int
                    Size of the training dataset.
        test_size : int
                    Size of the training dataset.
        """
        if params.resume_training:
            self("=============================================")
            self("============= RESUMING TRAINING =============")
            self("=============================================")

        self("=================== DATA ====================")
        self("            Training set: {} examples".format(train_size))
        self("          Validation set: {} examples".format(valid_size))
        self("             Testing set: {} examples".format(test_size))
        self("              Batch size: {}".format(params.batch_size))   

        self("=================== MODEL ===================")
        self("--------------- ARCHITECTURE ----------------")  
        self(" %-*s %-*s %-*s %-*s" % (10, "", 10, "Type", 8, "Size", 15, "Dropout (keep p)"))    
        self(" %-*s %-*s %-*s %-*s" % (10, "Layer 1", 10, "{}x{} Conv".format(params.conv1_k, params.conv1_k), 8, str(params.conv1_d), 15, str(params.conv1_p)))    
        self(" %-*s %-*s %-*s %-*s" % (10, "Layer 2", 10, "{}x{} Conv".format(params.conv2_k, params.conv2_k), 8, str(params.conv2_d), 15, str(params.conv2_p)))    
        self(" %-*s %-*s %-*s %-*s" % (10, "Layer 3", 10, "{}x{} Conv".format(params.conv3_k, params.conv3_k), 8, str(params.conv3_d), 15, str(params.conv3_p)))    
        self(" %-*s %-*s %-*s %-*s" % (10, "Layer 4", 10, "FC", 8, str(params.fc4_size), 15, str(params.fc4_p)))    
        self("---------------- PARAMETERS -----------------")
        self("     Learning rate decay: " + ("Enabled" if params.learning_rate_decay else "Disabled (rate = {})".format(params.learning_rate)))
        self("       L2 Regularization: " + ("Enabled (lambda = {})".format(params.l2_lambda) if params.l2_reg_enabled else "Disabled"))
        self("          Early stopping: " + ("Enabled (patience = {})".format(params.early_stopping_patience) if params.early_stopping_enabled else "Disabled"))
        self(" Keep training old model: " + ("Enabled" if params.resume_training else "Disabled"))

# %%
def fully_connected(input, size):
    """
    Performs a single fully connected layer pass, e.g. returns `input * weights + bias`.
    """
    weights = tf.get_variable( 'weights', 
        shape = [input.get_shape()[1], size],
        initializer = tf.contrib.layers.xavier_initializer()
      )
    biases = tf.get_variable( 'biases',
        shape = [size],
        initializer = tf.constant_initializer(0.0)
      )
    return tf.matmul(input, weights) + biases

def fully_connected_relu(input, size):
    return tf.nn.relu(fully_connected(input, size))

def conv_relu(input, kernel_size, depth):
    """
    Performs a single convolution layer pass.
    """
    weights = tf.get_variable( 'weights', 
        shape = [kernel_size, kernel_size, input.get_shape()[3], depth],
        initializer = tf.contrib.layers.xavier_initializer()
      )
    biases = tf.get_variable( 'biases',
        shape = [depth],
        initializer = tf.constant_initializer(0.0)
      )
    conv = tf.nn.conv2d(input, weights,
        strides = [1, 1, 1, 1], padding = 'SAME')
    return tf.nn.relu(conv + biases)

def pool(input, size):
    """
    Performs a max pooling layer pass.
    """
    return tf.nn.max_pool(
        input, 
        ksize = [1, size, size, 1], 
        strides = [1, size, size, 1], 
        padding = 'SAME'
    )

def model_pass(input, params, is_training):
    """
    Performs a full model pass.
    
    Parameters
    ----------
    input         : Tensor
                    NumPy array containing a batch of examples.
    params        : Parameters
                    Structure (`namedtuple`) containing model parameters.
    is_training   : Tensor of type tf.bool
                    Flag indicating if we are training or not (e.g. whether to use dropout).
                    
    Returns
    -------
    Tensor with predicted logits.
    """
    # Convolutions

    with tf.variable_scope('conv1'):
        conv1 = conv_relu(input, kernel_size = params.conv1_k, depth = params.conv1_d) 
    with tf.variable_scope('pool1'): 
        pool1 = pool(conv1, size = 2)
        pool1 = tf.cond(is_training, lambda: tf.nn.dropout(pool1, keep_prob = params.conv1_p), lambda: pool1)
    with tf.variable_scope('conv2'):
        conv2 = conv_relu(pool1, kernel_size = params.conv2_k, depth = params.conv2_d)
    with tf.variable_scope('pool2'):
        pool2 = pool(conv2, size = 2)
        pool2 = tf.cond(is_training, lambda: tf.nn.dropout(pool2, keep_prob = params.conv2_p), lambda: pool2)
    with tf.variable_scope('conv3'):
        conv3 = conv_relu(pool2, kernel_size = params.conv3_k, depth = params.conv3_d)
    with tf.variable_scope('pool3'):
        pool3 = pool(conv3, size = 2)
        pool3 = tf.cond(is_training, lambda: tf.nn.dropout(pool3, keep_prob = params.conv3_p), lambda: pool3)
    with tf.variable_scope('conv4'):
        conv4=conv_relu(pool3, kernel_size = params.conv4_k, depth = params.conv4_d)
    with tf.variable_scope('pool4'):
        pool4 = pool(conv4, size = 2)
        pool4 = tf.cond(is_training, lambda: tf.nn.dropout(pool4, keep_prob = params.conv4_p), lambda: pool4)
    
    # Fully connected
    
    # 1st stage output
    pool1 = pool(pool1, size = 8)
    shape = pool1.get_shape().as_list()
    pool1 = tf.reshape(pool1, [-1, shape[1] * shape[2] * shape[3]])
    
    # 2nd stage output
    pool2 = pool(pool2, size = 4)
    shape = pool2.get_shape().as_list()
    pool2 = tf.reshape(pool2, [-1, shape[1] * shape[2] * shape[3]])    
    
    # 3rd stage output
    pool3 = pool(pool3, size = 2)
    shape = pool3.get_shape().as_list()
    pool3 = tf.reshape(pool3, [-1, shape[1] * shape[2] * shape[3]])
    
    # 4th stage output
    shape = pool4.get_shape().as_list()
    pool4 = tf.reshape(pool4, [-1, shape[1] * shape[2] * shape[3]])    
    
    flattened = tf.concat([pool1, pool2, pool3,pool4],1)
    
    with tf.variable_scope('fc4'):
        fc4 = fully_connected_relu(flattened, size = params.fc4_size)
        fc4 = tf.cond(is_training, lambda: tf.nn.dropout(fc4, keep_prob = params.fc4_p), lambda: fc4)
    with tf.variable_scope('out'):
        logits = fully_connected(fc4, size = params.num_classes)
    return logits

# %%
def plot_curve(axis, params, train_column, valid_column, linewidth = 2, train_linestyle = "b-", valid_linestyle = "g-"):
    """
    Plots a pair of validation and training curves on a single plot.
    """
    model_history = np.load(Paths(params).train_history_path + ".npz")
    train_values = model_history[train_column]
    valid_values = model_history[valid_column]
    epochs = train_values.shape[0]
    x_axis = np.arange(epochs)
    axis.plot(x_axis[train_values > 0], train_values[train_values > 0], train_linestyle, linewidth=linewidth, label="train")
    axis.plot(x_axis[valid_values > 0], valid_values[valid_values > 0], valid_linestyle, linewidth=linewidth, label="valid")
    return epochs

# Plots history of learning curves for a specific model.
def plot_learning_curves(params):
    """
    Plots learning curves (loss and accuracy on both training and validation sets) for a model identified by a parameters struct.
    """
    curves_figure = pyplot.figure(figsize = (10, 4))
    axis = curves_figure.add_subplot(1, 2, 1)
    epochs_plotted = plot_curve(axis, parameters, train_column = "train_accuracy_history", valid_column = "valid_accuracy_history")

    pyplot.grid()
    pyplot.legend()
    pyplot.xlabel("epoch")
    pyplot.ylabel("accuracy")
    pyplot.ylim(50., 115.)
    pyplot.xlim(0, epochs_plotted)

    axis = curves_figure.add_subplot(1, 2, 2)
    epochs_plotted = plot_curve(axis, parameters, train_column = "train_loss_history", valid_column = "valid_loss_history")

    pyplot.grid()
    pyplot.legend()
    pyplot.xlabel("epoch")
    pyplot.ylabel("loss")
    pyplot.ylim(0.0001, 10.)
    pyplot.xlim(0, epochs_plotted)
    pyplot.yscale("log")

# %%
def train_model(params, X_train, y_train, X_valid, y_valid, X_test, y_test):
    """
    Performs model training based on provided training dataset 
    according to provided parameters, and then evaluates trained 
    model with testing dataset. 
    Part of the training dataset may be used for validation during
    training if specified in model parameters.

    Parameters
    ----------
    params        : Parameters
                    Structure (`namedtuple`) containing model parameters.
    X_train       : 
                    Training dataset. 
    y_train       : 
                    Training dataset labels. 
    X_valid       : 
                    Validation dataset. 
    y_valid       : 
                    Validation dataset labels. 
    X_test        : 
                    Testing dataset. 
    y_test        : 
                    Testing dataset labels. 
    logger_config : 
                    Logger configuration, containing Dropbox and Telegram settings 
                    for notifications and cloud logs backup. 
    """
    
    # Initialisation routines: generate variable scope, create logger, note start time.
    paths = Paths(params)
    log = ModelCloudLog(
        os.path.join(paths.root_path, "logs"), 
    )
    start = time.time()
    model_variable_scope = paths.var_scope

    log.log_parameters(params, y_train.shape[0], y_valid.shape[0], y_test.shape[0]) 
    
    # Build the graph
    graph = tf.Graph()
    with graph.as_default():
        # Input data. For the training data, we use a placeholder that will be fed at run time with a training minibatch.
        tf_x_batch = tf.placeholder(tf.float32, shape = (None, params.image_size[0], params.image_size[1], 1))
        tf_y_batch = tf.placeholder(tf.float32, shape = (None, params.num_classes))
        is_training = tf.placeholder(tf.bool)
        current_epoch = tf.Variable(0, trainable=False)  # count the number of epochs

        # Model parameters.
        if params.learning_rate_decay:
            learning_rate = tf.train.exponential_decay(params.learning_rate, current_epoch, decay_steps = params.max_epochs, decay_rate = 0.01)
        else:
            learning_rate = params.learning_rate
            
        # Training computation.
        with tf.variable_scope(model_variable_scope):
            logits = model_pass(tf_x_batch, params, is_training)
            if params.l2_reg_enabled:
                with tf.variable_scope('fc4', reuse = True):
                    l2_loss = tf.nn.l2_loss(tf.get_variable('weights'))
            else:
                l2_loss = 0

        predictions = tf.nn.softmax(logits)
        softmax_cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_y_batch)
        loss = tf.reduce_mean(softmax_cross_entropy) + params.l2_lambda * l2_loss  

        # Optimizer.
        optimizer = tf.train.AdamOptimizer(
            learning_rate = learning_rate
        ).minimize(loss)

    with tf.Session(graph = graph) as session:
        session.run(tf.global_variables_initializer())

        # A routine for evaluating current model parameters
        def get_accuracy_and_loss_in_batches(X, y):
            p = []
            sce = []
            batch_iterator = BatchIterator(batch_size = 128)
            for x_batch, y_batch in batch_iterator(X, y):
                [p_batch, sce_batch] = session.run([predictions, softmax_cross_entropy], feed_dict = {
                        tf_x_batch : x_batch, 
                        tf_y_batch : y_batch,
                        is_training : False
                    }
                )
                p.extend(p_batch)
                sce.extend(sce_batch)
            p = np.array(p)
            sce = np.array(sce)
            accuracy = 100.0 * np.sum(np.argmax(p, 1) == np.argmax(y, 1)) / p.shape[0]
            loss = np.mean(sce)
            return (accuracy, loss)
        
        # If we chose to keep training previously trained model, restore session.
        if params.resume_training: 
            try:
                tf.train.Saver().restore(session, paths.model_path)
            except Exception as e:
                log("Failed restoring previously trained model: file does not exist.")
                pass
        
        saver = tf.train.Saver()
        early_stopping = EarlyStopping(tf.train.Saver(), session, patience = params.early_stopping_patience, minimize = True)
        train_loss_history = np.empty([0], dtype = np.float32)
        train_accuracy_history = np.empty([0], dtype = np.float32)
        valid_loss_history = np.empty([0], dtype = np.float32)
        valid_accuracy_history = np.empty([0], dtype = np.float32)
        if params.max_epochs > 0:
            log("================= TRAINING ==================")
        else:
            log("================== TESTING ==================")       
        log(" Timestamp: " + get_time_hhmmss())
        log.sync()
        
        for epoch in range(params.max_epochs):
            current_epoch = epoch
            # Train on whole randomised dataset in batches
            batch_iterator = BatchIterator(batch_size = params.batch_size, shuffle = True)
            for x_batch, y_batch in batch_iterator(X_train, y_train):
                session.run([optimizer], feed_dict = {
                        tf_x_batch : x_batch, 
                        tf_y_batch : y_batch,
                        is_training : True
                    }
                )

            # If another significant epoch ended, we log our losses.
            if (epoch % params.log_epoch == 0):
                # Get validation data predictions and log validation loss:
                valid_accuracy, valid_loss = get_accuracy_and_loss_in_batches(X_valid, y_valid)

                # Get training data predictions and log training loss:
                train_accuracy, train_loss = get_accuracy_and_loss_in_batches(X_train, y_train)

                if (epoch % params.print_epoch == 0):
                    log("-------------- EPOCH %4d/%d --------------" % (epoch, params.max_epochs))
                    log("     Train loss: %.8f, accuracy: %.2f%%" % (train_loss, train_accuracy))
                    log("Validation loss: %.8f, accuracy: %.2f%%" % (valid_loss, valid_accuracy))
                    log("      Best loss: %.8f at epoch %d" % (early_stopping.best_monitored_value, early_stopping.best_monitored_epoch))
                    log("   Elapsed time: " + get_time_hhmmss(start))
                    log("      Timestamp: " + get_time_hhmmss())
                    log.sync()
            else:
                valid_loss = 0.
                valid_accuracy = 0.
                train_loss = 0.
                train_accuracy = 0.
                
            valid_loss_history = np.append(valid_loss_history, [valid_loss])
            valid_accuracy_history = np.append(valid_accuracy_history, [valid_accuracy])
            train_loss_history = np.append(train_loss_history, [train_loss])
            train_accuracy_history = np.append(train_accuracy_history, [train_accuracy])
            
            if params.early_stopping_enabled:
                # Get validation data predictions and log validation loss:
                if valid_loss == 0:
                    _, valid_loss = get_accuracy_and_loss_in_batches(X_valid, y_valid)
                if early_stopping(valid_loss, epoch): 
                    log("Early stopping.\nBest monitored loss was {:.8f} at epoch {}.".format(
                        early_stopping.best_monitored_value, early_stopping.best_monitored_epoch
                    ))
                    break

        # Evaluate on test dataset.
        test_accuracy, test_loss = get_accuracy_and_loss_in_batches(X_test, y_test)
        valid_accuracy, valid_loss = get_accuracy_and_loss_in_batches(X_valid, y_valid)
        log("=============================================")
        log(" Valid loss: %.8f, accuracy = %.2f%%)" % (valid_loss, valid_accuracy)) 
        log(" Test loss: %.8f, accuracy = %.2f%%)" % (test_loss, test_accuracy)) 
        log(" Total time: " + get_time_hhmmss(start))
        log("  Timestamp: " + get_time_hhmmss())

        # Save model weights for future use.
        saved_model_path = saver.save(session, paths.model_path)
        log("Model file: " + saved_model_path)
        np.savez(paths.train_history_path, train_loss_history = train_loss_history, train_accuracy_history = train_accuracy_history, valid_loss_history = valid_loss_history, valid_accuracy_history = valid_accuracy_history)
        log("Train history file: " + paths.train_history_path)
        log.sync(notify=True, message="Finished training with *%.2f%%* accuracy on the testing set (loss = *%.6f*)." % (test_accuracy, test_loss))
        
        plot_learning_curves(params)
        log.add_plot(notify=True, caption="Learning curves")
        
        pyplot.show()

# %% [markdown]
# ### Train the model

# %%
import pickle
from sklearn.model_selection import train_test_split

#train_extended_preprocessed_dataset_file = "data/train_extended_preprocessed.p"
train_balanced_preprocessed_dataset_file = "data/adv_image_4_layers.p"
test_preprocessed_dataset_file = "data/test_processed.p"


parameters = Parameters(
    # Data parameters
    num_classes = 43,
    image_size = (32, 32),
    # Training parameters
    batch_size = 256,
    max_epochs = 500,
    log_epoch = 1,
    print_epoch = 1,
    # Optimisations
    learning_rate_decay = False,
    learning_rate = 0.001,
    l2_reg_enabled = True,
    l2_lambda = 0.0001,
    early_stopping_enabled = True,
    early_stopping_patience = 50,
    resume_training = True,
    # Layers architecture
    conv1_k = 7, conv1_d = 16, conv1_p = 0.9,
    conv2_k = 7, conv2_d = 32, conv2_p = 0.8,
    conv3_k = 5, conv3_d = 64, conv3_p = 0.7,
    conv4_k = 3, conv4_d = 128, conv4_p = 0.6,
    fc4_size = 1024, fc4_p = 0.5,
    adv_training=True,
    perturbed_ratio= None
    
)

X_train, y_train = load_pickled_data(train_balanced_preprocessed_dataset_file, columns = ['features', 'labels'])
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.25)
X_test, y_test = load_pickled_data(test_preprocessed_dataset_file, columns = ['features', 'labels'])
train_model(parameters, X_train, y_train, X_valid, y_valid, X_test, y_test)
# Out:
# =============================================
# ============= RESUMING TRAINING =============
# =============================================
# =================== DATA ====================
#             Training set: 37132 examples
#           Validation set: 12378 examples
#              Testing set: 12630 examples
#               Batch size: 256
# =================== MODEL ===================
# --------------- ARCHITECTURE ----------------
#             Type       Size     Dropout (keep p)
#  Layer 1    7x7 Conv   16       0.9
#  Layer 2    7x7 Conv   32       0.8
#  Layer 3    5x5 Conv   64       0.7
#  Layer 4    FC         1024     0.5
# ---------------- PARAMETERS -----------------
#      Learning rate decay: Disabled (rate = 0.001)
#        L2 Regularization: Enabled (lambda = 0.0001)
#           Early stopping: Enabled (patience = 50)
#  Keep training old model: Enabled
# INFO:tensorflow:Restoring parameters from /home/wastaljoey/TSC1/models/4layers_k7d16p0.9_k7d32p0.8_k5d64p0.7_fc1024p0.5_no-lrdec_l2_advtrain/model.ckpt
# Failed restoring previously trained model: file does not exist.
# ================= TRAINING ==================
#  Timestamp: 2017/11/24 13:15:37
# -------------- EPOCH    0/500 --------------
#      Train loss: 2.51730895, accuracy: 31.36%
# Validation loss: 2.52975416, accuracy: 31.16%
#       Best loss: inf at epoch 0
#    Elapsed time: 00:01:18
#       Timestamp: 2017/11/24 13:16:35
# -------------- EPOCH    1/500 --------------
#      Train loss: 2.02272058, accuracy: 46.49%
# Validation loss: 2.05624866, accuracy: 45.40%
#       Best loss: 2.52975416 at epoch 0
#    Elapsed time: 00:02:16
#       Timestamp: 2017/11/24 13:17:32
# -------------- EPOCH    2/500 --------------
#      Train loss: 1.75038946, accuracy: 53.47%
# Validation loss: 1.80113423, accuracy: 52.32%
#       Best loss: 2.05624866 at epoch 1
#    Elapsed time: 00:03:14
#       Timestamp: 2017/11/24 13:18:31
# -------------- EPOCH    3/500 --------------
#      Train loss: 1.62391424, accuracy: 56.48%
# Validation loss: 1.69349718, accuracy: 54.50%
#       Best loss: 1.80113423 at epoch 2
#    Elapsed time: 00:04:11
#       Timestamp: 2017/11/24 13:19:28
# -------------- EPOCH    4/500 --------------
#      Train loss: 1.62190235, accuracy: 56.78%
# Validation loss: 1.69414830, accuracy: 54.48%
#       Best loss: 1.69349718 at epoch 3
#    Elapsed time: 00:05:09
#       Timestamp: 2017/11/24 13:20:25
# -------------- EPOCH    5/500 --------------
#      Train loss: 1.49068546, accuracy: 60.28%
# Validation loss: 1.56907558, accuracy: 58.28%
#       Best loss: 1.69349718 at epoch 3
#    Elapsed time: 00:06:06
#       Timestamp: 2017/11/24 13:21:22
# -------------- EPOCH    6/500 --------------
#      Train loss: 1.39840758, accuracy: 62.50%
# Validation loss: 1.49005055, accuracy: 59.95%
#       Best loss: 1.56907558 at epoch 5
#    Elapsed time: 00:07:04
#       Timestamp: 2017/11/24 13:22:21
# -------------- EPOCH    7/500 --------------
#      Train loss: 1.33375156, accuracy: 64.17%
# Validation loss: 1.43442762, accuracy: 61.15%
#       Best loss: 1.49005055 at epoch 6
#    Elapsed time: 00:08:01
#       Timestamp: 2017/11/24 13:23:18
# -------------- EPOCH    8/500 --------------
#      Train loss: 1.30619860, accuracy: 65.37%
# Validation loss: 1.41157210, accuracy: 61.86%
#       Best loss: 1.43442762 at epoch 7
#    Elapsed time: 00:08:58
#       Timestamp: 2017/11/24 13:24:15
# -------------- EPOCH    9/500 --------------
#      Train loss: 1.29658401, accuracy: 65.97%
# Validation loss: 1.40305710, accuracy: 62.36%
#       Best loss: 1.41157210 at epoch 8
#    Elapsed time: 00:09:55
#       Timestamp: 2017/11/24 13:25:12
# -------------- EPOCH   10/500 --------------
#      Train loss: 1.24596691, accuracy: 67.10%
# Validation loss: 1.36294937, accuracy: 63.30%
#       Best loss: 1.40305710 at epoch 9
#    Elapsed time: 00:10:52
#       Timestamp: 2017/11/24 13:26:09
# -------------- EPOCH   11/500 --------------
#      Train loss: 1.25556445, accuracy: 66.75%
# Validation loss: 1.36980987, accuracy: 63.09%
#       Best loss: 1.36294937 at epoch 10
#    Elapsed time: 00:11:50
#       Timestamp: 2017/11/24 13:27:07
# -------------- EPOCH   12/500 --------------
#      Train loss: 1.20261967, accuracy: 67.92%
# Validation loss: 1.32943559, accuracy: 64.07%
#       Best loss: 1.36294937 at epoch 10
#    Elapsed time: 00:12:49
#       Timestamp: 2017/11/24 13:28:05
# -------------- EPOCH   13/500 --------------
#      Train loss: 1.19933486, accuracy: 67.80%
# Validation loss: 1.32884908, accuracy: 63.88%
#       Best loss: 1.32943559 at epoch 12
#    Elapsed time: 00:13:47
#       Timestamp: 2017/11/24 13:29:04
# -------------- EPOCH   14/500 --------------
#      Train loss: 1.18731761, accuracy: 68.11%
# Validation loss: 1.32154512, accuracy: 64.26%
#       Best loss: 1.32884908 at epoch 13
#    Elapsed time: 00:14:47
#       Timestamp: 2017/11/24 13:30:03
# -------------- EPOCH   15/500 --------------
#      Train loss: 1.14912057, accuracy: 69.47%
# Validation loss: 1.28881454, accuracy: 65.09%
#       Best loss: 1.32154512 at epoch 14
#    Elapsed time: 00:15:45
#       Timestamp: 2017/11/24 13:31:02
# -------------- EPOCH   16/500 --------------
#      Train loss: 1.13255000, accuracy: 69.85%
# Validation loss: 1.27657676, accuracy: 65.28%
#       Best loss: 1.28881454 at epoch 15
#    Elapsed time: 00:16:44
#       Timestamp: 2017/11/24 13:32:00
# -------------- EPOCH   17/500 --------------
#      Train loss: 1.13023818, accuracy: 70.09%
# Validation loss: 1.27312839, accuracy: 66.02%
#       Best loss: 1.27657676 at epoch 16
#    Elapsed time: 00:17:41
#       Timestamp: 2017/11/24 13:32:58
# -------------- EPOCH   18/500 --------------
#      Train loss: 1.11805820, accuracy: 70.29%
# Validation loss: 1.26615036, accuracy: 65.76%
#       Best loss: 1.27312839 at epoch 17
#    Elapsed time: 00:18:37
#       Timestamp: 2017/11/24 13:33:54
# -------------- EPOCH   19/500 --------------
#      Train loss: 1.09100699, accuracy: 70.82%
# Validation loss: 1.24130750, accuracy: 66.34%
#       Best loss: 1.26615036 at epoch 18
#    Elapsed time: 00:19:33
#       Timestamp: 2017/11/24 13:34:49
# -------------- EPOCH   20/500 --------------
#      Train loss: 1.08991218, accuracy: 71.02%
# Validation loss: 1.24753153, accuracy: 66.21%
#       Best loss: 1.24130750 at epoch 19
#    Elapsed time: 00:20:31
#       Timestamp: 2017/11/24 13:35:48
# -------------- EPOCH   21/500 --------------
#      Train loss: 1.08836281, accuracy: 71.25%
# Validation loss: 1.24783635, accuracy: 66.49%
#       Best loss: 1.24130750 at epoch 19
#    Elapsed time: 00:21:29
#       Timestamp: 2017/11/24 13:36:46
# -------------- EPOCH   22/500 --------------
#      Train loss: 1.08372653, accuracy: 70.27%
# Validation loss: 1.24458730, accuracy: 65.44%
#       Best loss: 1.24130750 at epoch 19
#    Elapsed time: 00:22:27
#       Timestamp: 2017/11/24 13:37:43
# -------------- EPOCH   23/500 --------------
#      Train loss: 1.06498325, accuracy: 71.58%
# Validation loss: 1.23248637, accuracy: 66.54%
#       Best loss: 1.24130750 at epoch 19
#    Elapsed time: 00:23:24
#       Timestamp: 2017/11/24 13:38:41
# -------------- EPOCH   24/500 --------------
#      Train loss: 1.05588043, accuracy: 71.99%
# Validation loss: 1.22339189, accuracy: 66.93%
#       Best loss: 1.23248637 at epoch 23
#    Elapsed time: 00:24:20
#       Timestamp: 2017/11/24 13:39:37
# -------------- EPOCH   25/500 --------------
#      Train loss: 1.03827333, accuracy: 72.41%
# Validation loss: 1.20948184, accuracy: 67.39%
#       Best loss: 1.22339189 at epoch 24
#    Elapsed time: 00:25:17
#       Timestamp: 2017/11/24 13:40:33
# -------------- EPOCH   26/500 --------------
#      Train loss: 1.02683246, accuracy: 72.67%
# Validation loss: 1.20294762, accuracy: 67.27%
#       Best loss: 1.20948184 at epoch 25
#    Elapsed time: 00:26:14
#       Timestamp: 2017/11/24 13:41:31
# -------------- EPOCH   27/500 --------------
#      Train loss: 1.02755833, accuracy: 72.08%
# Validation loss: 1.20111597, accuracy: 66.34%
#       Best loss: 1.20294762 at epoch 26
#    Elapsed time: 00:27:11
#       Timestamp: 2017/11/24 13:42:28
# -------------- EPOCH   28/500 --------------
#      Train loss: 1.01980889, accuracy: 72.67%
# Validation loss: 1.19479489, accuracy: 67.68%
#       Best loss: 1.20111597 at epoch 27
#    Elapsed time: 00:28:09
#       Timestamp: 2017/11/24 13:43:25
# -------------- EPOCH   29/500 --------------
#      Train loss: 1.01862228, accuracy: 72.78%
# Validation loss: 1.19498324, accuracy: 67.85%
#       Best loss: 1.19479489 at epoch 28
#    Elapsed time: 00:29:04
#       Timestamp: 2017/11/24 13:44:21
# -------------- EPOCH   30/500 --------------
#      Train loss: 0.99074763, accuracy: 73.52%
# Validation loss: 1.18164444, accuracy: 67.92%
#       Best loss: 1.19479489 at epoch 28
#    Elapsed time: 00:30:02
#       Timestamp: 2017/11/24 13:45:19
# -------------- EPOCH   31/500 --------------
#      Train loss: 0.99436289, accuracy: 73.87%
# Validation loss: 1.17851472, accuracy: 68.19%
#       Best loss: 1.18164444 at epoch 30
#    Elapsed time: 00:31:01
#       Timestamp: 2017/11/24 13:46:18
# -------------- EPOCH   32/500 --------------
#      Train loss: 0.99092722, accuracy: 73.70%
# Validation loss: 1.17731905, accuracy: 68.22%
#       Best loss: 1.17851472 at epoch 31
#    Elapsed time: 00:31:59
#       Timestamp: 2017/11/24 13:47:16
# -------------- EPOCH   33/500 --------------
#      Train loss: 1.02523482, accuracy: 73.32%
# Validation loss: 1.21195662, accuracy: 67.72%
#       Best loss: 1.17731905 at epoch 32
#    Elapsed time: 00:32:54
#       Timestamp: 2017/11/24 13:48:11
# -------------- EPOCH   34/500 --------------
#      Train loss: 0.97868270, accuracy: 74.13%
# Validation loss: 1.17121887, accuracy: 68.19%
#       Best loss: 1.17731905 at epoch 32
#    Elapsed time: 00:33:52
#       Timestamp: 2017/11/24 13:49:09
# -------------- EPOCH   35/500 --------------
#      Train loss: 0.97317129, accuracy: 74.03%
# Validation loss: 1.16629148, accuracy: 68.40%
#       Best loss: 1.17121887 at epoch 34
#    Elapsed time: 00:34:49
#       Timestamp: 2017/11/24 13:50:06
# -------------- EPOCH   36/500 --------------
#      Train loss: 0.98048306, accuracy: 74.11%
# Validation loss: 1.17335427, accuracy: 68.40%
#       Best loss: 1.16629148 at epoch 35
#    Elapsed time: 00:35:45
#       Timestamp: 2017/11/24 13:51:01
# -------------- EPOCH   37/500 --------------
#      Train loss: 0.98153234, accuracy: 74.07%
# Validation loss: 1.17716646, accuracy: 68.20%
#       Best loss: 1.16629148 at epoch 35
#    Elapsed time: 00:36:41
#       Timestamp: 2017/11/24 13:51:58
# -------------- EPOCH   38/500 --------------
#      Train loss: 0.96325809, accuracy: 74.41%
# Validation loss: 1.16598701, accuracy: 68.52%
#       Best loss: 1.16629148 at epoch 35
#    Elapsed time: 00:37:37
#       Timestamp: 2017/11/24 13:52:53
# -------------- EPOCH   39/500 --------------
#      Train loss: 0.96379787, accuracy: 74.48%
# Validation loss: 1.16752517, accuracy: 68.56%
#       Best loss: 1.16598701 at epoch 38
#    Elapsed time: 00:38:33
#       Timestamp: 2017/11/24 13:53:49
# -------------- EPOCH   40/500 --------------
#      Train loss: 0.95637280, accuracy: 74.85%
# Validation loss: 1.15242970, accuracy: 69.00%
#       Best loss: 1.16598701 at epoch 38
#    Elapsed time: 00:39:29
#       Timestamp: 2017/11/24 13:54:46
# -------------- EPOCH   41/500 --------------
#      Train loss: 0.94326079, accuracy: 74.92%
# Validation loss: 1.15002584, accuracy: 68.93%
#       Best loss: 1.15242970 at epoch 40
#    Elapsed time: 00:40:26
#       Timestamp: 2017/11/24 13:55:43
# -------------- EPOCH   42/500 --------------
#      Train loss: 0.93663824, accuracy: 75.07%
# Validation loss: 1.14072108, accuracy: 69.29%
#       Best loss: 1.15002584 at epoch 41
#    Elapsed time: 00:41:22
#       Timestamp: 2017/11/24 13:56:39
# -------------- EPOCH   43/500 --------------
#      Train loss: 0.94153303, accuracy: 74.80%
# Validation loss: 1.15301228, accuracy: 68.76%
#       Best loss: 1.14072108 at epoch 42
#    Elapsed time: 00:42:18
#       Timestamp: 2017/11/24 13:57:35
# -------------- EPOCH   44/500 --------------
#      Train loss: 0.94052279, accuracy: 75.03%
# Validation loss: 1.15126240, accuracy: 68.73%
#       Best loss: 1.14072108 at epoch 42
#    Elapsed time: 00:43:15
#       Timestamp: 2017/11/24 13:58:32
# -------------- EPOCH   45/500 --------------
#      Train loss: 0.93073803, accuracy: 75.29%
# Validation loss: 1.14472437, accuracy: 69.03%
#       Best loss: 1.14072108 at epoch 42
#    Elapsed time: 00:44:12
#       Timestamp: 2017/11/24 13:59:28
# -------------- EPOCH   46/500 --------------
#      Train loss: 0.93159908, accuracy: 75.34%
# Validation loss: 1.14549029, accuracy: 69.20%
#       Best loss: 1.14072108 at epoch 42
#    Elapsed time: 00:45:08
#       Timestamp: 2017/11/24 14:00:24
# -------------- EPOCH   47/500 --------------
#      Train loss: 0.92049932, accuracy: 75.41%
# Validation loss: 1.14022112, accuracy: 69.30%
#       Best loss: 1.14072108 at epoch 42
#    Elapsed time: 00:46:03
#       Timestamp: 2017/11/24 14:01:20
# -------------- EPOCH   48/500 --------------
#      Train loss: 0.92184556, accuracy: 75.67%
# Validation loss: 1.13407624, accuracy: 69.49%
#       Best loss: 1.14022112 at epoch 47
#    Elapsed time: 00:47:01
#       Timestamp: 2017/11/24 14:02:17
# -------------- EPOCH   49/500 --------------
#      Train loss: 0.93262792, accuracy: 75.42%
# Validation loss: 1.14820278, accuracy: 69.13%
#       Best loss: 1.13407624 at epoch 48
#    Elapsed time: 00:47:56
#       Timestamp: 2017/11/24 14:03:13
# -------------- EPOCH   50/500 --------------
#      Train loss: 0.91529840, accuracy: 75.86%
# Validation loss: 1.13626468, accuracy: 69.41%
#       Best loss: 1.13407624 at epoch 48
#    Elapsed time: 00:48:53
#       Timestamp: 2017/11/24 14:04:10
# -------------- EPOCH   51/500 --------------
#      Train loss: 0.91357857, accuracy: 75.85%
# Validation loss: 1.13399315, accuracy: 69.53%
#       Best loss: 1.13407624 at epoch 48
#    Elapsed time: 00:49:49
#       Timestamp: 2017/11/24 14:05:06
# -------------- EPOCH   52/500 --------------
#      Train loss: 0.91078490, accuracy: 75.92%
# Validation loss: 1.13726389, accuracy: 69.31%
#       Best loss: 1.13399315 at epoch 51
#    Elapsed time: 00:50:46
#       Timestamp: 2017/11/24 14:06:02
# -------------- EPOCH   53/500 --------------
#      Train loss: 0.91186899, accuracy: 75.93%
# Validation loss: 1.14134550, accuracy: 69.11%
#       Best loss: 1.13399315 at epoch 51
#    Elapsed time: 00:51:41
#       Timestamp: 2017/11/24 14:06:58
# -------------- EPOCH   54/500 --------------
#      Train loss: 0.91046375, accuracy: 75.88%
# Validation loss: 1.14002907, accuracy: 69.54%
#       Best loss: 1.13399315 at epoch 51
#    Elapsed time: 00:52:37
#       Timestamp: 2017/11/24 14:07:54
# -------------- EPOCH   55/500 --------------
#      Train loss: 0.90964079, accuracy: 75.93%
# Validation loss: 1.13625205, accuracy: 69.37%
#       Best loss: 1.13399315 at epoch 51
#    Elapsed time: 00:53:33
#       Timestamp: 2017/11/24 14:08:50
# -------------- EPOCH   56/500 --------------
#      Train loss: 0.90347445, accuracy: 76.09%
# Validation loss: 1.13900208, accuracy: 69.37%
#       Best loss: 1.13399315 at epoch 51
#    Elapsed time: 00:54:28
#       Timestamp: 2017/11/24 14:09:45
# -------------- EPOCH   57/500 --------------
#      Train loss: 0.90103233, accuracy: 76.17%
# Validation loss: 1.13598120, accuracy: 69.52%
#       Best loss: 1.13399315 at epoch 51
#    Elapsed time: 00:55:23
#       Timestamp: 2017/11/24 14:10:39
# -------------- EPOCH   58/500 --------------
#      Train loss: 0.89700556, accuracy: 76.20%
# Validation loss: 1.13269639, accuracy: 69.46%
#       Best loss: 1.13399315 at epoch 51
#    Elapsed time: 00:56:18
#       Timestamp: 2017/11/24 14:11:35
# -------------- EPOCH   59/500 --------------
#      Train loss: 0.89222264, accuracy: 76.42%
# Validation loss: 1.12845922, accuracy: 69.72%
#       Best loss: 1.13269639 at epoch 58
#    Elapsed time: 00:57:15
#       Timestamp: 2017/11/24 14:12:31
# -------------- EPOCH   60/500 --------------
#      Train loss: 0.89074379, accuracy: 76.43%
# Validation loss: 1.12440038, accuracy: 69.71%
#       Best loss: 1.12845922 at epoch 59
#    Elapsed time: 00:58:10
#       Timestamp: 2017/11/24 14:13:27
# -------------- EPOCH   61/500 --------------
#      Train loss: 0.89537865, accuracy: 76.34%
# Validation loss: 1.13362896, accuracy: 69.30%
#       Best loss: 1.12440038 at epoch 60
#    Elapsed time: 00:59:09
#       Timestamp: 2017/11/24 14:14:25
# -------------- EPOCH   62/500 --------------
#      Train loss: 0.89022642, accuracy: 76.35%
# Validation loss: 1.13043320, accuracy: 69.46%
#       Best loss: 1.12440038 at epoch 60
#    Elapsed time: 01:00:04
#       Timestamp: 2017/11/24 14:15:21
# -------------- EPOCH   63/500 --------------
#      Train loss: 0.89022744, accuracy: 76.31%
# Validation loss: 1.12912142, accuracy: 69.46%
#       Best loss: 1.12440038 at epoch 60
#    Elapsed time: 01:00:59
#       Timestamp: 2017/11/24 14:16:15
# -------------- EPOCH   64/500 --------------
#      Train loss: 0.89069194, accuracy: 76.38%
# Validation loss: 1.13006413, accuracy: 69.58%
#       Best loss: 1.12440038 at epoch 60
#    Elapsed time: 01:01:55
#       Timestamp: 2017/11/24 14:17:12
# -------------- EPOCH   65/500 --------------
#      Train loss: 0.87611973, accuracy: 76.72%
# Validation loss: 1.11375976, accuracy: 69.96%
#       Best loss: 1.12440038 at epoch 60
#    Elapsed time: 01:02:52
#       Timestamp: 2017/11/24 14:18:08
# -------------- EPOCH   66/500 --------------
#      Train loss: 0.88007826, accuracy: 76.64%
# Validation loss: 1.11348343, accuracy: 69.87%
#       Best loss: 1.11375976 at epoch 65
#    Elapsed time: 01:03:49
#       Timestamp: 2017/11/24 14:19:05
# -------------- EPOCH   67/500 --------------
#      Train loss: 0.87460023, accuracy: 76.82%
# Validation loss: 1.12684846, accuracy: 69.89%
#       Best loss: 1.11348343 at epoch 66
#    Elapsed time: 01:04:45
#       Timestamp: 2017/11/24 14:20:02
# -------------- EPOCH   68/500 --------------
#      Train loss: 0.89080036, accuracy: 76.45%
# Validation loss: 1.13243937, accuracy: 69.49%
#       Best loss: 1.11348343 at epoch 66
#    Elapsed time: 01:05:40
#       Timestamp: 2017/11/24 14:20:57
# -------------- EPOCH   69/500 --------------
#      Train loss: 0.87480241, accuracy: 76.76%
# Validation loss: 1.12146032, accuracy: 69.76%
#       Best loss: 1.11348343 at epoch 66
#    Elapsed time: 01:06:38
#       Timestamp: 2017/11/24 14:21:54
# -------------- EPOCH   70/500 --------------
#      Train loss: 0.87498623, accuracy: 76.70%
# Validation loss: 1.11936092, accuracy: 70.04%
#       Best loss: 1.11348343 at epoch 66
#    Elapsed time: 01:07:34
#       Timestamp: 2017/11/24 14:22:51
# -------------- EPOCH   71/500 --------------
#      Train loss: 0.86877424, accuracy: 77.02%
# Validation loss: 1.11454654, accuracy: 69.93%
#       Best loss: 1.11348343 at epoch 66
#    Elapsed time: 01:08:29
#       Timestamp: 2017/11/24 14:23:46
# -------------- EPOCH   72/500 --------------
#      Train loss: 0.86610055, accuracy: 76.98%
# Validation loss: 1.12154198, accuracy: 69.90%
#       Best loss: 1.11348343 at epoch 66
#    Elapsed time: 01:09:25
#       Timestamp: 2017/11/24 14:24:42
# -------------- EPOCH   73/500 --------------
#      Train loss: 0.86109293, accuracy: 77.10%
# Validation loss: 1.11264563, accuracy: 69.95%
#       Best loss: 1.11348343 at epoch 66
#    Elapsed time: 01:10:22
#       Timestamp: 2017/11/24 14:25:39
# -------------- EPOCH   74/500 --------------
#      Train loss: 0.86118495, accuracy: 77.00%
# Validation loss: 1.11163712, accuracy: 70.04%
#       Best loss: 1.11264563 at epoch 73
#    Elapsed time: 01:11:17
#       Timestamp: 2017/11/24 14:26:34
# -------------- EPOCH   75/500 --------------
#      Train loss: 0.86538899, accuracy: 77.18%
# Validation loss: 1.11133683, accuracy: 70.01%
#       Best loss: 1.11163712 at epoch 74
#    Elapsed time: 01:12:12
#       Timestamp: 2017/11/24 14:27:29
# -------------- EPOCH   76/500 --------------
#      Train loss: 0.86146796, accuracy: 77.15%
# Validation loss: 1.11320531, accuracy: 70.00%
#       Best loss: 1.11133683 at epoch 75
#    Elapsed time: 01:13:07
#       Timestamp: 2017/11/24 14:28:24
# -------------- EPOCH   77/500 --------------
#      Train loss: 0.86705887, accuracy: 77.10%
# Validation loss: 1.11339688, accuracy: 70.08%
#       Best loss: 1.11133683 at epoch 75
#    Elapsed time: 01:14:02
#       Timestamp: 2017/11/24 14:29:19
# -------------- EPOCH   78/500 --------------
#      Train loss: 0.85873497, accuracy: 77.19%
# Validation loss: 1.11010027, accuracy: 70.16%
#       Best loss: 1.11133683 at epoch 75
#    Elapsed time: 01:14:57
#       Timestamp: 2017/11/24 14:30:13
# -------------- EPOCH   79/500 --------------
#      Train loss: 0.85948592, accuracy: 77.18%
# Validation loss: 1.11530197, accuracy: 70.08%
#       Best loss: 1.11010027 at epoch 78
#    Elapsed time: 01:15:52
#       Timestamp: 2017/11/24 14:31:08
# -------------- EPOCH   80/500 --------------
#      Train loss: 0.85701549, accuracy: 77.31%
# Validation loss: 1.10669601, accuracy: 70.25%
#       Best loss: 1.11010027 at epoch 78
#    Elapsed time: 01:16:46
#       Timestamp: 2017/11/24 14:32:02
# -------------- EPOCH   81/500 --------------
#      Train loss: 0.86196029, accuracy: 77.20%
# Validation loss: 1.11065006, accuracy: 70.17%
#       Best loss: 1.10669601 at epoch 80
#    Elapsed time: 01:17:41
#       Timestamp: 2017/11/24 14:32:57
# -------------- EPOCH   82/500 --------------
#      Train loss: 0.84856778, accuracy: 77.40%
# Validation loss: 1.10700834, accuracy: 70.25%
#       Best loss: 1.10669601 at epoch 80
#    Elapsed time: 01:18:35
#       Timestamp: 2017/11/24 14:33:51
# -------------- EPOCH   83/500 --------------
#      Train loss: 0.85127181, accuracy: 77.52%
# Validation loss: 1.10566986, accuracy: 70.16%
#       Best loss: 1.10669601 at epoch 80
#    Elapsed time: 01:19:32
#       Timestamp: 2017/11/24 14:34:48
# -------------- EPOCH   84/500 --------------
#      Train loss: 0.85261917, accuracy: 77.42%
# Validation loss: 1.11321294, accuracy: 70.24%
#       Best loss: 1.10566986 at epoch 83
#    Elapsed time: 01:20:27
#       Timestamp: 2017/11/24 14:35:44
# -------------- EPOCH   85/500 --------------
#      Train loss: 0.84497118, accuracy: 77.58%
# Validation loss: 1.10535991, accuracy: 70.20%
#       Best loss: 1.10566986 at epoch 83
#    Elapsed time: 01:21:23
#       Timestamp: 2017/11/24 14:36:40
# -------------- EPOCH   86/500 --------------
#      Train loss: 0.84889495, accuracy: 77.53%
# Validation loss: 1.11276650, accuracy: 70.29%
#       Best loss: 1.10535991 at epoch 85
#    Elapsed time: 01:22:19
#       Timestamp: 2017/11/24 14:37:35
# -------------- EPOCH   87/500 --------------
#      Train loss: 0.84690863, accuracy: 77.60%
# Validation loss: 1.10321331, accuracy: 70.45%
#       Best loss: 1.10535991 at epoch 85
#    Elapsed time: 01:23:14
#       Timestamp: 2017/11/24 14:38:30
# -------------- EPOCH   88/500 --------------
#      Train loss: 0.84670854, accuracy: 77.74%
# Validation loss: 1.10275400, accuracy: 70.37%
#       Best loss: 1.10321331 at epoch 87
#    Elapsed time: 01:24:10
#       Timestamp: 2017/11/24 14:39:26
# -------------- EPOCH   89/500 --------------
#      Train loss: 0.84306049, accuracy: 77.56%
# Validation loss: 1.10765231, accuracy: 70.44%
#       Best loss: 1.10275400 at epoch 88
#    Elapsed time: 01:25:07
#       Timestamp: 2017/11/24 14:40:24
# -------------- EPOCH   90/500 --------------
#      Train loss: 0.84337139, accuracy: 77.57%
# Validation loss: 1.10435653, accuracy: 70.38%
#       Best loss: 1.10275400 at epoch 88
#    Elapsed time: 01:26:05
#       Timestamp: 2017/11/24 14:41:21
# -------------- EPOCH   91/500 --------------
#      Train loss: 0.84329689, accuracy: 77.74%
# Validation loss: 1.10250568, accuracy: 70.33%
#       Best loss: 1.10275400 at epoch 88
#    Elapsed time: 01:27:00
#       Timestamp: 2017/11/24 14:42:16
# -------------- EPOCH   92/500 --------------
#      Train loss: 0.83721483, accuracy: 77.75%
# Validation loss: 1.09956360, accuracy: 70.57%
#       Best loss: 1.10250568 at epoch 91
#    Elapsed time: 01:27:55
#       Timestamp: 2017/11/24 14:43:12
# -------------- EPOCH   93/500 --------------
#      Train loss: 0.84346598, accuracy: 77.67%
# Validation loss: 1.10484946, accuracy: 70.43%
#       Best loss: 1.09956360 at epoch 92
#    Elapsed time: 01:28:51
#       Timestamp: 2017/11/24 14:44:08
# -------------- EPOCH   94/500 --------------
#      Train loss: 0.83679414, accuracy: 77.85%
# Validation loss: 1.10994256, accuracy: 70.42%
#       Best loss: 1.09956360 at epoch 92
#    Elapsed time: 01:29:46
#       Timestamp: 2017/11/24 14:45:03
# -------------- EPOCH   95/500 --------------
#      Train loss: 0.84183103, accuracy: 77.69%
# Validation loss: 1.11890376, accuracy: 70.00%
#       Best loss: 1.09956360 at epoch 92
#    Elapsed time: 01:30:41
#       Timestamp: 2017/11/24 14:45:58
# -------------- EPOCH   96/500 --------------
#      Train loss: 0.84140503, accuracy: 77.88%
# Validation loss: 1.10664475, accuracy: 70.30%
#       Best loss: 1.09956360 at epoch 92
#    Elapsed time: 01:31:38
#       Timestamp: 2017/11/24 14:46:55
# -------------- EPOCH   97/500 --------------
#      Train loss: 0.83864540, accuracy: 77.71%
# Validation loss: 1.10504961, accuracy: 70.52%
#       Best loss: 1.09956360 at epoch 92
#    Elapsed time: 01:32:33
#       Timestamp: 2017/11/24 14:47:50
# -------------- EPOCH   98/500 --------------
#      Train loss: 0.83408731, accuracy: 77.84%
# Validation loss: 1.10280883, accuracy: 70.44%
#       Best loss: 1.09956360 at epoch 92
#    Elapsed time: 01:33:28
#       Timestamp: 2017/11/24 14:48:45
# -------------- EPOCH   99/500 --------------
#      Train loss: 0.82670718, accuracy: 78.05%
# Validation loss: 1.09874403, accuracy: 70.41%
#       Best loss: 1.09956360 at epoch 92
#    Elapsed time: 01:34:23
#       Timestamp: 2017/11/24 14:49:39
# -------------- EPOCH  100/500 --------------
#      Train loss: 0.82994747, accuracy: 77.94%
# Validation loss: 1.10367310, accuracy: 70.61%
#       Best loss: 1.09874403 at epoch 99
#    Elapsed time: 01:35:17
#       Timestamp: 2017/11/24 14:50:34
# -------------- EPOCH  101/500 --------------
#      Train loss: 0.82673782, accuracy: 77.90%
# Validation loss: 1.10352397, accuracy: 70.46%
#       Best loss: 1.09874403 at epoch 99
#    Elapsed time: 01:36:12
#       Timestamp: 2017/11/24 14:51:29
# -------------- EPOCH  102/500 --------------
#      Train loss: 0.82814717, accuracy: 78.00%
# Validation loss: 1.09902644, accuracy: 70.74%
#       Best loss: 1.09874403 at epoch 99
#    Elapsed time: 01:37:06
#       Timestamp: 2017/11/24 14:52:23
# -------------- EPOCH  103/500 --------------
#      Train loss: 0.82623154, accuracy: 78.00%
# Validation loss: 1.10710013, accuracy: 70.42%
#       Best loss: 1.09874403 at epoch 99
#    Elapsed time: 01:38:00
#       Timestamp: 2017/11/24 14:53:17
# -------------- EPOCH  104/500 --------------
#      Train loss: 0.82935297, accuracy: 77.91%
# Validation loss: 1.09934556, accuracy: 70.63%
#       Best loss: 1.09874403 at epoch 99
#    Elapsed time: 01:38:57
#       Timestamp: 2017/11/24 14:54:14
# -------------- EPOCH  105/500 --------------
#      Train loss: 0.82685757, accuracy: 77.97%
# Validation loss: 1.10864842, accuracy: 70.32%
#       Best loss: 1.09874403 at epoch 99
#    Elapsed time: 01:39:53
#       Timestamp: 2017/11/24 14:55:09
# -------------- EPOCH  106/500 --------------
#      Train loss: 0.82600915, accuracy: 78.14%
# Validation loss: 1.10261250, accuracy: 70.47%
#       Best loss: 1.09874403 at epoch 99
#    Elapsed time: 01:40:51
#       Timestamp: 2017/11/24 14:56:08
# -------------- EPOCH  107/500 --------------
#      Train loss: 0.82232350, accuracy: 78.14%
# Validation loss: 1.10377502, accuracy: 70.48%
#       Best loss: 1.09874403 at epoch 99
#    Elapsed time: 01:41:49
#       Timestamp: 2017/11/24 14:57:06
# -------------- EPOCH  108/500 --------------
#      Train loss: 0.81782877, accuracy: 78.25%
# Validation loss: 1.09746552, accuracy: 70.70%
#       Best loss: 1.09874403 at epoch 99
#    Elapsed time: 01:42:45
#       Timestamp: 2017/11/24 14:58:02
# -------------- EPOCH  109/500 --------------
#      Train loss: 0.82066655, accuracy: 78.15%
# Validation loss: 1.09683430, accuracy: 70.56%
#       Best loss: 1.09746552 at epoch 108
#    Elapsed time: 01:43:41
#       Timestamp: 2017/11/24 14:58:57
# -------------- EPOCH  110/500 --------------
#      Train loss: 0.81708664, accuracy: 78.34%
# Validation loss: 1.09423161, accuracy: 70.68%
#       Best loss: 1.09683430 at epoch 109
#    Elapsed time: 01:44:36
#       Timestamp: 2017/11/24 14:59:53
# -------------- EPOCH  111/500 --------------
#      Train loss: 0.82203621, accuracy: 78.29%
# Validation loss: 1.09580243, accuracy: 70.54%
#       Best loss: 1.09423161 at epoch 110
#    Elapsed time: 01:45:33
#       Timestamp: 2017/11/24 15:00:50
# -------------- EPOCH  112/500 --------------
#      Train loss: 0.82740980, accuracy: 78.09%
# Validation loss: 1.10376740, accuracy: 70.49%
#       Best loss: 1.09423161 at epoch 110
#    Elapsed time: 01:46:29
#       Timestamp: 2017/11/24 15:01:45
# -------------- EPOCH  113/500 --------------
#      Train loss: 0.82548600, accuracy: 78.05%
# Validation loss: 1.10708296, accuracy: 70.36%
#       Best loss: 1.09423161 at epoch 110
#    Elapsed time: 01:47:25
#       Timestamp: 2017/11/24 15:02:41
# -------------- EPOCH  114/500 --------------
#      Train loss: 0.82308006, accuracy: 78.14%
# Validation loss: 1.10321438, accuracy: 70.54%
#       Best loss: 1.09423161 at epoch 110
#    Elapsed time: 01:48:22
#       Timestamp: 2017/11/24 15:03:39
# -------------- EPOCH  115/500 --------------
#      Train loss: 0.81868649, accuracy: 78.24%
# Validation loss: 1.10060585, accuracy: 70.57%
#       Best loss: 1.09423161 at epoch 110
#    Elapsed time: 01:49:18
#       Timestamp: 2017/11/24 15:04:34
# -------------- EPOCH  116/500 --------------
#      Train loss: 0.81841463, accuracy: 78.27%
# Validation loss: 1.10591078, accuracy: 70.52%
#       Best loss: 1.09423161 at epoch 110
#    Elapsed time: 01:50:14
#       Timestamp: 2017/11/24 15:05:30
# -------------- EPOCH  117/500 --------------
#      Train loss: 0.81893474, accuracy: 78.22%
# Validation loss: 1.09948504, accuracy: 70.68%
#       Best loss: 1.09423161 at epoch 110
#    Elapsed time: 01:51:10
#       Timestamp: 2017/11/24 15:06:27
# -------------- EPOCH  118/500 --------------
#      Train loss: 0.81422061, accuracy: 78.37%
# Validation loss: 1.09551072, accuracy: 70.55%
#       Best loss: 1.09423161 at epoch 110
#    Elapsed time: 01:52:06
#       Timestamp: 2017/11/24 15:07:23
# -------------- EPOCH  119/500 --------------
#      Train loss: 0.81230116, accuracy: 78.29%
# Validation loss: 1.09994304, accuracy: 70.67%
#       Best loss: 1.09423161 at epoch 110
#    Elapsed time: 01:53:03
#       Timestamp: 2017/11/24 15:08:19
# -------------- EPOCH  120/500 --------------
#      Train loss: 0.81718916, accuracy: 78.28%
# Validation loss: 1.10044122, accuracy: 70.60%
#       Best loss: 1.09423161 at epoch 110
#    Elapsed time: 01:54:00
#       Timestamp: 2017/11/24 15:09:17
# -------------- EPOCH  121/500 --------------
#      Train loss: 0.81574249, accuracy: 78.30%
# Validation loss: 1.09717786, accuracy: 70.63%
#       Best loss: 1.09423161 at epoch 110
#    Elapsed time: 01:54:57
#       Timestamp: 2017/11/24 15:10:14
# -------------- EPOCH  122/500 --------------
#      Train loss: 0.82024300, accuracy: 78.19%
# Validation loss: 1.10858583, accuracy: 70.42%
#       Best loss: 1.09423161 at epoch 110
#    Elapsed time: 01:55:53
#       Timestamp: 2017/11/24 15:11:09
# -------------- EPOCH  123/500 --------------
#      Train loss: 0.81440318, accuracy: 78.36%
# Validation loss: 1.09632576, accuracy: 70.91%
#       Best loss: 1.09423161 at epoch 110
#    Elapsed time: 01:56:49
#       Timestamp: 2017/11/24 15:12:06
# -------------- EPOCH  124/500 --------------
#      Train loss: 0.82325423, accuracy: 78.33%
# Validation loss: 1.09227073, accuracy: 70.79%
#       Best loss: 1.09423161 at epoch 110
#    Elapsed time: 01:57:46
#       Timestamp: 2017/11/24 15:13:02
# -------------- EPOCH  125/500 --------------
#      Train loss: 0.81283146, accuracy: 78.35%
# Validation loss: 1.09855413, accuracy: 70.82%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 01:58:42
#       Timestamp: 2017/11/24 15:13:58
# -------------- EPOCH  126/500 --------------
#      Train loss: 0.81483495, accuracy: 78.29%
# Validation loss: 1.09992957, accuracy: 70.54%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 01:59:38
#       Timestamp: 2017/11/24 15:14:55
# -------------- EPOCH  127/500 --------------
#      Train loss: 0.81274009, accuracy: 78.33%
# Validation loss: 1.10306323, accuracy: 70.79%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 02:00:35
#       Timestamp: 2017/11/24 15:15:52
# -------------- EPOCH  128/500 --------------
#      Train loss: 0.80851984, accuracy: 78.47%
# Validation loss: 1.09658074, accuracy: 70.72%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 02:01:30
#       Timestamp: 2017/11/24 15:16:47
# -------------- EPOCH  129/500 --------------
#      Train loss: 0.81078213, accuracy: 78.51%
# Validation loss: 1.09357452, accuracy: 70.97%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 02:02:26
#       Timestamp: 2017/11/24 15:17:43
# -------------- EPOCH  130/500 --------------
#      Train loss: 0.80968934, accuracy: 78.53%
# Validation loss: 1.09398484, accuracy: 70.88%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 02:03:23
#       Timestamp: 2017/11/24 15:18:39
# -------------- EPOCH  131/500 --------------
#      Train loss: 0.80957854, accuracy: 78.46%
# Validation loss: 1.10013509, accuracy: 70.81%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 02:04:17
#       Timestamp: 2017/11/24 15:19:33
# -------------- EPOCH  132/500 --------------
#      Train loss: 0.81029451, accuracy: 78.53%
# Validation loss: 1.09978414, accuracy: 70.81%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 02:05:12
#       Timestamp: 2017/11/24 15:20:29
# -------------- EPOCH  133/500 --------------
#      Train loss: 0.80808258, accuracy: 78.56%
# Validation loss: 1.09461725, accuracy: 70.92%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 02:06:09
#       Timestamp: 2017/11/24 15:21:26
# -------------- EPOCH  134/500 --------------
#      Train loss: 0.80855834, accuracy: 78.58%
# Validation loss: 1.09378695, accuracy: 70.88%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 02:07:05
#       Timestamp: 2017/11/24 15:22:22
# -------------- EPOCH  135/500 --------------
#      Train loss: 0.81013298, accuracy: 78.54%
# Validation loss: 1.09738672, accuracy: 70.81%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 02:08:00
#       Timestamp: 2017/11/24 15:23:17
# -------------- EPOCH  136/500 --------------
#      Train loss: 0.80440122, accuracy: 78.64%
# Validation loss: 1.09821999, accuracy: 70.78%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 02:08:57
#       Timestamp: 2017/11/24 15:24:14
# -------------- EPOCH  137/500 --------------
#      Train loss: 0.80127954, accuracy: 78.77%
# Validation loss: 1.09422970, accuracy: 70.67%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 02:09:52
#       Timestamp: 2017/11/24 15:25:08
# -------------- EPOCH  138/500 --------------
#      Train loss: 0.80335975, accuracy: 78.68%
# Validation loss: 1.09428501, accuracy: 71.24%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 02:10:46
#       Timestamp: 2017/11/24 15:26:03
# -------------- EPOCH  139/500 --------------
#      Train loss: 0.80271679, accuracy: 78.67%
# Validation loss: 1.09544837, accuracy: 70.86%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 02:11:41
#       Timestamp: 2017/11/24 15:26:57
# -------------- EPOCH  140/500 --------------
#      Train loss: 0.80835605, accuracy: 78.47%
# Validation loss: 1.10331392, accuracy: 70.58%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 02:12:38
#       Timestamp: 2017/11/24 15:27:55
# -------------- EPOCH  141/500 --------------
#      Train loss: 0.81637555, accuracy: 78.51%
# Validation loss: 1.10701370, accuracy: 70.59%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 02:13:33
#       Timestamp: 2017/11/24 15:28:49
# -------------- EPOCH  142/500 --------------
#      Train loss: 0.80205995, accuracy: 78.81%
# Validation loss: 1.08772647, accuracy: 70.88%
#       Best loss: 1.09227073 at epoch 124
#    Elapsed time: 02:14:27
#       Timestamp: 2017/11/24 15:29:44
# -------------- EPOCH  143/500 --------------
#      Train loss: 0.80542594, accuracy: 78.57%
# Validation loss: 1.10423243, accuracy: 70.61%
#       Best loss: 1.08772647 at epoch 142
#    Elapsed time: 02:15:23
#       Timestamp: 2017/11/24 15:30:39
# -------------- EPOCH  144/500 --------------
#      Train loss: 0.79838395, accuracy: 78.76%
# Validation loss: 1.09399271, accuracy: 70.88%
#       Best loss: 1.08772647 at epoch 142
#    Elapsed time: 02:16:17
#       Timestamp: 2017/11/24 15:31:34
# -------------- EPOCH  145/500 --------------
#      Train loss: 0.79564303, accuracy: 78.86%
# Validation loss: 1.09592211, accuracy: 70.84%
#       Best loss: 1.08772647 at epoch 142
#    Elapsed time: 02:17:14
#       Timestamp: 2017/11/24 15:32:31
# -------------- EPOCH  146/500 --------------
#      Train loss: 0.80216444, accuracy: 78.87%
# Validation loss: 1.08778739, accuracy: 70.96%
#       Best loss: 1.08772647 at epoch 142
#    Elapsed time: 02:18:08
#       Timestamp: 2017/11/24 15:33:25
# -------------- EPOCH  147/500 --------------
#      Train loss: 0.79699785, accuracy: 78.83%
# Validation loss: 1.09202194, accuracy: 70.94%
#       Best loss: 1.08772647 at epoch 142
#    Elapsed time: 02:19:03
#       Timestamp: 2017/11/24 15:34:20
# -------------- EPOCH  148/500 --------------
#      Train loss: 0.80264348, accuracy: 78.66%
# Validation loss: 1.10156798, accuracy: 70.76%
#       Best loss: 1.08772647 at epoch 142
#    Elapsed time: 02:19:58
#       Timestamp: 2017/11/24 15:35:15
# -------------- EPOCH  149/500 --------------
#      Train loss: 0.79759473, accuracy: 78.65%
# Validation loss: 1.09909260, accuracy: 70.76%
#       Best loss: 1.08772647 at epoch 142
#    Elapsed time: 02:20:52
#       Timestamp: 2017/11/24 15:36:09
# -------------- EPOCH  150/500 --------------
#      Train loss: 0.79885113, accuracy: 78.89%
# Validation loss: 1.08796501, accuracy: 70.92%
#       Best loss: 1.08772647 at epoch 142
#    Elapsed time: 02:21:47
#       Timestamp: 2017/11/24 15:37:04
# -------------- EPOCH  151/500 --------------
#      Train loss: 0.79425508, accuracy: 78.88%
# Validation loss: 1.08754790, accuracy: 70.96%
#       Best loss: 1.08772647 at epoch 142
#    Elapsed time: 02:22:44
#       Timestamp: 2017/11/24 15:38:00
# -------------- EPOCH  152/500 --------------
#      Train loss: 0.79703975, accuracy: 78.85%
# Validation loss: 1.09413326, accuracy: 70.75%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:23:39
#       Timestamp: 2017/11/24 15:38:56
# -------------- EPOCH  153/500 --------------
#      Train loss: 0.79922426, accuracy: 78.83%
# Validation loss: 1.09365010, accuracy: 71.04%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:24:34
#       Timestamp: 2017/11/24 15:39:50
# -------------- EPOCH  154/500 --------------
#      Train loss: 0.80316913, accuracy: 78.74%
# Validation loss: 1.09768641, accuracy: 70.71%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:25:31
#       Timestamp: 2017/11/24 15:40:48
# -------------- EPOCH  155/500 --------------
#      Train loss: 0.80430466, accuracy: 78.69%
# Validation loss: 1.10427177, accuracy: 70.73%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:26:26
#       Timestamp: 2017/11/24 15:41:43
# -------------- EPOCH  156/500 --------------
#      Train loss: 0.79141736, accuracy: 78.95%
# Validation loss: 1.09242940, accuracy: 70.97%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:27:20
#       Timestamp: 2017/11/24 15:42:37
# -------------- EPOCH  157/500 --------------
#      Train loss: 0.78920650, accuracy: 78.96%
# Validation loss: 1.10101807, accuracy: 70.87%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:28:17
#       Timestamp: 2017/11/24 15:43:34
# -------------- EPOCH  158/500 --------------
#      Train loss: 0.81081861, accuracy: 78.58%
# Validation loss: 1.10177839, accuracy: 70.74%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:29:13
#       Timestamp: 2017/11/24 15:44:30
# -------------- EPOCH  159/500 --------------
#      Train loss: 0.80949110, accuracy: 78.58%
# Validation loss: 1.10742342, accuracy: 70.44%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:30:09
#       Timestamp: 2017/11/24 15:45:26
# -------------- EPOCH  160/500 --------------
#      Train loss: 0.79957312, accuracy: 78.85%
# Validation loss: 1.09688509, accuracy: 70.75%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:31:06
#       Timestamp: 2017/11/24 15:46:22
# -------------- EPOCH  161/500 --------------
#      Train loss: 0.79951489, accuracy: 78.88%
# Validation loss: 1.09360075, accuracy: 70.87%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:32:01
#       Timestamp: 2017/11/24 15:47:17
# -------------- EPOCH  162/500 --------------
#      Train loss: 0.79495269, accuracy: 78.90%
# Validation loss: 1.09515119, accuracy: 70.85%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:32:56
#       Timestamp: 2017/11/24 15:48:12
# -------------- EPOCH  163/500 --------------
#      Train loss: 0.78829217, accuracy: 78.96%
# Validation loss: 1.09122646, accuracy: 71.00%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:33:52
#       Timestamp: 2017/11/24 15:49:09
# -------------- EPOCH  164/500 --------------
#      Train loss: 0.79211569, accuracy: 78.99%
# Validation loss: 1.09171069, accuracy: 70.88%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:34:47
#       Timestamp: 2017/11/24 15:50:04
# -------------- EPOCH  165/500 --------------
#      Train loss: 0.79050571, accuracy: 78.93%
# Validation loss: 1.08831918, accuracy: 70.88%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:35:45
#       Timestamp: 2017/11/24 15:51:01
# -------------- EPOCH  166/500 --------------
#      Train loss: 0.79029411, accuracy: 79.06%
# Validation loss: 1.08785713, accuracy: 71.01%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:36:39
#       Timestamp: 2017/11/24 15:51:56
# -------------- EPOCH  167/500 --------------
#      Train loss: 0.78879929, accuracy: 79.09%
# Validation loss: 1.09465301, accuracy: 71.00%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:37:34
#       Timestamp: 2017/11/24 15:52:51
# -------------- EPOCH  168/500 --------------
#      Train loss: 0.79007953, accuracy: 78.95%
# Validation loss: 1.09329104, accuracy: 70.86%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:38:30
#       Timestamp: 2017/11/24 15:53:47
# -------------- EPOCH  169/500 --------------
#      Train loss: 0.79087287, accuracy: 79.05%
# Validation loss: 1.09095168, accuracy: 71.22%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:39:25
#       Timestamp: 2017/11/24 15:54:42
# -------------- EPOCH  170/500 --------------
#      Train loss: 0.79079878, accuracy: 79.03%
# Validation loss: 1.09131753, accuracy: 70.96%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:40:20
#       Timestamp: 2017/11/24 15:55:36
# -------------- EPOCH  171/500 --------------
#      Train loss: 0.78618598, accuracy: 79.17%
# Validation loss: 1.08689058, accuracy: 70.96%
#       Best loss: 1.08754790 at epoch 151
#    Elapsed time: 02:41:16
#       Timestamp: 2017/11/24 15:56:32
# -------------- EPOCH  172/500 --------------
#      Train loss: 0.78388327, accuracy: 79.16%
# Validation loss: 1.09182990, accuracy: 70.92%
#       Best loss: 1.08689058 at epoch 171
#    Elapsed time: 02:42:12
#       Timestamp: 2017/11/24 15:57:28
# -------------- EPOCH  173/500 --------------
#      Train loss: 0.78605765, accuracy: 79.21%
# Validation loss: 1.09006345, accuracy: 71.01%
#       Best loss: 1.08689058 at epoch 171
#    Elapsed time: 02:43:10
#       Timestamp: 2017/11/24 15:58:26
# -------------- EPOCH  174/500 --------------
#      Train loss: 0.79300529, accuracy: 78.93%
# Validation loss: 1.10123575, accuracy: 70.90%
#       Best loss: 1.08689058 at epoch 171
#    Elapsed time: 02:44:05
#       Timestamp: 2017/11/24 15:59:22
# -------------- EPOCH  175/500 --------------
#      Train loss: 0.78554231, accuracy: 79.19%
# Validation loss: 1.08953774, accuracy: 71.03%
#       Best loss: 1.08689058 at epoch 171
#    Elapsed time: 02:45:01
#       Timestamp: 2017/11/24 16:00:17
# -------------- EPOCH  176/500 --------------
#      Train loss: 0.78230059, accuracy: 79.16%
# Validation loss: 1.08545864, accuracy: 71.01%
#       Best loss: 1.08689058 at epoch 171
#    Elapsed time: 02:45:56
#       Timestamp: 2017/11/24 16:01:13
# -------------- EPOCH  177/500 --------------
#      Train loss: 0.79132199, accuracy: 79.11%
# Validation loss: 1.08672297, accuracy: 71.23%
#       Best loss: 1.08545864 at epoch 176
#    Elapsed time: 02:46:52
#       Timestamp: 2017/11/24 16:02:09
# -------------- EPOCH  178/500 --------------
#      Train loss: 0.78345251, accuracy: 79.06%
# Validation loss: 1.09913290, accuracy: 71.09%
#       Best loss: 1.08545864 at epoch 176
#    Elapsed time: 02:47:46
#       Timestamp: 2017/11/24 16:03:03
# -------------- EPOCH  179/500 --------------
#      Train loss: 0.78337890, accuracy: 79.19%
# Validation loss: 1.08750796, accuracy: 71.16%
#       Best loss: 1.08545864 at epoch 176
#    Elapsed time: 02:48:43
#       Timestamp: 2017/11/24 16:03:59
# -------------- EPOCH  180/500 --------------
#      Train loss: 0.78356254, accuracy: 79.27%
# Validation loss: 1.08223426, accuracy: 71.24%
#       Best loss: 1.08545864 at epoch 176
#    Elapsed time: 02:49:37
#       Timestamp: 2017/11/24 16:04:54
# -------------- EPOCH  181/500 --------------
#      Train loss: 0.78053463, accuracy: 79.15%
# Validation loss: 1.08629394, accuracy: 71.08%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 02:50:33
#       Timestamp: 2017/11/24 16:05:49
# -------------- EPOCH  182/500 --------------
#      Train loss: 0.78203970, accuracy: 79.25%
# Validation loss: 1.09169972, accuracy: 71.13%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 02:51:29
#       Timestamp: 2017/11/24 16:06:45
# -------------- EPOCH  183/500 --------------
#      Train loss: 0.78393871, accuracy: 79.14%
# Validation loss: 1.08886433, accuracy: 71.17%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 02:52:24
#       Timestamp: 2017/11/24 16:07:40
# -------------- EPOCH  184/500 --------------
#      Train loss: 0.77976024, accuracy: 79.19%
# Validation loss: 1.08674455, accuracy: 71.40%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 02:53:19
#       Timestamp: 2017/11/24 16:08:35
# -------------- EPOCH  185/500 --------------
#      Train loss: 0.78334874, accuracy: 79.19%
# Validation loss: 1.08641613, accuracy: 71.29%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 02:54:15
#       Timestamp: 2017/11/24 16:09:32
# -------------- EPOCH  186/500 --------------
#      Train loss: 0.77834737, accuracy: 79.26%
# Validation loss: 1.09610975, accuracy: 71.04%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 02:55:14
#       Timestamp: 2017/11/24 16:10:31
# -------------- EPOCH  187/500 --------------
#      Train loss: 0.79194969, accuracy: 78.99%
# Validation loss: 1.10169673, accuracy: 70.83%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 02:56:12
#       Timestamp: 2017/11/24 16:11:29
# -------------- EPOCH  188/500 --------------
#      Train loss: 0.78220350, accuracy: 79.16%
# Validation loss: 1.09172702, accuracy: 71.02%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 02:57:08
#       Timestamp: 2017/11/24 16:12:25
# -------------- EPOCH  189/500 --------------
#      Train loss: 0.78795666, accuracy: 79.13%
# Validation loss: 1.08581018, accuracy: 71.27%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 02:58:05
#       Timestamp: 2017/11/24 16:13:22
# -------------- EPOCH  190/500 --------------
#      Train loss: 0.77877164, accuracy: 79.27%
# Validation loss: 1.09170127, accuracy: 71.23%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 02:59:00
#       Timestamp: 2017/11/24 16:14:16
# -------------- EPOCH  191/500 --------------
#      Train loss: 0.77862751, accuracy: 79.25%
# Validation loss: 1.08274722, accuracy: 71.39%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 02:59:56
#       Timestamp: 2017/11/24 16:15:13
# -------------- EPOCH  192/500 --------------
#      Train loss: 0.78209209, accuracy: 79.21%
# Validation loss: 1.09061861, accuracy: 71.32%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:00:51
#       Timestamp: 2017/11/24 16:16:08
# -------------- EPOCH  193/500 --------------
#      Train loss: 0.77902806, accuracy: 79.21%
# Validation loss: 1.09536982, accuracy: 71.10%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:01:46
#       Timestamp: 2017/11/24 16:17:03
# -------------- EPOCH  194/500 --------------
#      Train loss: 0.81485331, accuracy: 78.64%
# Validation loss: 1.10836780, accuracy: 70.58%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:02:41
#       Timestamp: 2017/11/24 16:17:58
# -------------- EPOCH  195/500 --------------
#      Train loss: 0.77943903, accuracy: 79.33%
# Validation loss: 1.08702123, accuracy: 71.34%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:03:36
#       Timestamp: 2017/11/24 16:18:52
# -------------- EPOCH  196/500 --------------
#      Train loss: 0.77675319, accuracy: 79.36%
# Validation loss: 1.08687210, accuracy: 71.22%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:04:31
#       Timestamp: 2017/11/24 16:19:48
# -------------- EPOCH  197/500 --------------
#      Train loss: 0.77788103, accuracy: 79.34%
# Validation loss: 1.08769858, accuracy: 71.08%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:05:28
#       Timestamp: 2017/11/24 16:20:45
# -------------- EPOCH  198/500 --------------
#      Train loss: 0.77419925, accuracy: 79.37%
# Validation loss: 1.08725226, accuracy: 71.25%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:06:23
#       Timestamp: 2017/11/24 16:21:39
# -------------- EPOCH  199/500 --------------
#      Train loss: 0.77735603, accuracy: 79.31%
# Validation loss: 1.09037805, accuracy: 71.24%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:07:17
#       Timestamp: 2017/11/24 16:22:33
# -------------- EPOCH  200/500 --------------
#      Train loss: 0.77556759, accuracy: 79.42%
# Validation loss: 1.08817971, accuracy: 71.09%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:08:11
#       Timestamp: 2017/11/24 16:23:28
# -------------- EPOCH  201/500 --------------
#      Train loss: 0.77401072, accuracy: 79.34%
# Validation loss: 1.09312022, accuracy: 71.15%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:09:06
#       Timestamp: 2017/11/24 16:24:23
# -------------- EPOCH  202/500 --------------
#      Train loss: 0.77942461, accuracy: 79.37%
# Validation loss: 1.08399069, accuracy: 71.11%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:10:00
#       Timestamp: 2017/11/24 16:25:17
# -------------- EPOCH  203/500 --------------
#      Train loss: 0.77563119, accuracy: 79.45%
# Validation loss: 1.08767068, accuracy: 71.26%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:10:55
#       Timestamp: 2017/11/24 16:26:12
# -------------- EPOCH  204/500 --------------
#      Train loss: 0.77647018, accuracy: 79.34%
# Validation loss: 1.09532869, accuracy: 71.15%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:11:50
#       Timestamp: 2017/11/24 16:27:07
# -------------- EPOCH  205/500 --------------
#      Train loss: 0.77602732, accuracy: 79.31%
# Validation loss: 1.09545493, accuracy: 71.13%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:12:45
#       Timestamp: 2017/11/24 16:28:02
# -------------- EPOCH  206/500 --------------
#      Train loss: 0.77395958, accuracy: 79.44%
# Validation loss: 1.08612752, accuracy: 71.31%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:13:43
#       Timestamp: 2017/11/24 16:28:59
# -------------- EPOCH  207/500 --------------
#      Train loss: 0.77406585, accuracy: 79.39%
# Validation loss: 1.09608841, accuracy: 71.16%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:14:37
#       Timestamp: 2017/11/24 16:29:54
# -------------- EPOCH  208/500 --------------
#      Train loss: 0.77971697, accuracy: 79.37%
# Validation loss: 1.09251690, accuracy: 71.13%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:15:32
#       Timestamp: 2017/11/24 16:30:48
# -------------- EPOCH  209/500 --------------
#      Train loss: 0.77357829, accuracy: 79.37%
# Validation loss: 1.09213483, accuracy: 71.31%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:16:27
#       Timestamp: 2017/11/24 16:31:44
# -------------- EPOCH  210/500 --------------
#      Train loss: 0.77598566, accuracy: 79.50%
# Validation loss: 1.08991313, accuracy: 71.17%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:17:23
#       Timestamp: 2017/11/24 16:32:39
# -------------- EPOCH  211/500 --------------
#      Train loss: 0.77110416, accuracy: 79.45%
# Validation loss: 1.09028387, accuracy: 71.43%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:18:18
#       Timestamp: 2017/11/24 16:33:35
# -------------- EPOCH  212/500 --------------
#      Train loss: 0.77373815, accuracy: 79.48%
# Validation loss: 1.09615982, accuracy: 71.05%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:19:12
#       Timestamp: 2017/11/24 16:34:29
# -------------- EPOCH  213/500 --------------
#      Train loss: 0.76824147, accuracy: 79.52%
# Validation loss: 1.08985305, accuracy: 71.24%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:20:07
#       Timestamp: 2017/11/24 16:35:24
# -------------- EPOCH  214/500 --------------
#      Train loss: 0.77580351, accuracy: 79.38%
# Validation loss: 1.09189630, accuracy: 71.26%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:21:03
#       Timestamp: 2017/11/24 16:36:20
# -------------- EPOCH  215/500 --------------
#      Train loss: 0.77691120, accuracy: 79.35%
# Validation loss: 1.08557999, accuracy: 71.29%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:21:58
#       Timestamp: 2017/11/24 16:37:15
# -------------- EPOCH  216/500 --------------
#      Train loss: 0.77002454, accuracy: 79.44%
# Validation loss: 1.08812869, accuracy: 71.10%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:22:53
#       Timestamp: 2017/11/24 16:38:10
# -------------- EPOCH  217/500 --------------
#      Train loss: 0.77195841, accuracy: 79.50%
# Validation loss: 1.09500504, accuracy: 71.18%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:23:48
#       Timestamp: 2017/11/24 16:39:05
# -------------- EPOCH  218/500 --------------
#      Train loss: 0.77440935, accuracy: 79.46%
# Validation loss: 1.08741081, accuracy: 71.15%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:24:42
#       Timestamp: 2017/11/24 16:39:59
# -------------- EPOCH  219/500 --------------
#      Train loss: 0.76706207, accuracy: 79.51%
# Validation loss: 1.08891678, accuracy: 71.26%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:25:37
#       Timestamp: 2017/11/24 16:40:54
# -------------- EPOCH  220/500 --------------
#      Train loss: 0.77293056, accuracy: 79.41%
# Validation loss: 1.09561932, accuracy: 71.43%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:26:31
#       Timestamp: 2017/11/24 16:41:48
# -------------- EPOCH  221/500 --------------
#      Train loss: 0.78591800, accuracy: 79.09%
# Validation loss: 1.11042047, accuracy: 70.93%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:27:27
#       Timestamp: 2017/11/24 16:42:43
# -------------- EPOCH  222/500 --------------
#      Train loss: 0.77412248, accuracy: 79.44%
# Validation loss: 1.09758675, accuracy: 70.90%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:28:21
#       Timestamp: 2017/11/24 16:43:38
# -------------- EPOCH  223/500 --------------
#      Train loss: 0.77000982, accuracy: 79.54%
# Validation loss: 1.09074366, accuracy: 71.39%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:29:16
#       Timestamp: 2017/11/24 16:44:32
# -------------- EPOCH  224/500 --------------
#      Train loss: 0.76941574, accuracy: 79.45%
# Validation loss: 1.09634340, accuracy: 71.05%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:30:12
#       Timestamp: 2017/11/24 16:45:28
# -------------- EPOCH  225/500 --------------
#      Train loss: 0.77081406, accuracy: 79.47%
# Validation loss: 1.09009397, accuracy: 71.36%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:31:07
#       Timestamp: 2017/11/24 16:46:24
# -------------- EPOCH  226/500 --------------
#      Train loss: 0.77028203, accuracy: 79.51%
# Validation loss: 1.09516370, accuracy: 71.28%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:32:03
#       Timestamp: 2017/11/24 16:47:19
# -------------- EPOCH  227/500 --------------
#      Train loss: 1.07258475, accuracy: 75.01%
# Validation loss: 1.35665596, accuracy: 68.08%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:33:00
#       Timestamp: 2017/11/24 16:48:16
# -------------- EPOCH  228/500 --------------
#      Train loss: 0.77677494, accuracy: 79.40%
# Validation loss: 1.09475720, accuracy: 71.13%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:33:55
#       Timestamp: 2017/11/24 16:49:11
# -------------- EPOCH  229/500 --------------
#      Train loss: 0.77260077, accuracy: 79.52%
# Validation loss: 1.08780062, accuracy: 71.27%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:34:49
#       Timestamp: 2017/11/24 16:50:05
# -------------- EPOCH  230/500 --------------
#      Train loss: 0.77962738, accuracy: 79.33%
# Validation loss: 1.09985077, accuracy: 71.02%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:35:44
#       Timestamp: 2017/11/24 16:51:01
# -------------- EPOCH  231/500 --------------
#      Train loss: 0.77073771, accuracy: 79.55%
# Validation loss: 1.08491957, accuracy: 71.33%
#       Best loss: 1.08223426 at epoch 180
#    Elapsed time: 03:36:39
#       Timestamp: 2017/11/24 16:51:55
# INFO:tensorflow:Restoring parameters from /home/wastaljoey/TSC1/early_stopping_checkpoint
# Early stopping.
# Best monitored loss was 1.08223426 at epoch 180.
# =============================================
#  Valid loss: 1.08223426, accuracy = 71.24%)
#  Test loss: 94.94815826, accuracy = 18.46%)
#  Total time: 03:36:47
#   Timestamp: 2017/11/24 16:52:03
# Model file: /home/wastaljoey/TSC1/models/4layers_k7d16p0.9_k7d32p0.8_k5d64p0.7_fc1024p0.5_no-lrdec_l2_advtrain/model.ckpt
# Train history file: /home/wastaljoey/TSC1/models/4layers_k7d16p0.9_k7d32p0.8_k5d64p0.7_fc1024p0.5_no-lrdec_l2_advtrain/train_history

# %%
import pickle
from sklearn.model_selection import train_test_split

#train_extended_preprocessed_dataset_file = "data/train_extended_preprocessed.p"
train_balanced_preprocessed_dataset_file = "data/train_processed.p"
test_preprocessed_dataset_file = "data/test_processed.p"


parameters = Parameters(
    # Data parameters
    num_classes = 43,
    image_size = (32, 32),
    # Training parameters
    batch_size = 256,
    max_epochs = 500,
    log_epoch = 1,
    print_epoch = 1,
    # Optimisations
    learning_rate_decay = False,
    learning_rate = 0.001,
    l2_reg_enabled = True,
    l2_lambda = 0.0001,
    early_stopping_enabled = True,
    early_stopping_patience = 50,
    resume_training = True,
    # Layers architecture
    conv1_k = 7, conv1_d = 16, conv1_p = 0.9,
    conv2_k = 7, conv2_d = 32, conv2_p = 0.8,
    conv3_k = 5, conv3_d = 64, conv3_p = 0.7,
    conv4_k = 3, conv4_d = 128, conv4_p = 0.6,
    fc4_size = 1024, fc4_p = 0.5,
    adv_training=None,
    perturbed_ratio= None
    
)

X_train, y_train = load_pickled_data(train_balanced_preprocessed_dataset_file, columns = ['features', 'labels'])
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.25)
X_test, y_test = load_pickled_data(test_preprocessed_dataset_file, columns = ['features', 'labels'])
train_model(parameters, X_train, y_train, X_valid, y_valid, X_test, y_test)
# Out:
# =============================================
# ============= RESUMING TRAINING =============
# =============================================
# =================== DATA ====================
#             Training set: 37132 examples
#           Validation set: 12378 examples
#              Testing set: 12630 examples
#               Batch size: 256
# =================== MODEL ===================
# --------------- ARCHITECTURE ----------------
#             Type       Size     Dropout (keep p)
#  Layer 1    7x7 Conv   16       0.9
#  Layer 2    7x7 Conv   32       0.8
#  Layer 3    5x5 Conv   64       0.7
#  Layer 4    FC         1024     0.5
# ---------------- PARAMETERS -----------------
#      Learning rate decay: Disabled (rate = 0.001)
#        L2 Regularization: Enabled (lambda = 0.0001)
#           Early stopping: Enabled (patience = 50)
#  Keep training old model: Enabled
# INFO:tensorflow:Restoring parameters from /home/wastaljoey/TSC1/models/4layers_k7d16p0.9_k7d32p0.8_k5d64p0.7_fc1024p0.5_no-lrdec_l2/model.ckpt
# Failed restoring previously trained model: file does not exist.
# ================= TRAINING ==================
#  Timestamp: 2017/11/24 16:52:10
# -------------- EPOCH    0/500 --------------
#      Train loss: 2.04135227, accuracy: 42.60%
# Validation loss: 2.06372619, accuracy: 42.20%
#       Best loss: inf at epoch 0
#    Elapsed time: 00:00:55
#       Timestamp: 2017/11/24 16:53:05
# -------------- EPOCH    1/500 --------------
#      Train loss: 0.66525358, accuracy: 82.27%
# Validation loss: 0.68636775, accuracy: 81.81%
#       Best loss: 2.06372619 at epoch 0
#    Elapsed time: 00:01:53
#       Timestamp: 2017/11/24 16:54:02
# -------------- EPOCH    2/500 --------------
#      Train loss: 0.37266785, accuracy: 90.57%
# Validation loss: 0.39211446, accuracy: 89.71%
#       Best loss: 0.68636775 at epoch 1
#    Elapsed time: 00:02:47
#       Timestamp: 2017/11/24 16:54:57
# -------------- EPOCH    3/500 --------------
#      Train loss: 0.23138013, accuracy: 93.72%
# Validation loss: 0.25199100, accuracy: 92.83%
#       Best loss: 0.39211446 at epoch 2
#    Elapsed time: 00:03:41
#       Timestamp: 2017/11/24 16:55:51
# -------------- EPOCH    4/500 --------------
#      Train loss: 0.15943035, accuracy: 96.64%
# Validation loss: 0.17976063, accuracy: 95.71%
#       Best loss: 0.25199100 at epoch 3
#    Elapsed time: 00:04:35
#       Timestamp: 2017/11/24 16:56:45
# -------------- EPOCH    5/500 --------------
#      Train loss: 0.09471371, accuracy: 97.94%
# Validation loss: 0.11425812, accuracy: 97.36%
#       Best loss: 0.17976063 at epoch 4
#    Elapsed time: 00:05:30
#       Timestamp: 2017/11/24 16:57:39
# -------------- EPOCH    6/500 --------------
#      Train loss: 0.06020821, accuracy: 98.83%
# Validation loss: 0.08184111, accuracy: 98.11%
#       Best loss: 0.11425812 at epoch 5
#    Elapsed time: 00:06:25
#       Timestamp: 2017/11/24 16:58:35
# -------------- EPOCH    7/500 --------------
#      Train loss: 0.06176820, accuracy: 98.66%
# Validation loss: 0.08202989, accuracy: 98.04%
#       Best loss: 0.08184111 at epoch 6
#    Elapsed time: 00:07:20
#       Timestamp: 2017/11/24 16:59:29
# -------------- EPOCH    8/500 --------------
#      Train loss: 0.09320088, accuracy: 97.74%
# Validation loss: 0.11480493, accuracy: 97.01%
#       Best loss: 0.08184111 at epoch 6
#    Elapsed time: 00:08:15
#       Timestamp: 2017/11/24 17:00:24
# -------------- EPOCH    9/500 --------------
#      Train loss: 0.03848290, accuracy: 99.27%
# Validation loss: 0.05726705, accuracy: 98.66%
#       Best loss: 0.08184111 at epoch 6
#    Elapsed time: 00:09:11
#       Timestamp: 2017/11/24 17:01:21
# -------------- EPOCH   10/500 --------------
#      Train loss: 0.03138443, accuracy: 99.37%
# Validation loss: 0.04868479, accuracy: 98.81%
#       Best loss: 0.05726705 at epoch 9
#    Elapsed time: 00:10:07
#       Timestamp: 2017/11/24 17:02:16
# -------------- EPOCH   11/500 --------------
#      Train loss: 0.02010482, accuracy: 99.64%
# Validation loss: 0.03770308, accuracy: 99.06%
#       Best loss: 0.04868479 at epoch 10
#    Elapsed time: 00:11:01
#       Timestamp: 2017/11/24 17:03:10
# -------------- EPOCH   12/500 --------------
#      Train loss: 0.02428043, accuracy: 99.56%
# Validation loss: 0.04049084, accuracy: 99.09%
#       Best loss: 0.03770308 at epoch 11
#    Elapsed time: 00:11:56
#       Timestamp: 2017/11/24 17:04:05
# -------------- EPOCH   13/500 --------------
#      Train loss: 0.02344101, accuracy: 99.56%
# Validation loss: 0.04173446, accuracy: 99.00%
#       Best loss: 0.03770308 at epoch 11
#    Elapsed time: 00:12:49
#       Timestamp: 2017/11/24 17:04:59
# -------------- EPOCH   14/500 --------------
#      Train loss: 0.01841833, accuracy: 99.66%
# Validation loss: 0.03740045, accuracy: 99.04%
#       Best loss: 0.03770308 at epoch 11
#    Elapsed time: 00:13:43
#       Timestamp: 2017/11/24 17:05:53
# -------------- EPOCH   15/500 --------------
#      Train loss: 0.03087425, accuracy: 99.13%
# Validation loss: 0.04707835, accuracy: 98.70%
#       Best loss: 0.03740045 at epoch 14
#    Elapsed time: 00:14:38
#       Timestamp: 2017/11/24 17:06:47
# -------------- EPOCH   16/500 --------------
#      Train loss: 0.05731179, accuracy: 98.19%
# Validation loss: 0.08136091, accuracy: 97.44%
#       Best loss: 0.03740045 at epoch 14
#    Elapsed time: 00:15:33
#       Timestamp: 2017/11/24 17:07:42
# -------------- EPOCH   17/500 --------------
#      Train loss: 0.01290577, accuracy: 99.82%
# Validation loss: 0.02754418, accuracy: 99.37%
#       Best loss: 0.03740045 at epoch 14
#    Elapsed time: 00:16:27
#       Timestamp: 2017/11/24 17:08:37
# -------------- EPOCH   18/500 --------------
#      Train loss: 0.02667996, accuracy: 99.29%
# Validation loss: 0.04620193, accuracy: 98.72%
#       Best loss: 0.02754418 at epoch 17
#    Elapsed time: 00:17:22
#       Timestamp: 2017/11/24 17:09:31
# -------------- EPOCH   19/500 --------------
#      Train loss: 0.00932054, accuracy: 99.84%
# Validation loss: 0.02311043, accuracy: 99.44%
#       Best loss: 0.02754418 at epoch 17
#    Elapsed time: 00:18:16
#       Timestamp: 2017/11/24 17:10:25
# -------------- EPOCH   20/500 --------------
#      Train loss: 0.00888916, accuracy: 99.85%
# Validation loss: 0.02506135, accuracy: 99.39%
#       Best loss: 0.02311043 at epoch 19
#    Elapsed time: 00:19:11
#       Timestamp: 2017/11/24 17:11:20
# -------------- EPOCH   21/500 --------------
#      Train loss: 0.00868838, accuracy: 99.84%
# Validation loss: 0.02378409, accuracy: 99.44%
#       Best loss: 0.02311043 at epoch 19
#    Elapsed time: 00:20:05
#       Timestamp: 2017/11/24 17:12:15
# -------------- EPOCH   22/500 --------------
#      Train loss: 0.00650574, accuracy: 99.92%
# Validation loss: 0.02141452, accuracy: 99.51%
#       Best loss: 0.02311043 at epoch 19
#    Elapsed time: 00:21:01
#       Timestamp: 2017/11/24 17:13:10
# -------------- EPOCH   23/500 --------------
#      Train loss: 0.00874546, accuracy: 99.85%
# Validation loss: 0.02540732, accuracy: 99.30%
#       Best loss: 0.02141452 at epoch 22
#    Elapsed time: 00:21:55
#       Timestamp: 2017/11/24 17:14:05
# -------------- EPOCH   24/500 --------------
#      Train loss: 0.00920024, accuracy: 99.80%
# Validation loss: 0.02463758, accuracy: 99.28%
#       Best loss: 0.02141452 at epoch 22
#    Elapsed time: 00:22:50
#       Timestamp: 2017/11/24 17:15:00
# -------------- EPOCH   25/500 --------------
#      Train loss: 0.00681511, accuracy: 99.89%
# Validation loss: 0.02208929, accuracy: 99.40%
#       Best loss: 0.02141452 at epoch 22
#    Elapsed time: 00:23:45
#       Timestamp: 2017/11/24 17:15:55
# -------------- EPOCH   26/500 --------------
#      Train loss: 0.01033137, accuracy: 99.81%
# Validation loss: 0.02561517, accuracy: 99.39%
#       Best loss: 0.02141452 at epoch 22
#    Elapsed time: 00:24:39
#       Timestamp: 2017/11/24 17:16:49
# -------------- EPOCH   27/500 --------------
#      Train loss: 0.00631599, accuracy: 99.89%
# Validation loss: 0.01912174, accuracy: 99.50%
#       Best loss: 0.02141452 at epoch 22
#    Elapsed time: 00:25:34
#       Timestamp: 2017/11/24 17:17:43
# -------------- EPOCH   28/500 --------------
#      Train loss: 0.00774175, accuracy: 99.85%
# Validation loss: 0.02138430, accuracy: 99.38%
#       Best loss: 0.01912174 at epoch 27
#    Elapsed time: 00:26:28
#       Timestamp: 2017/11/24 17:18:38
# -------------- EPOCH   29/500 --------------
#      Train loss: 0.00474831, accuracy: 99.92%
# Validation loss: 0.02038923, accuracy: 99.43%
#       Best loss: 0.01912174 at epoch 27
#    Elapsed time: 00:27:22
#       Timestamp: 2017/11/24 17:19:32
# -------------- EPOCH   30/500 --------------
#      Train loss: 0.00606739, accuracy: 99.87%
# Validation loss: 0.01964458, accuracy: 99.46%
#       Best loss: 0.01912174 at epoch 27
#    Elapsed time: 00:28:18
#       Timestamp: 2017/11/24 17:20:28
# -------------- EPOCH   31/500 --------------
#      Train loss: 0.00496674, accuracy: 99.92%
# Validation loss: 0.01957502, accuracy: 99.43%
#       Best loss: 0.01912174 at epoch 27
#    Elapsed time: 00:29:13
#       Timestamp: 2017/11/24 17:21:23
# -------------- EPOCH   32/500 --------------
#      Train loss: 0.00745723, accuracy: 99.79%
# Validation loss: 0.02189019, accuracy: 99.40%
#       Best loss: 0.01912174 at epoch 27
#    Elapsed time: 00:30:08
#       Timestamp: 2017/11/24 17:22:17
# -------------- EPOCH   33/500 --------------
#      Train loss: 0.00653982, accuracy: 99.89%
# Validation loss: 0.02007077, accuracy: 99.45%
#       Best loss: 0.01912174 at epoch 27
#    Elapsed time: 00:31:03
#       Timestamp: 2017/11/24 17:23:12
# -------------- EPOCH   34/500 --------------
#      Train loss: 0.00366609, accuracy: 99.95%
# Validation loss: 0.01730472, accuracy: 99.55%
#       Best loss: 0.01912174 at epoch 27
#    Elapsed time: 00:31:59
#       Timestamp: 2017/11/24 17:24:08
# -------------- EPOCH   35/500 --------------
#      Train loss: 0.00452978, accuracy: 99.92%
# Validation loss: 0.01913627, accuracy: 99.48%
#       Best loss: 0.01730472 at epoch 34
#    Elapsed time: 00:32:54
#       Timestamp: 2017/11/24 17:25:03
# -------------- EPOCH   36/500 --------------
#      Train loss: 0.00601387, accuracy: 99.87%
# Validation loss: 0.02133488, accuracy: 99.39%
#       Best loss: 0.01730472 at epoch 34
#    Elapsed time: 00:33:49
#       Timestamp: 2017/11/24 17:25:58
# -------------- EPOCH   37/500 --------------
#      Train loss: 0.00444093, accuracy: 99.89%
# Validation loss: 0.01819037, accuracy: 99.48%
#       Best loss: 0.01730472 at epoch 34
#    Elapsed time: 00:34:45
#       Timestamp: 2017/11/24 17:26:54
# -------------- EPOCH   38/500 --------------
#      Train loss: 0.00785762, accuracy: 99.84%
# Validation loss: 0.02660542, accuracy: 99.30%
#       Best loss: 0.01730472 at epoch 34
#    Elapsed time: 00:35:41
#       Timestamp: 2017/11/24 17:27:51
# -------------- EPOCH   39/500 --------------
#      Train loss: 0.00270775, accuracy: 99.95%
# Validation loss: 0.01511241, accuracy: 99.55%
#       Best loss: 0.01730472 at epoch 34
#    Elapsed time: 00:36:38
#       Timestamp: 2017/11/24 17:28:48
# -------------- EPOCH   40/500 --------------
#      Train loss: 0.00364181, accuracy: 99.93%
# Validation loss: 0.01883858, accuracy: 99.46%
#       Best loss: 0.01511241 at epoch 39
#    Elapsed time: 00:37:34
#       Timestamp: 2017/11/24 17:29:43
# -------------- EPOCH   41/500 --------------
#      Train loss: 0.01338598, accuracy: 99.74%
# Validation loss: 0.02718806, accuracy: 99.35%
#       Best loss: 0.01511241 at epoch 39
#    Elapsed time: 00:38:30
#       Timestamp: 2017/11/24 17:30:39
# -------------- EPOCH   42/500 --------------
#      Train loss: 0.00218136, accuracy: 99.96%
# Validation loss: 0.01404462, accuracy: 99.58%
#       Best loss: 0.01511241 at epoch 39
#    Elapsed time: 00:39:25
#       Timestamp: 2017/11/24 17:31:34
# -------------- EPOCH   43/500 --------------
#      Train loss: 0.04907300, accuracy: 98.57%
# Validation loss: 0.06427889, accuracy: 98.20%
#       Best loss: 0.01404462 at epoch 42
#    Elapsed time: 00:40:21
#       Timestamp: 2017/11/24 17:32:30
# -------------- EPOCH   44/500 --------------
#      Train loss: 0.00367831, accuracy: 99.92%
# Validation loss: 0.01868729, accuracy: 99.49%
#       Best loss: 0.01404462 at epoch 42
#    Elapsed time: 00:41:18
#       Timestamp: 2017/11/24 17:33:28
# -------------- EPOCH   45/500 --------------
#      Train loss: 0.00553105, accuracy: 99.86%
# Validation loss: 0.01931333, accuracy: 99.52%
#       Best loss: 0.01404462 at epoch 42
#    Elapsed time: 00:42:15
#       Timestamp: 2017/11/24 17:34:24
# -------------- EPOCH   46/500 --------------
#      Train loss: 0.00255480, accuracy: 99.96%
# Validation loss: 0.01636420, accuracy: 99.56%
#       Best loss: 0.01404462 at epoch 42
#    Elapsed time: 00:43:10
#       Timestamp: 2017/11/24 17:35:20
# -------------- EPOCH   47/500 --------------
#      Train loss: 0.04915765, accuracy: 98.61%
# Validation loss: 0.06878744, accuracy: 98.04%
#       Best loss: 0.01404462 at epoch 42
#    Elapsed time: 00:44:06
#       Timestamp: 2017/11/24 17:36:16
# -------------- EPOCH   48/500 --------------
#      Train loss: 0.00177355, accuracy: 99.97%
# Validation loss: 0.01424540, accuracy: 99.60%
#       Best loss: 0.01404462 at epoch 42
#    Elapsed time: 00:45:01
#       Timestamp: 2017/11/24 17:37:10
# -------------- EPOCH   49/500 --------------
#      Train loss: 0.01820137, accuracy: 99.50%
# Validation loss: 0.03415221, accuracy: 99.05%
#       Best loss: 0.01404462 at epoch 42
#    Elapsed time: 00:45:56
#       Timestamp: 2017/11/24 17:38:05
# -------------- EPOCH   50/500 --------------
#      Train loss: 0.00210107, accuracy: 99.96%
# Validation loss: 0.01219629, accuracy: 99.68%
#       Best loss: 0.01404462 at epoch 42
#    Elapsed time: 00:46:51
#       Timestamp: 2017/11/24 17:39:00
# -------------- EPOCH   51/500 --------------
#      Train loss: 0.00360582, accuracy: 99.91%
# Validation loss: 0.01617290, accuracy: 99.53%
#       Best loss: 0.01219629 at epoch 50
#    Elapsed time: 00:47:48
#       Timestamp: 2017/11/24 17:39:57
# -------------- EPOCH   52/500 --------------
#      Train loss: 0.00146617, accuracy: 99.98%
# Validation loss: 0.01441325, accuracy: 99.61%
#       Best loss: 0.01219629 at epoch 50
#    Elapsed time: 00:48:43
#       Timestamp: 2017/11/24 17:40:52
# -------------- EPOCH   53/500 --------------
#      Train loss: 0.00393268, accuracy: 99.89%
# Validation loss: 0.01880622, accuracy: 99.39%
#       Best loss: 0.01219629 at epoch 50
#    Elapsed time: 00:49:38
#       Timestamp: 2017/11/24 17:41:47
# -------------- EPOCH   54/500 --------------
#      Train loss: 0.00196711, accuracy: 99.97%
# Validation loss: 0.01482131, accuracy: 99.64%
#       Best loss: 0.01219629 at epoch 50
#    Elapsed time: 00:50:31
#       Timestamp: 2017/11/24 17:42:41
# -------------- EPOCH   55/500 --------------
#      Train loss: 0.08930414, accuracy: 97.42%
# Validation loss: 0.10847642, accuracy: 96.83%
#       Best loss: 0.01219629 at epoch 50
#    Elapsed time: 00:51:24
#       Timestamp: 2017/11/24 17:43:34
# -------------- EPOCH   56/500 --------------
#      Train loss: 0.00141312, accuracy: 99.99%
# Validation loss: 0.01423215, accuracy: 99.60%
#       Best loss: 0.01219629 at epoch 50
#    Elapsed time: 00:52:20
#       Timestamp: 2017/11/24 17:44:29
# -------------- EPOCH   57/500 --------------
#      Train loss: 0.00275922, accuracy: 99.95%
# Validation loss: 0.01674202, accuracy: 99.58%
#       Best loss: 0.01219629 at epoch 50
#    Elapsed time: 00:53:15
#       Timestamp: 2017/11/24 17:45:24
# -------------- EPOCH   58/500 --------------
#      Train loss: 0.00216268, accuracy: 99.94%
# Validation loss: 0.01375746, accuracy: 99.63%
#       Best loss: 0.01219629 at epoch 50
#    Elapsed time: 00:54:08
#       Timestamp: 2017/11/24 17:46:17
# -------------- EPOCH   59/500 --------------
#      Train loss: 0.00171569, accuracy: 99.95%
# Validation loss: 0.01292497, accuracy: 99.61%
#       Best loss: 0.01219629 at epoch 50
#    Elapsed time: 00:55:04
#       Timestamp: 2017/11/24 17:47:14
# -------------- EPOCH   60/500 --------------
#      Train loss: 0.00255900, accuracy: 99.94%
# Validation loss: 0.01400634, accuracy: 99.59%
#       Best loss: 0.01219629 at epoch 50
#    Elapsed time: 00:55:58
#       Timestamp: 2017/11/24 17:48:08
# -------------- EPOCH   61/500 --------------
#      Train loss: 0.00110657, accuracy: 99.99%
# Validation loss: 0.01320338, accuracy: 99.64%
#       Best loss: 0.01219629 at epoch 50
#    Elapsed time: 00:56:51
#       Timestamp: 2017/11/24 17:49:00
# -------------- EPOCH   62/500 --------------
#      Train loss: 0.00327354, accuracy: 99.96%
# Validation loss: 0.01731711, accuracy: 99.53%
#       Best loss: 0.01219629 at epoch 50
#    Elapsed time: 00:57:44
#       Timestamp: 2017/11/24 17:49:54
# -------------- EPOCH   63/500 --------------
#      Train loss: 0.00209732, accuracy: 99.95%
# Validation loss: 0.01541921, accuracy: 99.56%
#       Best loss: 0.01219629 at epoch 50
#    Elapsed time: 00:58:38
#       Timestamp: 2017/11/24 17:50:48
# -------------- EPOCH   64/500 --------------
#      Train loss: 0.00196669, accuracy: 99.97%
# Validation loss: 0.01215023, accuracy: 99.70%
#       Best loss: 0.01219629 at epoch 50
#    Elapsed time: 00:59:34
#       Timestamp: 2017/11/24 17:51:44
# -------------- EPOCH   65/500 --------------
#      Train loss: 0.01047163, accuracy: 99.81%
# Validation loss: 0.02271487, accuracy: 99.49%
#       Best loss: 0.01215023 at epoch 64
#    Elapsed time: 01:00:29
#       Timestamp: 2017/11/24 17:52:38
# -------------- EPOCH   66/500 --------------
#      Train loss: 0.00200410, accuracy: 99.96%
# Validation loss: 0.01309330, accuracy: 99.67%
#       Best loss: 0.01215023 at epoch 64
#    Elapsed time: 01:01:24
#       Timestamp: 2017/11/24 17:53:34
# -------------- EPOCH   67/500 --------------
#      Train loss: 0.00304744, accuracy: 99.94%
# Validation loss: 0.01550521, accuracy: 99.62%
#       Best loss: 0.01215023 at epoch 64
#    Elapsed time: 01:02:19
#       Timestamp: 2017/11/24 17:54:29
# -------------- EPOCH   68/500 --------------
#      Train loss: 0.00269337, accuracy: 99.95%
# Validation loss: 0.01742110, accuracy: 99.47%
#       Best loss: 0.01215023 at epoch 64
#    Elapsed time: 01:03:12
#       Timestamp: 2017/11/24 17:55:22
# -------------- EPOCH   69/500 --------------
#      Train loss: 0.00215590, accuracy: 99.98%
# Validation loss: 0.01472787, accuracy: 99.60%
#       Best loss: 0.01215023 at epoch 64
#    Elapsed time: 01:04:07
#       Timestamp: 2017/11/24 17:56:16
# -------------- EPOCH   70/500 --------------
#      Train loss: 0.00207921, accuracy: 99.98%
# Validation loss: 0.01400651, accuracy: 99.66%
#       Best loss: 0.01215023 at epoch 64
#    Elapsed time: 01:04:59
#       Timestamp: 2017/11/24 17:57:09
# -------------- EPOCH   71/500 --------------
#      Train loss: 0.00414760, accuracy: 99.92%
# Validation loss: 0.01698073, accuracy: 99.53%
#       Best loss: 0.01215023 at epoch 64
#    Elapsed time: 01:05:54
#       Timestamp: 2017/11/24 17:58:03
# -------------- EPOCH   72/500 --------------
#      Train loss: 0.00386309, accuracy: 99.91%
# Validation loss: 0.01480237, accuracy: 99.63%
#       Best loss: 0.01215023 at epoch 64
#    Elapsed time: 01:06:47
#       Timestamp: 2017/11/24 17:58:57
# -------------- EPOCH   73/500 --------------
#      Train loss: 0.00122546, accuracy: 99.98%
# Validation loss: 0.01302220, accuracy: 99.69%
#       Best loss: 0.01215023 at epoch 64
#    Elapsed time: 01:07:41
#       Timestamp: 2017/11/24 17:59:50
# -------------- EPOCH   74/500 --------------
#      Train loss: 0.03216146, accuracy: 99.32%
# Validation loss: 0.04646894, accuracy: 98.84%
#       Best loss: 0.01215023 at epoch 64
#    Elapsed time: 01:08:34
#       Timestamp: 2017/11/24 18:00:43
# -------------- EPOCH   75/500 --------------
#      Train loss: 0.00091987, accuracy: 99.99%
# Validation loss: 0.01080795, accuracy: 99.69%
#       Best loss: 0.01215023 at epoch 64
#    Elapsed time: 01:09:29
#       Timestamp: 2017/11/24 18:01:39
# -------------- EPOCH   76/500 --------------
#      Train loss: 0.00242656, accuracy: 99.95%
# Validation loss: 0.01611546, accuracy: 99.51%
#       Best loss: 0.01080795 at epoch 75
#    Elapsed time: 01:10:21
#       Timestamp: 2017/11/24 18:02:31
# -------------- EPOCH   77/500 --------------
#      Train loss: 0.00209391, accuracy: 99.95%
# Validation loss: 0.01190973, accuracy: 99.72%
#       Best loss: 0.01080795 at epoch 75
#    Elapsed time: 01:11:15
#       Timestamp: 2017/11/24 18:03:24
# -------------- EPOCH   78/500 --------------
#      Train loss: 0.00064995, accuracy: 99.99%
# Validation loss: 0.01082737, accuracy: 99.70%
#       Best loss: 0.01080795 at epoch 75
#    Elapsed time: 01:12:08
#       Timestamp: 2017/11/24 18:04:17
# -------------- EPOCH   79/500 --------------
#      Train loss: 0.00126782, accuracy: 99.98%
# Validation loss: 0.01109796, accuracy: 99.73%
#       Best loss: 0.01080795 at epoch 75
#    Elapsed time: 01:13:01
#       Timestamp: 2017/11/24 18:05:10
# -------------- EPOCH   80/500 --------------
#      Train loss: 0.00115532, accuracy: 99.98%
# Validation loss: 0.01182255, accuracy: 99.70%
#       Best loss: 0.01080795 at epoch 75
#    Elapsed time: 01:13:55
#       Timestamp: 2017/11/24 18:06:05
# -------------- EPOCH   81/500 --------------
#      Train loss: 0.00129539, accuracy: 99.97%
# Validation loss: 0.01092221, accuracy: 99.70%
#       Best loss: 0.01080795 at epoch 75
#    Elapsed time: 01:14:52
#       Timestamp: 2017/11/24 18:07:01
# -------------- EPOCH   82/500 --------------
#      Train loss: 0.00142009, accuracy: 99.97%
# Validation loss: 0.01199185, accuracy: 99.73%
#       Best loss: 0.01080795 at epoch 75
#    Elapsed time: 01:15:45
#       Timestamp: 2017/11/24 18:07:55
# -------------- EPOCH   83/500 --------------
#      Train loss: 0.00157956, accuracy: 99.97%
# Validation loss: 0.01491580, accuracy: 99.56%
#       Best loss: 0.01080795 at epoch 75
#    Elapsed time: 01:16:41
#       Timestamp: 2017/11/24 18:08:50
# -------------- EPOCH   84/500 --------------
#      Train loss: 0.00120095, accuracy: 99.99%
# Validation loss: 0.01203353, accuracy: 99.68%
#       Best loss: 0.01080795 at epoch 75
#    Elapsed time: 01:17:35
#       Timestamp: 2017/11/24 18:09:45
# -------------- EPOCH   85/500 --------------
#      Train loss: 0.00160057, accuracy: 99.96%
# Validation loss: 0.01422294, accuracy: 99.59%
#       Best loss: 0.01080795 at epoch 75
#    Elapsed time: 01:18:31
#       Timestamp: 2017/11/24 18:10:40
# -------------- EPOCH   86/500 --------------
#      Train loss: 0.00605385, accuracy: 99.89%
# Validation loss: 0.01841321, accuracy: 99.44%
#       Best loss: 0.01080795 at epoch 75
#    Elapsed time: 01:19:27
#       Timestamp: 2017/11/24 18:11:36
# -------------- EPOCH   87/500 --------------
#      Train loss: 0.00113566, accuracy: 99.98%
# Validation loss: 0.01262329, accuracy: 99.64%
#       Best loss: 0.01080795 at epoch 75
#    Elapsed time: 01:20:21
#       Timestamp: 2017/11/24 18:12:31
# -------------- EPOCH   88/500 --------------
#      Train loss: 0.00271830, accuracy: 99.96%
# Validation loss: 0.01339091, accuracy: 99.66%
#       Best loss: 0.01080795 at epoch 75
#    Elapsed time: 01:21:18
#       Timestamp: 2017/11/24 18:13:27
# -------------- EPOCH   89/500 --------------
#      Train loss: 0.00743156, accuracy: 99.86%
# Validation loss: 0.02205662, accuracy: 99.40%
#       Best loss: 0.01080795 at epoch 75
#    Elapsed time: 01:22:12
#       Timestamp: 2017/11/24 18:14:22
# -------------- EPOCH   90/500 --------------
#      Train loss: 0.00350774, accuracy: 99.92%
# Validation loss: 0.01424982, accuracy: 99.56%
#       Best loss: 0.01080795 at epoch 75
#    Elapsed time: 01:23:10
#       Timestamp: 2017/11/24 18:15:20
# -------------- EPOCH   91/500 --------------
#      Train loss: 0.00088808, accuracy: 99.99%
# Validation loss: 0.01133415, accuracy: 99.65%
#       Best loss: 0.01080795 at epoch 75
#    Elapsed time: 01:24:08
#       Timestamp: 2017/11/24 18:16:17
# -------------- EPOCH   92/500 --------------
#      Train loss: 0.00044230, accuracy: 99.99%
# Validation loss: 0.00886920, accuracy: 99.78%
#       Best loss: 0.01080795 at epoch 75
#    Elapsed time: 01:25:05
#       Timestamp: 2017/11/24 18:17:14
# -------------- EPOCH   93/500 --------------
#      Train loss: 0.00164846, accuracy: 99.96%
# Validation loss: 0.01363723, accuracy: 99.70%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:26:03
#       Timestamp: 2017/11/24 18:18:12
# -------------- EPOCH   94/500 --------------
#      Train loss: 0.00174186, accuracy: 99.98%
# Validation loss: 0.01139763, accuracy: 99.70%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:27:00
#       Timestamp: 2017/11/24 18:19:09
# -------------- EPOCH   95/500 --------------
#      Train loss: 0.00158890, accuracy: 99.97%
# Validation loss: 0.01227097, accuracy: 99.65%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:27:57
#       Timestamp: 2017/11/24 18:20:06
# -------------- EPOCH   96/500 --------------
#      Train loss: 0.00154943, accuracy: 99.98%
# Validation loss: 0.01129662, accuracy: 99.74%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:28:54
#       Timestamp: 2017/11/24 18:21:03
# -------------- EPOCH   97/500 --------------
#      Train loss: 0.00103572, accuracy: 99.97%
# Validation loss: 0.01206086, accuracy: 99.67%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:29:51
#       Timestamp: 2017/11/24 18:22:01
# -------------- EPOCH   98/500 --------------
#      Train loss: 0.00106853, accuracy: 99.98%
# Validation loss: 0.01324108, accuracy: 99.60%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:30:49
#       Timestamp: 2017/11/24 18:22:58
# -------------- EPOCH   99/500 --------------
#      Train loss: 0.00124377, accuracy: 99.98%
# Validation loss: 0.01562035, accuracy: 99.60%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:31:46
#       Timestamp: 2017/11/24 18:23:56
# -------------- EPOCH  100/500 --------------
#      Train loss: 0.00393562, accuracy: 99.89%
# Validation loss: 0.01738496, accuracy: 99.43%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:32:43
#       Timestamp: 2017/11/24 18:24:53
# -------------- EPOCH  101/500 --------------
#      Train loss: 0.00196408, accuracy: 99.96%
# Validation loss: 0.01413987, accuracy: 99.67%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:33:40
#       Timestamp: 2017/11/24 18:25:49
# -------------- EPOCH  102/500 --------------
#      Train loss: 0.00874004, accuracy: 99.84%
# Validation loss: 0.01737851, accuracy: 99.60%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:34:37
#       Timestamp: 2017/11/24 18:26:46
# -------------- EPOCH  103/500 --------------
#      Train loss: 0.00068515, accuracy: 99.98%
# Validation loss: 0.01210782, accuracy: 99.64%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:35:34
#       Timestamp: 2017/11/24 18:27:43
# -------------- EPOCH  104/500 --------------
#      Train loss: 0.00084069, accuracy: 99.98%
# Validation loss: 0.01253028, accuracy: 99.66%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:36:31
#       Timestamp: 2017/11/24 18:28:41
# -------------- EPOCH  105/500 --------------
#      Train loss: 0.00410445, accuracy: 99.87%
# Validation loss: 0.01637246, accuracy: 99.41%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:37:29
#       Timestamp: 2017/11/24 18:29:39
# -------------- EPOCH  106/500 --------------
#      Train loss: 0.00110893, accuracy: 99.99%
# Validation loss: 0.01106116, accuracy: 99.67%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:38:27
#       Timestamp: 2017/11/24 18:30:37
# -------------- EPOCH  107/500 --------------
#      Train loss: 0.00235141, accuracy: 99.93%
# Validation loss: 0.01675467, accuracy: 99.56%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:39:25
#       Timestamp: 2017/11/24 18:31:34
# -------------- EPOCH  108/500 --------------
#      Train loss: 0.00305342, accuracy: 99.95%
# Validation loss: 0.01388887, accuracy: 99.64%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:40:23
#       Timestamp: 2017/11/24 18:32:32
# -------------- EPOCH  109/500 --------------
#      Train loss: 0.00216698, accuracy: 99.92%
# Validation loss: 0.01645890, accuracy: 99.47%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:41:20
#       Timestamp: 2017/11/24 18:33:29
# -------------- EPOCH  110/500 --------------
#      Train loss: 0.00135539, accuracy: 99.98%
# Validation loss: 0.01218784, accuracy: 99.65%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:42:17
#       Timestamp: 2017/11/24 18:34:27
# -------------- EPOCH  111/500 --------------
#      Train loss: 0.00085549, accuracy: 99.98%
# Validation loss: 0.01090557, accuracy: 99.69%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:43:15
#       Timestamp: 2017/11/24 18:35:24
# -------------- EPOCH  112/500 --------------
#      Train loss: 0.00104396, accuracy: 99.98%
# Validation loss: 0.01198856, accuracy: 99.65%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:44:12
#       Timestamp: 2017/11/24 18:36:22
# -------------- EPOCH  113/500 --------------
#      Train loss: 0.00072126, accuracy: 99.99%
# Validation loss: 0.01074995, accuracy: 99.67%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:45:10
#       Timestamp: 2017/11/24 18:37:19
# -------------- EPOCH  114/500 --------------
#      Train loss: 0.00051625, accuracy: 99.99%
# Validation loss: 0.00997603, accuracy: 99.75%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:46:14
#       Timestamp: 2017/11/24 18:38:24
# -------------- EPOCH  115/500 --------------
#      Train loss: 0.00195076, accuracy: 99.94%
# Validation loss: 0.01380090, accuracy: 99.60%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:47:12
#       Timestamp: 2017/11/24 18:39:22
# -------------- EPOCH  116/500 --------------
#      Train loss: 0.00060518, accuracy: 99.99%
# Validation loss: 0.00988614, accuracy: 99.75%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:48:10
#       Timestamp: 2017/11/24 18:40:20
# -------------- EPOCH  117/500 --------------
#      Train loss: 0.00083889, accuracy: 99.98%
# Validation loss: 0.01186132, accuracy: 99.64%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:49:08
#       Timestamp: 2017/11/24 18:41:18
# -------------- EPOCH  118/500 --------------
#      Train loss: 0.00131830, accuracy: 99.98%
# Validation loss: 0.01258544, accuracy: 99.69%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:50:06
#       Timestamp: 2017/11/24 18:42:16
# -------------- EPOCH  119/500 --------------
#      Train loss: 0.00064252, accuracy: 99.99%
# Validation loss: 0.01216644, accuracy: 99.68%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:51:05
#       Timestamp: 2017/11/24 18:43:15
# -------------- EPOCH  120/500 --------------
#      Train loss: 0.00062618, accuracy: 99.99%
# Validation loss: 0.01152878, accuracy: 99.68%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:52:02
#       Timestamp: 2017/11/24 18:44:12
# -------------- EPOCH  121/500 --------------
#      Train loss: 0.00109417, accuracy: 99.98%
# Validation loss: 0.01469514, accuracy: 99.59%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:53:00
#       Timestamp: 2017/11/24 18:45:09
# -------------- EPOCH  122/500 --------------
#      Train loss: 0.00050093, accuracy: 99.99%
# Validation loss: 0.01038394, accuracy: 99.73%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:53:57
#       Timestamp: 2017/11/24 18:46:07
# -------------- EPOCH  123/500 --------------
#      Train loss: 0.00098736, accuracy: 99.98%
# Validation loss: 0.01181643, accuracy: 99.68%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:54:56
#       Timestamp: 2017/11/24 18:47:06
# -------------- EPOCH  124/500 --------------
#      Train loss: 0.00058996, accuracy: 99.99%
# Validation loss: 0.01179024, accuracy: 99.68%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:55:54
#       Timestamp: 2017/11/24 18:48:03
# -------------- EPOCH  125/500 --------------
#      Train loss: 0.00097004, accuracy: 99.98%
# Validation loss: 0.01164892, accuracy: 99.63%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:56:51
#       Timestamp: 2017/11/24 18:49:01
# -------------- EPOCH  126/500 --------------
#      Train loss: 0.00081894, accuracy: 99.98%
# Validation loss: 0.00908782, accuracy: 99.72%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:57:48
#       Timestamp: 2017/11/24 18:49:58
# -------------- EPOCH  127/500 --------------
#      Train loss: 0.00165741, accuracy: 99.95%
# Validation loss: 0.01374981, accuracy: 99.56%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:58:47
#       Timestamp: 2017/11/24 18:50:56
# -------------- EPOCH  128/500 --------------
#      Train loss: 0.00089101, accuracy: 99.99%
# Validation loss: 0.01026533, accuracy: 99.76%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 01:59:50
#       Timestamp: 2017/11/24 18:52:00
# -------------- EPOCH  129/500 --------------
#      Train loss: 0.00095139, accuracy: 99.99%
# Validation loss: 0.00948504, accuracy: 99.76%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 02:00:56
#       Timestamp: 2017/11/24 18:53:06
# -------------- EPOCH  130/500 --------------
#      Train loss: 0.00706009, accuracy: 99.83%
# Validation loss: 0.01940494, accuracy: 99.48%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 02:01:58
#       Timestamp: 2017/11/24 18:54:08
# -------------- EPOCH  131/500 --------------
#      Train loss: 0.00162756, accuracy: 99.94%
# Validation loss: 0.01228550, accuracy: 99.65%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 02:03:01
#       Timestamp: 2017/11/24 18:55:11
# -------------- EPOCH  132/500 --------------
#      Train loss: 0.00095428, accuracy: 99.98%
# Validation loss: 0.00974954, accuracy: 99.75%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 02:04:09
#       Timestamp: 2017/11/24 18:56:18
# -------------- EPOCH  133/500 --------------
#      Train loss: 0.00065255, accuracy: 99.99%
# Validation loss: 0.00962928, accuracy: 99.74%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 02:05:17
#       Timestamp: 2017/11/24 18:57:26
# -------------- EPOCH  134/500 --------------
#      Train loss: 0.00061757, accuracy: 99.99%
# Validation loss: 0.00974005, accuracy: 99.77%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 02:06:14
#       Timestamp: 2017/11/24 18:58:23
# -------------- EPOCH  135/500 --------------
#      Train loss: 0.00062022, accuracy: 99.98%
# Validation loss: 0.01236723, accuracy: 99.64%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 02:07:10
#       Timestamp: 2017/11/24 18:59:20
# -------------- EPOCH  136/500 --------------
#      Train loss: 0.00155551, accuracy: 99.96%
# Validation loss: 0.01193055, accuracy: 99.68%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 02:08:07
#       Timestamp: 2017/11/24 19:00:16
# -------------- EPOCH  137/500 --------------
#      Train loss: 0.00054422, accuracy: 99.99%
# Validation loss: 0.00978427, accuracy: 99.68%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 02:09:03
#       Timestamp: 2017/11/24 19:01:13
# -------------- EPOCH  138/500 --------------
#      Train loss: 0.00695548, accuracy: 99.87%
# Validation loss: 0.01738209, accuracy: 99.55%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 02:10:01
#       Timestamp: 2017/11/24 19:02:10
# -------------- EPOCH  139/500 --------------
#      Train loss: 0.00082027, accuracy: 99.99%
# Validation loss: 0.01050151, accuracy: 99.70%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 02:10:59
#       Timestamp: 2017/11/24 19:03:09
# -------------- EPOCH  140/500 --------------
#      Train loss: 0.00527177, accuracy: 99.84%
# Validation loss: 0.01624234, accuracy: 99.51%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 02:11:57
#       Timestamp: 2017/11/24 19:04:06
# -------------- EPOCH  141/500 --------------
#      Train loss: 0.00064966, accuracy: 99.98%
# Validation loss: 0.00874088, accuracy: 99.73%
#       Best loss: 0.00886920 at epoch 92
#    Elapsed time: 02:12:57
#       Timestamp: 2017/11/24 19:05:07
# -------------- EPOCH  142/500 --------------
#      Train loss: 0.00088804, accuracy: 99.98%
# Validation loss: 0.00802396, accuracy: 99.79%
#       Best loss: 0.00874088 at epoch 141
#    Elapsed time: 02:13:58
#       Timestamp: 2017/11/24 19:06:08
# -------------- EPOCH  143/500 --------------
#      Train loss: 0.00142211, accuracy: 99.98%
# Validation loss: 0.00991279, accuracy: 99.71%
#       Best loss: 0.00802396 at epoch 142
#    Elapsed time: 02:15:01
#       Timestamp: 2017/11/24 19:07:10
# -------------- EPOCH  144/500 --------------
#      Train loss: 0.00092470, accuracy: 99.98%
# Validation loss: 0.01001022, accuracy: 99.69%
#       Best loss: 0.00802396 at epoch 142
#    Elapsed time: 02:16:00
#       Timestamp: 2017/11/24 19:08:09
# -------------- EPOCH  145/500 --------------
#      Train loss: 0.00063367, accuracy: 99.99%
# Validation loss: 0.00974126, accuracy: 99.75%
#       Best loss: 0.00802396 at epoch 142
#    Elapsed time: 02:17:01
#       Timestamp: 2017/11/24 19:09:11
# -------------- EPOCH  146/500 --------------
#      Train loss: 0.00059191, accuracy: 99.99%
# Validation loss: 0.01066442, accuracy: 99.73%
#       Best loss: 0.00802396 at epoch 142
#    Elapsed time: 02:18:00
#       Timestamp: 2017/11/24 19:10:09
# -------------- EPOCH  147/500 --------------
#      Train loss: 0.00050695, accuracy: 99.99%
# Validation loss: 0.00759616, accuracy: 99.81%
#       Best loss: 0.00802396 at epoch 142
#    Elapsed time: 02:18:58
#       Timestamp: 2017/11/24 19:11:08
# -------------- EPOCH  148/500 --------------
#      Train loss: 0.00063196, accuracy: 99.99%
# Validation loss: 0.00835184, accuracy: 99.77%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:19:59
#       Timestamp: 2017/11/24 19:12:08
# -------------- EPOCH  149/500 --------------
#      Train loss: 0.00106003, accuracy: 99.97%
# Validation loss: 0.00928711, accuracy: 99.78%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:21:00
#       Timestamp: 2017/11/24 19:13:10
# -------------- EPOCH  150/500 --------------
#      Train loss: 0.00107306, accuracy: 99.98%
# Validation loss: 0.01167817, accuracy: 99.69%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:22:00
#       Timestamp: 2017/11/24 19:14:09
# -------------- EPOCH  151/500 --------------
#      Train loss: 0.00093097, accuracy: 99.99%
# Validation loss: 0.01021269, accuracy: 99.73%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:22:59
#       Timestamp: 2017/11/24 19:15:09
# -------------- EPOCH  152/500 --------------
#      Train loss: 0.00075326, accuracy: 99.98%
# Validation loss: 0.00828619, accuracy: 99.77%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:23:59
#       Timestamp: 2017/11/24 19:16:09
# -------------- EPOCH  153/500 --------------
#      Train loss: 0.00131456, accuracy: 99.95%
# Validation loss: 0.00836489, accuracy: 99.79%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:25:01
#       Timestamp: 2017/11/24 19:17:11
# -------------- EPOCH  154/500 --------------
#      Train loss: 0.00103020, accuracy: 99.98%
# Validation loss: 0.00976290, accuracy: 99.69%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:26:02
#       Timestamp: 2017/11/24 19:18:12
# -------------- EPOCH  155/500 --------------
#      Train loss: 0.00029875, accuracy: 100.00%
# Validation loss: 0.00783741, accuracy: 99.80%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:27:06
#       Timestamp: 2017/11/24 19:19:15
# -------------- EPOCH  156/500 --------------
#      Train loss: 0.00124468, accuracy: 99.98%
# Validation loss: 0.01321965, accuracy: 99.66%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:28:07
#       Timestamp: 2017/11/24 19:20:17
# -------------- EPOCH  157/500 --------------
#      Train loss: 0.00108068, accuracy: 99.96%
# Validation loss: 0.01080535, accuracy: 99.71%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:29:08
#       Timestamp: 2017/11/24 19:21:17
# -------------- EPOCH  158/500 --------------
#      Train loss: 0.00046339, accuracy: 99.99%
# Validation loss: 0.00846102, accuracy: 99.76%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:30:06
#       Timestamp: 2017/11/24 19:22:15
# -------------- EPOCH  159/500 --------------
#      Train loss: 0.00073271, accuracy: 99.99%
# Validation loss: 0.00924488, accuracy: 99.80%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:31:04
#       Timestamp: 2017/11/24 19:23:14
# -------------- EPOCH  160/500 --------------
#      Train loss: 0.00065294, accuracy: 99.99%
# Validation loss: 0.00931802, accuracy: 99.73%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:32:03
#       Timestamp: 2017/11/24 19:24:13
# -------------- EPOCH  161/500 --------------
#      Train loss: 0.00053208, accuracy: 99.99%
# Validation loss: 0.00836798, accuracy: 99.81%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:33:03
#       Timestamp: 2017/11/24 19:25:12
# -------------- EPOCH  162/500 --------------
#      Train loss: 0.00061909, accuracy: 99.99%
# Validation loss: 0.00926488, accuracy: 99.74%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:34:03
#       Timestamp: 2017/11/24 19:26:13
# -------------- EPOCH  163/500 --------------
#      Train loss: 0.00189671, accuracy: 99.96%
# Validation loss: 0.01338831, accuracy: 99.60%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:35:01
#       Timestamp: 2017/11/24 19:27:11
# -------------- EPOCH  164/500 --------------
#      Train loss: 0.00059217, accuracy: 99.99%
# Validation loss: 0.00762940, accuracy: 99.79%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:36:00
#       Timestamp: 2017/11/24 19:28:10
# -------------- EPOCH  165/500 --------------
#      Train loss: 0.00070018, accuracy: 99.98%
# Validation loss: 0.01154238, accuracy: 99.67%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:37:01
#       Timestamp: 2017/11/24 19:29:10
# -------------- EPOCH  166/500 --------------
#      Train loss: 0.00080056, accuracy: 99.98%
# Validation loss: 0.01017383, accuracy: 99.73%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:38:02
#       Timestamp: 2017/11/24 19:30:11
# -------------- EPOCH  167/500 --------------
#      Train loss: 0.00151487, accuracy: 99.97%
# Validation loss: 0.01136640, accuracy: 99.74%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:38:59
#       Timestamp: 2017/11/24 19:31:08
# -------------- EPOCH  168/500 --------------
#      Train loss: 0.00085293, accuracy: 99.98%
# Validation loss: 0.00983894, accuracy: 99.80%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:39:56
#       Timestamp: 2017/11/24 19:32:05
# -------------- EPOCH  169/500 --------------
#      Train loss: 0.00036905, accuracy: 99.99%
# Validation loss: 0.01144528, accuracy: 99.74%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:40:54
#       Timestamp: 2017/11/24 19:33:03
# -------------- EPOCH  170/500 --------------
#      Train loss: 0.00037255, accuracy: 100.00%
# Validation loss: 0.01037466, accuracy: 99.76%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:41:50
#       Timestamp: 2017/11/24 19:34:00
# -------------- EPOCH  171/500 --------------
#      Train loss: 0.00110418, accuracy: 99.97%
# Validation loss: 0.00976836, accuracy: 99.69%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:42:47
#       Timestamp: 2017/11/24 19:34:56
# -------------- EPOCH  172/500 --------------
#      Train loss: 0.00154899, accuracy: 99.96%
# Validation loss: 0.01148698, accuracy: 99.69%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:43:44
#       Timestamp: 2017/11/24 19:35:53
# -------------- EPOCH  173/500 --------------
#      Train loss: 0.00638786, accuracy: 99.80%
# Validation loss: 0.01966379, accuracy: 99.42%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:44:41
#       Timestamp: 2017/11/24 19:36:51
# -------------- EPOCH  174/500 --------------
#      Train loss: 0.00035073, accuracy: 99.99%
# Validation loss: 0.00995565, accuracy: 99.74%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:45:37
#       Timestamp: 2017/11/24 19:37:47
# -------------- EPOCH  175/500 --------------
#      Train loss: 0.00105975, accuracy: 99.98%
# Validation loss: 0.01260261, accuracy: 99.72%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:46:34
#       Timestamp: 2017/11/24 19:38:43
# -------------- EPOCH  176/500 --------------
#      Train loss: 0.00103993, accuracy: 99.98%
# Validation loss: 0.00956751, accuracy: 99.76%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:47:34
#       Timestamp: 2017/11/24 19:39:44
# -------------- EPOCH  177/500 --------------
#      Train loss: 0.00076724, accuracy: 99.98%
# Validation loss: 0.01061348, accuracy: 99.73%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:48:35
#       Timestamp: 2017/11/24 19:40:44
# -------------- EPOCH  178/500 --------------
#      Train loss: 0.00048097, accuracy: 99.99%
# Validation loss: 0.01091038, accuracy: 99.73%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:49:32
#       Timestamp: 2017/11/24 19:41:41
# -------------- EPOCH  179/500 --------------
#      Train loss: 0.00143935, accuracy: 99.95%
# Validation loss: 0.01137355, accuracy: 99.70%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:50:29
#       Timestamp: 2017/11/24 19:42:39
# -------------- EPOCH  180/500 --------------
#      Train loss: 0.00049908, accuracy: 99.99%
# Validation loss: 0.00912447, accuracy: 99.78%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:51:29
#       Timestamp: 2017/11/24 19:43:38
# -------------- EPOCH  181/500 --------------
#      Train loss: 0.00051224, accuracy: 99.98%
# Validation loss: 0.00932417, accuracy: 99.74%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:52:26
#       Timestamp: 2017/11/24 19:44:35
# -------------- EPOCH  182/500 --------------
#      Train loss: 0.00106775, accuracy: 99.97%
# Validation loss: 0.00991302, accuracy: 99.72%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:53:22
#       Timestamp: 2017/11/24 19:45:32
# -------------- EPOCH  183/500 --------------
#      Train loss: 0.00090696, accuracy: 99.98%
# Validation loss: 0.01241288, accuracy: 99.68%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:54:18
#       Timestamp: 2017/11/24 19:46:28
# -------------- EPOCH  184/500 --------------
#      Train loss: 0.00085694, accuracy: 99.99%
# Validation loss: 0.00874174, accuracy: 99.75%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:55:15
#       Timestamp: 2017/11/24 19:47:24
# -------------- EPOCH  185/500 --------------
#      Train loss: 0.00057629, accuracy: 99.99%
# Validation loss: 0.00848395, accuracy: 99.77%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:56:12
#       Timestamp: 2017/11/24 19:48:21
# -------------- EPOCH  186/500 --------------
#      Train loss: 0.00180676, accuracy: 99.97%
# Validation loss: 0.01104200, accuracy: 99.68%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:57:08
#       Timestamp: 2017/11/24 19:49:18
# -------------- EPOCH  187/500 --------------
#      Train loss: 0.00111704, accuracy: 99.98%
# Validation loss: 0.01059743, accuracy: 99.71%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:58:05
#       Timestamp: 2017/11/24 19:50:14
# -------------- EPOCH  188/500 --------------
#      Train loss: 0.00221274, accuracy: 99.94%
# Validation loss: 0.01305932, accuracy: 99.66%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 02:59:06
#       Timestamp: 2017/11/24 19:51:16
# -------------- EPOCH  189/500 --------------
#      Train loss: 0.00105012, accuracy: 99.98%
# Validation loss: 0.01382540, accuracy: 99.64%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 03:00:03
#       Timestamp: 2017/11/24 19:52:12
# -------------- EPOCH  190/500 --------------
#      Train loss: 0.00037481, accuracy: 99.99%
# Validation loss: 0.00890314, accuracy: 99.77%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 03:00:59
#       Timestamp: 2017/11/24 19:53:09
# -------------- EPOCH  191/500 --------------
#      Train loss: 0.00030321, accuracy: 100.00%
# Validation loss: 0.00764492, accuracy: 99.81%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 03:01:56
#       Timestamp: 2017/11/24 19:54:05
# -------------- EPOCH  192/500 --------------
#      Train loss: 0.00031924, accuracy: 99.99%
# Validation loss: 0.00835274, accuracy: 99.78%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 03:02:53
#       Timestamp: 2017/11/24 19:55:02
# -------------- EPOCH  193/500 --------------
#      Train loss: 0.00042064, accuracy: 99.99%
# Validation loss: 0.00901376, accuracy: 99.77%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 03:03:51
#       Timestamp: 2017/11/24 19:56:00
# -------------- EPOCH  194/500 --------------
#      Train loss: 0.00372159, accuracy: 99.92%
# Validation loss: 0.01384136, accuracy: 99.60%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 03:04:48
#       Timestamp: 2017/11/24 19:56:57
# -------------- EPOCH  195/500 --------------
#      Train loss: 0.00052082, accuracy: 99.99%
# Validation loss: 0.01061963, accuracy: 99.68%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 03:05:45
#       Timestamp: 2017/11/24 19:57:54
# -------------- EPOCH  196/500 --------------
#      Train loss: 0.00060046, accuracy: 99.99%
# Validation loss: 0.00882191, accuracy: 99.73%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 03:06:42
#       Timestamp: 2017/11/24 19:58:51
# -------------- EPOCH  197/500 --------------
#      Train loss: 0.00038046, accuracy: 99.99%
# Validation loss: 0.00806390, accuracy: 99.83%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 03:07:39
#       Timestamp: 2017/11/24 19:59:48
# -------------- EPOCH  198/500 --------------
#      Train loss: 0.00053270, accuracy: 99.99%
# Validation loss: 0.00840501, accuracy: 99.77%
#       Best loss: 0.00759616 at epoch 147
#    Elapsed time: 03:08:36
#       Timestamp: 2017/11/24 20:00:46
# INFO:tensorflow:Restoring parameters from /home/wastaljoey/TSC1/early_stopping_checkpoint
# Early stopping.
# Best monitored loss was 0.00759616 at epoch 147.
# =============================================
#  Valid loss: 0.00759616, accuracy = 99.81%)
#  Test loss: 0.21572512, accuracy = 95.94%)
#  Total time: 03:08:44
#   Timestamp: 2017/11/24 20:00:54
# Model file: /home/wastaljoey/TSC1/models/4layers_k7d16p0.9_k7d32p0.8_k5d64p0.7_fc1024p0.5_no-lrdec_l2/model.ckpt
# Train history file: /home/wastaljoey/TSC1/models/4layers_k7d16p0.9_k7d32p0.8_k5d64p0.7_fc1024p0.5_no-lrdec_l2/train_history

# %% [markdown]
# ### Create partial perturbed dataset

# %%
import pickle
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

train_dataset_file = "data/train_processed.p"
adv4layers_dataset_file = "data/adv_image_4_layers.p"

X_train, y_train = load_pickled_data(train_dataset_file, columns = ['features', 'labels'])
X_adv, y_adv = load_pickled_data(adv4layers_dataset_file, columns = ['features', 'labels'])

X_train,y_train=shuffle(X_train,y_train)

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.75)
X_adv, X_val, y_adv, y_val = train_test_split(X_adv, y_adv, test_size = 0.25)

print(X_train.shape,y_train.shape)
print(X_adv.shape,y_adv.shape)

X_adv_4layers=np.concatenate((X_adv,X_train),axis=0)
y_adv_4layers=np.concatenate((y_adv,y_train),axis=0)

print(X_adv_4layers.shape,y_adv_4layers.shape)

X_adv_4layers,y_adv_4layers=shuffle(X_adv_4layers,y_adv_4layers)

adv_dataset_file="data/75%_perturbed_adv_image_4layers.p"
pickle.dump({
    "features":X_adv_4layers,
    "labels":y_adv_4layers
},open(adv_dataset_file,"wb"))
print("adv_images saved")
# Out:
# (12377, 32, 32, 1) (12377, 43)
# (37132, 32, 32, 1) (37132, 43)
# (49509, 32, 32, 1) (49509, 43)
# adv_images saved

# %%
import pickle
from sklearn.model_selection import train_test_split

#train_extended_preprocessed_dataset_file = "data/train_extended_preprocessed.p"
train_balanced_preprocessed_dataset_file = "data/30%_perturbed_adv_image.p"
test_preprocessed_dataset_file = "data/adv_image_test.p"


parameters = Parameters(
    # Data parameters
    num_classes = 43,
    image_size = (32, 32),
    # Training parameters
    batch_size = 256,
    max_epochs = 1001,
    log_epoch = 1,
    print_epoch = 1,
    # Optimisations
    learning_rate_decay = False,
    learning_rate = 0.0001,
    l2_reg_enabled = True,
    l2_lambda = 0.0001,
    early_stopping_enabled = True,
    early_stopping_patience = 80,
    resume_training = True,
    # Layers architecture
    conv1_k = 5, conv1_d = 32, conv1_p = 0.9,
    conv2_k = 5, conv2_d = 64, conv2_p = 0.8,
    conv3_k = 5, conv3_d = 128, conv3_p = 0.7,
    fc4_size = 1024, fc4_p = 0.5,
    adv_training=None,
    perturbed_ratio= 30
    
)

X_train, y_train = load_pickled_data(train_balanced_preprocessed_dataset_file, columns = ['features', 'labels'])
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.25)
X_test, y_test = load_pickled_data(test_preprocessed_dataset_file, columns = ['features', 'labels'])
train_model(parameters, X_train, y_train, X_valid, y_valid, X_test, y_test)
# Out:
# =============================================
# ============= RESUMING TRAINING =============
# =============================================
# =================== DATA ====================
#             Training set: 37132 examples
#           Validation set: 12378 examples
#              Testing set: 12630 examples
#               Batch size: 256
# =================== MODEL ===================
# --------------- ARCHITECTURE ----------------
#             Type       Size     Dropout (keep p)
#  Layer 1    5x5 Conv   32       0.9
#  Layer 2    5x5 Conv   64       0.8
#  Layer 3    5x5 Conv   128      0.7
#  Layer 4    FC         1024     0.5
# ---------------- PARAMETERS -----------------
#      Learning rate decay: Disabled (rate = 0.0001)
#        L2 Regularization: Enabled (lambda = 0.0001)
#           Early stopping: Enabled (patience = 80)
#  Keep training old model: Enabled
# INFO:tensorflow:Restoring parameters from /home/wastaljoey/TSC1/models/k5d32p0.9_k5d64p0.8_k5d128p0.7_fc1024p0.5_no-lrdec_l2_30%_perturbed/model.ckpt
# Failed restoring previously trained model: file does not exist.
# ================= TRAINING ==================
#  Timestamp: 2017/10/17 07:09:22
# -------------- EPOCH    0/1001 --------------
#      Train loss: 3.23705149, accuracy: 20.47%
# Validation loss: 3.24515343, accuracy: 19.94%
#       Best loss: inf at epoch 0
#    Elapsed time: 00:01:41
#       Timestamp: 2017/10/17 07:11:03
# -------------- EPOCH    1/1001 --------------
#      Train loss: 2.19875669, accuracy: 43.07%
# Validation loss: 2.21128631, accuracy: 42.49%
#       Best loss: 3.24515343 at epoch 0
#    Elapsed time: 00:03:22
#       Timestamp: 2017/10/17 07:12:44
# -------------- EPOCH    2/1001 --------------
#      Train loss: 1.59701812, accuracy: 60.07%
# Validation loss: 1.61286819, accuracy: 59.35%
#       Best loss: 2.21128631 at epoch 1
#    Elapsed time: 00:05:03
#       Timestamp: 2017/10/17 07:14:25
# -------------- EPOCH    3/1001 --------------
#      Train loss: 1.30888534, accuracy: 66.38%
# Validation loss: 1.33238566, accuracy: 65.37%
#       Best loss: 1.61286819 at epoch 2
#    Elapsed time: 00:06:44
#       Timestamp: 2017/10/17 07:16:06
# -------------- EPOCH    4/1001 --------------
#      Train loss: 1.10870767, accuracy: 72.65%
# Validation loss: 1.13818944, accuracy: 71.36%
#       Best loss: 1.33238566 at epoch 3
#    Elapsed time: 00:08:26
#       Timestamp: 2017/10/17 07:17:47
# -------------- EPOCH    5/1001 --------------
#      Train loss: 0.99205792, accuracy: 75.05%
# Validation loss: 1.02795672, accuracy: 73.74%
#       Best loss: 1.13818944 at epoch 4
#    Elapsed time: 00:10:07
#       Timestamp: 2017/10/17 07:19:28
# -------------- EPOCH    6/1001 --------------
#      Train loss: 0.89605147, accuracy: 77.43%
# Validation loss: 0.93505001, accuracy: 75.88%
#       Best loss: 1.02795672 at epoch 5
#    Elapsed time: 00:11:48
#       Timestamp: 2017/10/17 07:21:09
# -------------- EPOCH    7/1001 --------------
#      Train loss: 0.83417660, accuracy: 78.62%
# Validation loss: 0.87865508, accuracy: 76.68%
#       Best loss: 0.93505001 at epoch 6
#    Elapsed time: 00:13:29
#       Timestamp: 2017/10/17 07:22:51
# -------------- EPOCH    8/1001 --------------
#      Train loss: 0.77783859, accuracy: 80.77%
# Validation loss: 0.82505852, accuracy: 78.76%
#       Best loss: 0.87865508 at epoch 7
#    Elapsed time: 00:15:11
#       Timestamp: 2017/10/17 07:24:32
# -------------- EPOCH    9/1001 --------------
#      Train loss: 0.73411119, accuracy: 81.85%
# Validation loss: 0.78300053, accuracy: 79.67%
#       Best loss: 0.82505852 at epoch 8
#    Elapsed time: 00:16:54
#       Timestamp: 2017/10/17 07:26:16
# -------------- EPOCH   10/1001 --------------
#      Train loss: 0.70243806, accuracy: 82.53%
# Validation loss: 0.75202179, accuracy: 80.68%
#       Best loss: 0.78300053 at epoch 9
#    Elapsed time: 00:18:36
#       Timestamp: 2017/10/17 07:27:58
# -------------- EPOCH   11/1001 --------------
#      Train loss: 0.66363692, accuracy: 83.67%
# Validation loss: 0.71486789, accuracy: 81.63%
#       Best loss: 0.75202179 at epoch 10
#    Elapsed time: 00:20:17
#       Timestamp: 2017/10/17 07:29:39
# -------------- EPOCH   12/1001 --------------
#      Train loss: 0.63896984, accuracy: 84.08%
# Validation loss: 0.69381207, accuracy: 81.86%
#       Best loss: 0.71486789 at epoch 11
#    Elapsed time: 00:21:57
#       Timestamp: 2017/10/17 07:31:18
# -------------- EPOCH   13/1001 --------------
#      Train loss: 0.61654949, accuracy: 84.51%
# Validation loss: 0.67241269, accuracy: 82.49%
#       Best loss: 0.69381207 at epoch 12
#    Elapsed time: 00:23:36
#       Timestamp: 2017/10/17 07:32:57
# -------------- EPOCH   14/1001 --------------
#      Train loss: 0.60084212, accuracy: 84.81%
# Validation loss: 0.66015768, accuracy: 82.44%
#       Best loss: 0.67241269 at epoch 13
#    Elapsed time: 00:25:15
#       Timestamp: 2017/10/17 07:34:36
# -------------- EPOCH   15/1001 --------------
#      Train loss: 0.57933378, accuracy: 85.46%
# Validation loss: 0.63997966, accuracy: 83.23%
#       Best loss: 0.66015768 at epoch 14
#    Elapsed time: 00:26:55
#       Timestamp: 2017/10/17 07:36:17
# -------------- EPOCH   16/1001 --------------
#      Train loss: 0.56005639, accuracy: 86.02%
# Validation loss: 0.62244457, accuracy: 83.58%
#       Best loss: 0.63997966 at epoch 15
#    Elapsed time: 00:28:37
#       Timestamp: 2017/10/17 07:37:58
# -------------- EPOCH   17/1001 --------------
#      Train loss: 0.54593462, accuracy: 86.34%
# Validation loss: 0.60919613, accuracy: 83.94%
#       Best loss: 0.62244457 at epoch 16
#    Elapsed time: 00:30:18
#       Timestamp: 2017/10/17 07:39:39
# -------------- EPOCH   18/1001 --------------
#      Train loss: 0.53197807, accuracy: 86.57%
# Validation loss: 0.59805548, accuracy: 84.32%
#       Best loss: 0.60919613 at epoch 17
#    Elapsed time: 00:32:00
#       Timestamp: 2017/10/17 07:41:21
# -------------- EPOCH   19/1001 --------------
#      Train loss: 0.52325428, accuracy: 86.96%
# Validation loss: 0.59094775, accuracy: 84.67%
#       Best loss: 0.59805548 at epoch 18
#    Elapsed time: 00:33:42
#       Timestamp: 2017/10/17 07:43:04
# -------------- EPOCH   20/1001 --------------
#      Train loss: 0.50924444, accuracy: 87.21%
# Validation loss: 0.57795101, accuracy: 84.81%
#       Best loss: 0.59094775 at epoch 19
#    Elapsed time: 00:35:24
#       Timestamp: 2017/10/17 07:44:46
# -------------- EPOCH   21/1001 --------------
#      Train loss: 0.49983856, accuracy: 87.61%
# Validation loss: 0.56940740, accuracy: 85.27%
#       Best loss: 0.57795101 at epoch 20
#    Elapsed time: 00:37:07
#       Timestamp: 2017/10/17 07:46:28
# -------------- EPOCH   22/1001 --------------
#      Train loss: 0.49329802, accuracy: 87.67%
# Validation loss: 0.56675965, accuracy: 84.90%
#       Best loss: 0.56940740 at epoch 21
#    Elapsed time: 00:38:50
#       Timestamp: 2017/10/17 07:48:11
# -------------- EPOCH   23/1001 --------------
#      Train loss: 0.48590103, accuracy: 87.76%
# Validation loss: 0.55998224, accuracy: 85.06%
#       Best loss: 0.56675965 at epoch 22
#    Elapsed time: 00:40:32
#       Timestamp: 2017/10/17 07:49:54
# -------------- EPOCH   24/1001 --------------
#      Train loss: 0.47311345, accuracy: 88.11%
# Validation loss: 0.54859620, accuracy: 85.22%
#       Best loss: 0.55998224 at epoch 23
#    Elapsed time: 00:42:15
#       Timestamp: 2017/10/17 07:51:37
# -------------- EPOCH   25/1001 --------------
#      Train loss: 0.46486416, accuracy: 88.30%
# Validation loss: 0.54102618, accuracy: 85.67%
#       Best loss: 0.54859620 at epoch 24
#    Elapsed time: 00:43:59
#       Timestamp: 2017/10/17 07:53:20
# -------------- EPOCH   26/1001 --------------
#      Train loss: 0.46197277, accuracy: 88.41%
# Validation loss: 0.54047620, accuracy: 85.77%
#       Best loss: 0.54102618 at epoch 25
#    Elapsed time: 00:45:41
#       Timestamp: 2017/10/17 07:55:03
# -------------- EPOCH   27/1001 --------------
#      Train loss: 0.45503357, accuracy: 88.66%
# Validation loss: 0.53501445, accuracy: 85.84%
#       Best loss: 0.54047620 at epoch 26
#    Elapsed time: 00:47:21
#       Timestamp: 2017/10/17 07:56:43
# -------------- EPOCH   28/1001 --------------
#      Train loss: 0.44830847, accuracy: 88.52%
# Validation loss: 0.53049576, accuracy: 85.62%
#       Best loss: 0.53501445 at epoch 27
#    Elapsed time: 00:49:01
#       Timestamp: 2017/10/17 07:58:22
# -------------- EPOCH   29/1001 --------------
#      Train loss: 0.44097453, accuracy: 88.85%
# Validation loss: 0.52473176, accuracy: 85.84%
#       Best loss: 0.53049576 at epoch 28
#    Elapsed time: 00:50:41
#       Timestamp: 2017/10/17 08:00:02
# -------------- EPOCH   30/1001 --------------
#      Train loss: 0.43505132, accuracy: 89.06%
# Validation loss: 0.52152902, accuracy: 85.89%
#       Best loss: 0.52473176 at epoch 29
#    Elapsed time: 00:52:22
#       Timestamp: 2017/10/17 08:01:44
# -------------- EPOCH   31/1001 --------------
#      Train loss: 0.42896035, accuracy: 89.18%
# Validation loss: 0.51398468, accuracy: 86.03%
#       Best loss: 0.52152902 at epoch 30
#    Elapsed time: 00:54:04
#       Timestamp: 2017/10/17 08:03:26
# -------------- EPOCH   32/1001 --------------
#      Train loss: 0.42541578, accuracy: 89.39%
# Validation loss: 0.51434809, accuracy: 86.17%
#       Best loss: 0.51398468 at epoch 31
#    Elapsed time: 00:55:46
#       Timestamp: 2017/10/17 08:05:08
# -------------- EPOCH   33/1001 --------------
#      Train loss: 0.42057025, accuracy: 89.45%
# Validation loss: 0.51111805, accuracy: 86.35%
#       Best loss: 0.51398468 at epoch 31
#    Elapsed time: 00:57:28
#       Timestamp: 2017/10/17 08:06:49
# -------------- EPOCH   34/1001 --------------
#      Train loss: 0.41346821, accuracy: 89.69%
# Validation loss: 0.50391734, accuracy: 86.62%
#       Best loss: 0.51111805 at epoch 33
#    Elapsed time: 00:59:10
#       Timestamp: 2017/10/17 08:08:31
# -------------- EPOCH   35/1001 --------------
#      Train loss: 0.40825588, accuracy: 89.85%
# Validation loss: 0.50068527, accuracy: 86.76%
#       Best loss: 0.50391734 at epoch 34
#    Elapsed time: 01:00:51
#       Timestamp: 2017/10/17 08:10:13
# -------------- EPOCH   36/1001 --------------
#      Train loss: 0.40301055, accuracy: 89.86%
# Validation loss: 0.49503902, accuracy: 86.77%
#       Best loss: 0.50068527 at epoch 35
#    Elapsed time: 01:02:33
#       Timestamp: 2017/10/17 08:11:55
# -------------- EPOCH   37/1001 --------------
#      Train loss: 0.39680627, accuracy: 90.03%
# Validation loss: 0.49217591, accuracy: 86.71%
#       Best loss: 0.49503902 at epoch 36
#    Elapsed time: 01:04:15
#       Timestamp: 2017/10/17 08:13:37
# -------------- EPOCH   38/1001 --------------
#      Train loss: 0.39490408, accuracy: 90.12%
# Validation loss: 0.49055350, accuracy: 86.94%
#       Best loss: 0.49217591 at epoch 37
#    Elapsed time: 01:05:57
#       Timestamp: 2017/10/17 08:15:19
# -------------- EPOCH   39/1001 --------------
#      Train loss: 0.39248979, accuracy: 90.15%
# Validation loss: 0.48788229, accuracy: 86.77%
#       Best loss: 0.49055350 at epoch 38
#    Elapsed time: 01:07:39
#       Timestamp: 2017/10/17 08:17:01
# -------------- EPOCH   40/1001 --------------
#      Train loss: 0.38864800, accuracy: 89.93%
# Validation loss: 0.48935997, accuracy: 86.68%
#       Best loss: 0.48788229 at epoch 39
#    Elapsed time: 01:09:21
#       Timestamp: 2017/10/17 08:18:43
# -------------- EPOCH   41/1001 --------------
#      Train loss: 0.38684145, accuracy: 90.33%
# Validation loss: 0.48723280, accuracy: 86.96%
#       Best loss: 0.48788229 at epoch 39
#    Elapsed time: 01:11:02
#       Timestamp: 2017/10/17 08:20:24
# -------------- EPOCH   42/1001 --------------
#      Train loss: 0.37982619, accuracy: 90.52%
# Validation loss: 0.48120120, accuracy: 87.03%
#       Best loss: 0.48723280 at epoch 41
#    Elapsed time: 01:12:43
#       Timestamp: 2017/10/17 08:22:05
# -------------- EPOCH   43/1001 --------------
#      Train loss: 0.37816361, accuracy: 90.46%
# Validation loss: 0.48190296, accuracy: 86.88%
#       Best loss: 0.48120120 at epoch 42
#    Elapsed time: 01:14:24
#       Timestamp: 2017/10/17 08:23:46
# -------------- EPOCH   44/1001 --------------
#      Train loss: 0.37636271, accuracy: 90.63%
# Validation loss: 0.48091576, accuracy: 87.18%
#       Best loss: 0.48120120 at epoch 42
#    Elapsed time: 01:16:04
#       Timestamp: 2017/10/17 08:25:26
# -------------- EPOCH   45/1001 --------------
#      Train loss: 0.37378395, accuracy: 90.60%
# Validation loss: 0.48033848, accuracy: 86.90%
#       Best loss: 0.48091576 at epoch 44
#    Elapsed time: 01:17:45
#       Timestamp: 2017/10/17 08:27:07
# -------------- EPOCH   46/1001 --------------
#      Train loss: 0.36905116, accuracy: 90.75%
# Validation loss: 0.47582838, accuracy: 87.24%
#       Best loss: 0.48033848 at epoch 45
#    Elapsed time: 01:19:26
#       Timestamp: 2017/10/17 08:28:47
# -------------- EPOCH   47/1001 --------------
#      Train loss: 0.36647549, accuracy: 90.80%
# Validation loss: 0.47367850, accuracy: 87.11%
#       Best loss: 0.47582838 at epoch 46
#    Elapsed time: 01:21:07
#       Timestamp: 2017/10/17 08:30:28
# -------------- EPOCH   48/1001 --------------
#      Train loss: 0.36297327, accuracy: 90.87%
# Validation loss: 0.47207224, accuracy: 87.13%
#       Best loss: 0.47367850 at epoch 47
#    Elapsed time: 01:22:48
#       Timestamp: 2017/10/17 08:32:09
# -------------- EPOCH   49/1001 --------------
#      Train loss: 0.36300299, accuracy: 90.81%
# Validation loss: 0.47568491, accuracy: 87.19%
#       Best loss: 0.47207224 at epoch 48
#    Elapsed time: 01:24:29
#       Timestamp: 2017/10/17 08:33:50
# -------------- EPOCH   50/1001 --------------
#      Train loss: 0.35910314, accuracy: 91.08%
# Validation loss: 0.47041485, accuracy: 87.45%
#       Best loss: 0.47207224 at epoch 48
#    Elapsed time: 01:26:09
#       Timestamp: 2017/10/17 08:35:30
# -------------- EPOCH   51/1001 --------------
#      Train loss: 0.35542187, accuracy: 91.05%
# Validation loss: 0.46955654, accuracy: 87.44%
#       Best loss: 0.47041485 at epoch 50
#    Elapsed time: 01:27:50
#       Timestamp: 2017/10/17 08:37:11
# -------------- EPOCH   52/1001 --------------
#      Train loss: 0.35344344, accuracy: 91.08%
# Validation loss: 0.46917161, accuracy: 87.41%
#       Best loss: 0.46955654 at epoch 51
#    Elapsed time: 01:29:31
#       Timestamp: 2017/10/17 08:38:52
# -------------- EPOCH   53/1001 --------------
#      Train loss: 0.35005122, accuracy: 91.24%
# Validation loss: 0.46895140, accuracy: 87.41%
#       Best loss: 0.46917161 at epoch 52
#    Elapsed time: 01:31:12
#       Timestamp: 2017/10/17 08:40:33
# -------------- EPOCH   54/1001 --------------
#      Train loss: 0.34812024, accuracy: 91.10%
# Validation loss: 0.46941945, accuracy: 87.23%
#       Best loss: 0.46895140 at epoch 53
#    Elapsed time: 01:32:52
#       Timestamp: 2017/10/17 08:42:14
# -------------- EPOCH   55/1001 --------------
#      Train loss: 0.34665501, accuracy: 91.26%
# Validation loss: 0.46479824, accuracy: 87.50%
#       Best loss: 0.46895140 at epoch 53
#    Elapsed time: 01:34:33
#       Timestamp: 2017/10/17 08:43:54
# -------------- EPOCH   56/1001 --------------
#      Train loss: 0.34452584, accuracy: 91.32%
# Validation loss: 0.46111050, accuracy: 87.59%
#       Best loss: 0.46479824 at epoch 55
#    Elapsed time: 01:36:13
#       Timestamp: 2017/10/17 08:45:34
# -------------- EPOCH   57/1001 --------------
#      Train loss: 0.34389102, accuracy: 91.38%
# Validation loss: 0.46604285, accuracy: 87.53%
#       Best loss: 0.46111050 at epoch 56
#    Elapsed time: 01:37:53
#       Timestamp: 2017/10/17 08:47:14
# -------------- EPOCH   58/1001 --------------
#      Train loss: 0.34231839, accuracy: 91.31%
# Validation loss: 0.46516317, accuracy: 87.31%
#       Best loss: 0.46111050 at epoch 56
#    Elapsed time: 01:39:32
#       Timestamp: 2017/10/17 08:48:53
# -------------- EPOCH   59/1001 --------------
#      Train loss: 0.34064025, accuracy: 91.53%
# Validation loss: 0.46048367, accuracy: 87.78%
#       Best loss: 0.46111050 at epoch 56
#    Elapsed time: 01:41:11
#       Timestamp: 2017/10/17 08:50:32
# -------------- EPOCH   60/1001 --------------
#      Train loss: 0.33626372, accuracy: 91.43%
# Validation loss: 0.46373200, accuracy: 87.43%
#       Best loss: 0.46048367 at epoch 59
#    Elapsed time: 01:42:51
#       Timestamp: 2017/10/17 08:52:12
# -------------- EPOCH   61/1001 --------------
#      Train loss: 0.33548862, accuracy: 91.54%
# Validation loss: 0.46226019, accuracy: 87.71%
#       Best loss: 0.46048367 at epoch 59
#    Elapsed time: 01:44:30
#       Timestamp: 2017/10/17 08:53:52
# -------------- EPOCH   62/1001 --------------
#      Train loss: 0.33346733, accuracy: 91.48%
# Validation loss: 0.46362332, accuracy: 87.42%
#       Best loss: 0.46048367 at epoch 59
#    Elapsed time: 01:46:09
#       Timestamp: 2017/10/17 08:55:31
# -------------- EPOCH   63/1001 --------------
#      Train loss: 0.33237520, accuracy: 91.57%
# Validation loss: 0.46058375, accuracy: 87.64%
#       Best loss: 0.46048367 at epoch 59
#    Elapsed time: 01:47:48
#       Timestamp: 2017/10/17 08:57:10
# -------------- EPOCH   64/1001 --------------
#      Train loss: 0.32966730, accuracy: 91.58%
# Validation loss: 0.46252212, accuracy: 87.51%
#       Best loss: 0.46048367 at epoch 59
#    Elapsed time: 01:49:27
#       Timestamp: 2017/10/17 08:58:49
# -------------- EPOCH   65/1001 --------------
#      Train loss: 0.32881454, accuracy: 91.66%
# Validation loss: 0.45883888, accuracy: 87.78%
#       Best loss: 0.46048367 at epoch 59
#    Elapsed time: 01:51:06
#       Timestamp: 2017/10/17 09:00:28
# -------------- EPOCH   66/1001 --------------
#      Train loss: 0.32586184, accuracy: 91.79%
# Validation loss: 0.45669532, accuracy: 87.76%
#       Best loss: 0.45883888 at epoch 65
#    Elapsed time: 01:52:45
#       Timestamp: 2017/10/17 09:02:07
# -------------- EPOCH   67/1001 --------------
#      Train loss: 0.32554609, accuracy: 91.72%
# Validation loss: 0.45879382, accuracy: 87.85%
#       Best loss: 0.45669532 at epoch 66
#    Elapsed time: 01:54:23
#       Timestamp: 2017/10/17 09:03:45
# -------------- EPOCH   68/1001 --------------
#      Train loss: 0.32458308, accuracy: 91.72%
# Validation loss: 0.45799366, accuracy: 87.67%
#       Best loss: 0.45669532 at epoch 66
#    Elapsed time: 01:56:01
#       Timestamp: 2017/10/17 09:05:23
# -------------- EPOCH   69/1001 --------------
#      Train loss: 0.32276118, accuracy: 91.79%
# Validation loss: 0.45869529, accuracy: 87.65%
#       Best loss: 0.45669532 at epoch 66
#    Elapsed time: 01:57:40
#       Timestamp: 2017/10/17 09:07:01
# -------------- EPOCH   70/1001 --------------
#      Train loss: 0.32241327, accuracy: 91.85%
# Validation loss: 0.45596600, accuracy: 87.91%
#       Best loss: 0.45669532 at epoch 66
#    Elapsed time: 01:59:18
#       Timestamp: 2017/10/17 09:08:40
# -------------- EPOCH   71/1001 --------------
#      Train loss: 0.31875888, accuracy: 91.83%
# Validation loss: 0.45638698, accuracy: 87.67%
#       Best loss: 0.45596600 at epoch 70
#    Elapsed time: 02:00:56
#       Timestamp: 2017/10/17 09:10:18
# -------------- EPOCH   72/1001 --------------
#      Train loss: 0.31720203, accuracy: 91.88%
# Validation loss: 0.45387957, accuracy: 87.81%
#       Best loss: 0.45596600 at epoch 70
#    Elapsed time: 02:02:35
#       Timestamp: 2017/10/17 09:11:57
# -------------- EPOCH   73/1001 --------------
#      Train loss: 0.31548554, accuracy: 91.92%
# Validation loss: 0.45462048, accuracy: 87.94%
#       Best loss: 0.45387957 at epoch 72
#    Elapsed time: 02:04:14
#       Timestamp: 2017/10/17 09:13:36
# -------------- EPOCH   74/1001 --------------
#      Train loss: 0.31599775, accuracy: 91.89%
# Validation loss: 0.45452696, accuracy: 87.79%
#       Best loss: 0.45387957 at epoch 72
#    Elapsed time: 02:05:52
#       Timestamp: 2017/10/17 09:15:14
# -------------- EPOCH   75/1001 --------------
#      Train loss: 0.31474611, accuracy: 91.94%
# Validation loss: 0.45664707, accuracy: 87.78%
#       Best loss: 0.45387957 at epoch 72
#    Elapsed time: 02:07:31
#       Timestamp: 2017/10/17 09:16:52
# -------------- EPOCH   76/1001 --------------
#      Train loss: 0.31211200, accuracy: 91.97%
# Validation loss: 0.45620924, accuracy: 87.80%
#       Best loss: 0.45387957 at epoch 72
#    Elapsed time: 02:09:10
#       Timestamp: 2017/10/17 09:18:31
# -------------- EPOCH   77/1001 --------------
#      Train loss: 0.31071356, accuracy: 92.08%
# Validation loss: 0.45097157, accuracy: 87.91%
#       Best loss: 0.45387957 at epoch 72
#    Elapsed time: 02:10:50
#       Timestamp: 2017/10/17 09:20:11
# -------------- EPOCH   78/1001 --------------
#      Train loss: 0.30892766, accuracy: 92.08%
# Validation loss: 0.45259649, accuracy: 87.99%
#       Best loss: 0.45097157 at epoch 77
#    Elapsed time: 02:12:29
#       Timestamp: 2017/10/17 09:21:51
# -------------- EPOCH   79/1001 --------------
#      Train loss: 0.30853757, accuracy: 92.05%
# Validation loss: 0.45446581, accuracy: 87.86%
#       Best loss: 0.45097157 at epoch 77
#    Elapsed time: 02:14:08
#       Timestamp: 2017/10/17 09:23:29
# -------------- EPOCH   80/1001 --------------
#      Train loss: 0.30784592, accuracy: 92.15%
# Validation loss: 0.45328307, accuracy: 87.89%
#       Best loss: 0.45097157 at epoch 77
#    Elapsed time: 02:15:47
#       Timestamp: 2017/10/17 09:25:09
# -------------- EPOCH   81/1001 --------------
#      Train loss: 0.30597568, accuracy: 92.14%
# Validation loss: 0.45293462, accuracy: 87.93%
#       Best loss: 0.45097157 at epoch 77
#    Elapsed time: 02:17:26
#       Timestamp: 2017/10/17 09:26:47
# -------------- EPOCH   82/1001 --------------
#      Train loss: 0.30481800, accuracy: 92.09%
# Validation loss: 0.45506975, accuracy: 87.77%
#       Best loss: 0.45097157 at epoch 77
#    Elapsed time: 02:19:04
#       Timestamp: 2017/10/17 09:28:26
# -------------- EPOCH   83/1001 --------------
#      Train loss: 0.30524689, accuracy: 92.23%
# Validation loss: 0.45151231, accuracy: 87.99%
#       Best loss: 0.45097157 at epoch 77
#    Elapsed time: 02:20:43
#       Timestamp: 2017/10/17 09:30:05
# -------------- EPOCH   84/1001 --------------
#      Train loss: 0.30471608, accuracy: 92.18%
# Validation loss: 0.45094237, accuracy: 87.97%
#       Best loss: 0.45097157 at epoch 77
#    Elapsed time: 02:22:22
#       Timestamp: 2017/10/17 09:31:43
# -------------- EPOCH   85/1001 --------------
#      Train loss: 0.30335999, accuracy: 92.19%
# Validation loss: 0.45145139, accuracy: 88.04%
#       Best loss: 0.45094237 at epoch 84
#    Elapsed time: 02:24:01
#       Timestamp: 2017/10/17 09:33:23
# -------------- EPOCH   86/1001 --------------
#      Train loss: 0.30132392, accuracy: 92.28%
# Validation loss: 0.45255798, accuracy: 88.02%
#       Best loss: 0.45094237 at epoch 84
#    Elapsed time: 02:25:40
#       Timestamp: 2017/10/17 09:35:01
# -------------- EPOCH   87/1001 --------------
#      Train loss: 0.29989937, accuracy: 92.29%
# Validation loss: 0.45253822, accuracy: 88.05%
#       Best loss: 0.45094237 at epoch 84
#    Elapsed time: 02:27:19
#       Timestamp: 2017/10/17 09:36:41
# -------------- EPOCH   88/1001 --------------
#      Train loss: 0.30055049, accuracy: 92.33%
# Validation loss: 0.45262223, accuracy: 88.13%
#       Best loss: 0.45094237 at epoch 84
#    Elapsed time: 02:28:59
#       Timestamp: 2017/10/17 09:38:20
# -------------- EPOCH   89/1001 --------------
#      Train loss: 0.29807657, accuracy: 92.28%
# Validation loss: 0.45374221, accuracy: 88.02%
#       Best loss: 0.45094237 at epoch 84
#    Elapsed time: 02:30:38
#       Timestamp: 2017/10/17 09:40:00
# -------------- EPOCH   90/1001 --------------
#      Train loss: 0.29734844, accuracy: 92.34%
# Validation loss: 0.44957212, accuracy: 88.08%
#       Best loss: 0.45094237 at epoch 84
#    Elapsed time: 02:32:18
#       Timestamp: 2017/10/17 09:41:39
# -------------- EPOCH   91/1001 --------------
#      Train loss: 0.29659981, accuracy: 92.39%
# Validation loss: 0.45004281, accuracy: 88.10%
#       Best loss: 0.44957212 at epoch 90
#    Elapsed time: 02:33:57
#       Timestamp: 2017/10/17 09:43:19
# -------------- EPOCH   92/1001 --------------
#      Train loss: 0.29522589, accuracy: 92.33%
# Validation loss: 0.45311400, accuracy: 88.07%
#       Best loss: 0.44957212 at epoch 90
#    Elapsed time: 02:35:37
#       Timestamp: 2017/10/17 09:44:59
# -------------- EPOCH   93/1001 --------------
#      Train loss: 0.29487491, accuracy: 92.37%
# Validation loss: 0.45467970, accuracy: 88.03%
#       Best loss: 0.44957212 at epoch 90
#    Elapsed time: 02:37:17
#       Timestamp: 2017/10/17 09:46:39
# -------------- EPOCH   94/1001 --------------
#      Train loss: 0.29363170, accuracy: 92.37%
# Validation loss: 0.45168331, accuracy: 88.15%
#       Best loss: 0.44957212 at epoch 90
#    Elapsed time: 02:38:57
#       Timestamp: 2017/10/17 09:48:19
# -------------- EPOCH   95/1001 --------------
#      Train loss: 0.29306060, accuracy: 92.46%
# Validation loss: 0.45085236, accuracy: 88.22%
#       Best loss: 0.44957212 at epoch 90
#    Elapsed time: 02:40:37
#       Timestamp: 2017/10/17 09:49:58
# -------------- EPOCH   96/1001 --------------
#      Train loss: 0.29289287, accuracy: 92.47%
# Validation loss: 0.45206285, accuracy: 88.07%
#       Best loss: 0.44957212 at epoch 90
#    Elapsed time: 02:42:17
#       Timestamp: 2017/10/17 09:51:38
# -------------- EPOCH   97/1001 --------------
#      Train loss: 0.29354033, accuracy: 92.49%
# Validation loss: 0.45107421, accuracy: 88.18%
#       Best loss: 0.44957212 at epoch 90
#    Elapsed time: 02:43:58
#       Timestamp: 2017/10/17 09:53:19
# -------------- EPOCH   98/1001 --------------
#      Train loss: 0.29125172, accuracy: 92.47%
# Validation loss: 0.45160657, accuracy: 88.29%
#       Best loss: 0.44957212 at epoch 90
#    Elapsed time: 02:45:37
#       Timestamp: 2017/10/17 09:54:59
# -------------- EPOCH   99/1001 --------------
#      Train loss: 0.28921679, accuracy: 92.52%
# Validation loss: 0.44985875, accuracy: 88.33%
#       Best loss: 0.44957212 at epoch 90
#    Elapsed time: 02:47:16
#       Timestamp: 2017/10/17 09:56:38
# -------------- EPOCH  100/1001 --------------
#      Train loss: 0.28991175, accuracy: 92.53%
# Validation loss: 0.45454779, accuracy: 88.06%
#       Best loss: 0.44957212 at epoch 90
#    Elapsed time: 02:48:55
#       Timestamp: 2017/10/17 09:58:17
# -------------- EPOCH  101/1001 --------------
#      Train loss: 0.28844729, accuracy: 92.53%
# Validation loss: 0.45207325, accuracy: 88.13%
#       Best loss: 0.44957212 at epoch 90
#    Elapsed time: 02:50:34
#       Timestamp: 2017/10/17 09:59:55
# -------------- EPOCH  102/1001 --------------
#      Train loss: 0.28763688, accuracy: 92.55%
# Validation loss: 0.44669998, accuracy: 88.24%
#       Best loss: 0.44957212 at epoch 90
#    Elapsed time: 02:52:12
#       Timestamp: 2017/10/17 10:01:33
# -------------- EPOCH  103/1001 --------------
#      Train loss: 0.28690422, accuracy: 92.60%
# Validation loss: 0.45022088, accuracy: 88.29%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 02:53:50
#       Timestamp: 2017/10/17 10:03:12
# -------------- EPOCH  104/1001 --------------
#      Train loss: 0.28584448, accuracy: 92.65%
# Validation loss: 0.45269164, accuracy: 88.33%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 02:55:28
#       Timestamp: 2017/10/17 10:04:50
# -------------- EPOCH  105/1001 --------------
#      Train loss: 0.28614226, accuracy: 92.63%
# Validation loss: 0.45124120, accuracy: 88.25%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 02:57:07
#       Timestamp: 2017/10/17 10:06:28
# -------------- EPOCH  106/1001 --------------
#      Train loss: 0.28515413, accuracy: 92.65%
# Validation loss: 0.44995925, accuracy: 88.31%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 02:58:45
#       Timestamp: 2017/10/17 10:08:06
# -------------- EPOCH  107/1001 --------------
#      Train loss: 0.28620088, accuracy: 92.65%
# Validation loss: 0.45242119, accuracy: 88.37%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:00:23
#       Timestamp: 2017/10/17 10:09:44
# -------------- EPOCH  108/1001 --------------
#      Train loss: 0.28409407, accuracy: 92.70%
# Validation loss: 0.45356613, accuracy: 88.21%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:02:01
#       Timestamp: 2017/10/17 10:11:22
# -------------- EPOCH  109/1001 --------------
#      Train loss: 0.28219551, accuracy: 92.70%
# Validation loss: 0.45678633, accuracy: 88.26%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:03:39
#       Timestamp: 2017/10/17 10:13:01
# -------------- EPOCH  110/1001 --------------
#      Train loss: 0.28270516, accuracy: 92.73%
# Validation loss: 0.45489118, accuracy: 88.20%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:05:18
#       Timestamp: 2017/10/17 10:14:39
# -------------- EPOCH  111/1001 --------------
#      Train loss: 0.28220168, accuracy: 92.66%
# Validation loss: 0.45829758, accuracy: 88.33%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:06:56
#       Timestamp: 2017/10/17 10:16:18
# -------------- EPOCH  112/1001 --------------
#      Train loss: 0.28140265, accuracy: 92.75%
# Validation loss: 0.45031196, accuracy: 88.44%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:08:35
#       Timestamp: 2017/10/17 10:17:56
# -------------- EPOCH  113/1001 --------------
#      Train loss: 0.28015128, accuracy: 92.70%
# Validation loss: 0.45798293, accuracy: 88.14%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:10:14
#       Timestamp: 2017/10/17 10:19:36
# -------------- EPOCH  114/1001 --------------
#      Train loss: 0.27912691, accuracy: 92.76%
# Validation loss: 0.45652550, accuracy: 88.23%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:11:53
#       Timestamp: 2017/10/17 10:21:15
# -------------- EPOCH  115/1001 --------------
#      Train loss: 0.28099951, accuracy: 92.81%
# Validation loss: 0.45761287, accuracy: 88.22%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:13:32
#       Timestamp: 2017/10/17 10:22:53
# -------------- EPOCH  116/1001 --------------
#      Train loss: 0.27793318, accuracy: 92.81%
# Validation loss: 0.45405459, accuracy: 88.26%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:15:12
#       Timestamp: 2017/10/17 10:24:33
# -------------- EPOCH  117/1001 --------------
#      Train loss: 0.27825746, accuracy: 92.78%
# Validation loss: 0.45376518, accuracy: 88.25%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:16:52
#       Timestamp: 2017/10/17 10:26:14
# -------------- EPOCH  118/1001 --------------
#      Train loss: 0.27869320, accuracy: 92.78%
# Validation loss: 0.45714155, accuracy: 88.29%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:18:32
#       Timestamp: 2017/10/17 10:27:53
# -------------- EPOCH  119/1001 --------------
#      Train loss: 0.27732465, accuracy: 92.80%
# Validation loss: 0.45565683, accuracy: 88.35%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:20:11
#       Timestamp: 2017/10/17 10:29:33
# -------------- EPOCH  120/1001 --------------
#      Train loss: 0.27689499, accuracy: 92.90%
# Validation loss: 0.45097136, accuracy: 88.33%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:21:50
#       Timestamp: 2017/10/17 10:31:12
# -------------- EPOCH  121/1001 --------------
#      Train loss: 0.27704370, accuracy: 92.88%
# Validation loss: 0.45155537, accuracy: 88.57%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:23:29
#       Timestamp: 2017/10/17 10:32:51
# -------------- EPOCH  122/1001 --------------
#      Train loss: 0.27466056, accuracy: 92.89%
# Validation loss: 0.45991537, accuracy: 88.26%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:25:08
#       Timestamp: 2017/10/17 10:34:30
# -------------- EPOCH  123/1001 --------------
#      Train loss: 0.27422619, accuracy: 92.93%
# Validation loss: 0.45432648, accuracy: 88.50%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:26:46
#       Timestamp: 2017/10/17 10:36:08
# -------------- EPOCH  124/1001 --------------
#      Train loss: 0.27358729, accuracy: 92.91%
# Validation loss: 0.45658138, accuracy: 88.45%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:28:25
#       Timestamp: 2017/10/17 10:37:46
# -------------- EPOCH  125/1001 --------------
#      Train loss: 0.27298775, accuracy: 92.92%
# Validation loss: 0.45533949, accuracy: 88.50%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:30:03
#       Timestamp: 2017/10/17 10:39:25
# -------------- EPOCH  126/1001 --------------
#      Train loss: 0.27210915, accuracy: 92.94%
# Validation loss: 0.45341316, accuracy: 88.50%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:31:41
#       Timestamp: 2017/10/17 10:41:03
# -------------- EPOCH  127/1001 --------------
#      Train loss: 0.27246231, accuracy: 92.92%
# Validation loss: 0.45953625, accuracy: 88.40%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:33:20
#       Timestamp: 2017/10/17 10:42:41
# -------------- EPOCH  128/1001 --------------
#      Train loss: 0.27130017, accuracy: 92.96%
# Validation loss: 0.45725468, accuracy: 88.36%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:34:58
#       Timestamp: 2017/10/17 10:44:20
# -------------- EPOCH  129/1001 --------------
#      Train loss: 0.27259785, accuracy: 92.96%
# Validation loss: 0.45725942, accuracy: 88.46%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:36:36
#       Timestamp: 2017/10/17 10:45:58
# -------------- EPOCH  130/1001 --------------
#      Train loss: 0.27096197, accuracy: 93.04%
# Validation loss: 0.46095484, accuracy: 88.46%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:38:15
#       Timestamp: 2017/10/17 10:47:36
# -------------- EPOCH  131/1001 --------------
#      Train loss: 0.27109194, accuracy: 92.98%
# Validation loss: 0.45975053, accuracy: 88.37%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:39:53
#       Timestamp: 2017/10/17 10:49:15
# -------------- EPOCH  132/1001 --------------
#      Train loss: 0.27035329, accuracy: 93.04%
# Validation loss: 0.45752567, accuracy: 88.54%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:41:32
#       Timestamp: 2017/10/17 10:50:53
# -------------- EPOCH  133/1001 --------------
#      Train loss: 0.26866671, accuracy: 93.03%
# Validation loss: 0.45582446, accuracy: 88.58%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:43:10
#       Timestamp: 2017/10/17 10:52:31
# -------------- EPOCH  134/1001 --------------
#      Train loss: 0.26854768, accuracy: 93.08%
# Validation loss: 0.45488656, accuracy: 88.53%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:44:48
#       Timestamp: 2017/10/17 10:54:10
# -------------- EPOCH  135/1001 --------------
#      Train loss: 0.26969028, accuracy: 93.04%
# Validation loss: 0.46236226, accuracy: 88.28%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:46:26
#       Timestamp: 2017/10/17 10:55:48
# -------------- EPOCH  136/1001 --------------
#      Train loss: 0.26801103, accuracy: 93.05%
# Validation loss: 0.45817980, accuracy: 88.41%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:48:05
#       Timestamp: 2017/10/17 10:57:26
# -------------- EPOCH  137/1001 --------------
#      Train loss: 0.26760131, accuracy: 93.05%
# Validation loss: 0.45420587, accuracy: 88.50%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:49:43
#       Timestamp: 2017/10/17 10:59:04
# -------------- EPOCH  138/1001 --------------
#      Train loss: 0.26795956, accuracy: 93.08%
# Validation loss: 0.45812273, accuracy: 88.51%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:51:21
#       Timestamp: 2017/10/17 11:00:43
# -------------- EPOCH  139/1001 --------------
#      Train loss: 0.26689506, accuracy: 93.11%
# Validation loss: 0.45183593, accuracy: 88.60%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:53:00
#       Timestamp: 2017/10/17 11:02:21
# -------------- EPOCH  140/1001 --------------
#      Train loss: 0.26630056, accuracy: 93.11%
# Validation loss: 0.45750958, accuracy: 88.65%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:54:38
#       Timestamp: 2017/10/17 11:03:59
# -------------- EPOCH  141/1001 --------------
#      Train loss: 0.26561132, accuracy: 93.15%
# Validation loss: 0.45874527, accuracy: 88.70%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:56:16
#       Timestamp: 2017/10/17 11:05:38
# -------------- EPOCH  142/1001 --------------
#      Train loss: 0.26473850, accuracy: 93.12%
# Validation loss: 0.45995274, accuracy: 88.54%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:57:54
#       Timestamp: 2017/10/17 11:07:16
# -------------- EPOCH  143/1001 --------------
#      Train loss: 0.26528835, accuracy: 93.11%
# Validation loss: 0.45890799, accuracy: 88.58%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 03:59:32
#       Timestamp: 2017/10/17 11:08:54
# -------------- EPOCH  144/1001 --------------
#      Train loss: 0.26493993, accuracy: 93.16%
# Validation loss: 0.46008858, accuracy: 88.60%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:01:11
#       Timestamp: 2017/10/17 11:10:32
# -------------- EPOCH  145/1001 --------------
#      Train loss: 0.26419446, accuracy: 93.15%
# Validation loss: 0.46083683, accuracy: 88.59%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:02:49
#       Timestamp: 2017/10/17 11:12:10
# -------------- EPOCH  146/1001 --------------
#      Train loss: 0.26421914, accuracy: 93.20%
# Validation loss: 0.45858178, accuracy: 88.65%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:04:27
#       Timestamp: 2017/10/17 11:13:49
# -------------- EPOCH  147/1001 --------------
#      Train loss: 0.26311702, accuracy: 93.22%
# Validation loss: 0.46041024, accuracy: 88.62%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:06:05
#       Timestamp: 2017/10/17 11:15:27
# -------------- EPOCH  148/1001 --------------
#      Train loss: 0.26297000, accuracy: 93.21%
# Validation loss: 0.46159106, accuracy: 88.55%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:07:44
#       Timestamp: 2017/10/17 11:17:05
# -------------- EPOCH  149/1001 --------------
#      Train loss: 0.26310369, accuracy: 93.21%
# Validation loss: 0.46028382, accuracy: 88.54%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:09:22
#       Timestamp: 2017/10/17 11:18:44
# -------------- EPOCH  150/1001 --------------
#      Train loss: 0.26261684, accuracy: 93.22%
# Validation loss: 0.46049508, accuracy: 88.63%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:11:00
#       Timestamp: 2017/10/17 11:20:22
# -------------- EPOCH  151/1001 --------------
#      Train loss: 0.26147008, accuracy: 93.27%
# Validation loss: 0.46547985, accuracy: 88.70%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:12:38
#       Timestamp: 2017/10/17 11:22:00
# -------------- EPOCH  152/1001 --------------
#      Train loss: 0.26196828, accuracy: 93.25%
# Validation loss: 0.45851606, accuracy: 88.74%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:14:17
#       Timestamp: 2017/10/17 11:23:38
# -------------- EPOCH  153/1001 --------------
#      Train loss: 0.26093867, accuracy: 93.23%
# Validation loss: 0.45581725, accuracy: 88.62%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:15:55
#       Timestamp: 2017/10/17 11:25:16
# -------------- EPOCH  154/1001 --------------
#      Train loss: 0.26220575, accuracy: 93.26%
# Validation loss: 0.45566890, accuracy: 88.71%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:17:33
#       Timestamp: 2017/10/17 11:26:55
# -------------- EPOCH  155/1001 --------------
#      Train loss: 0.26102960, accuracy: 93.28%
# Validation loss: 0.46553695, accuracy: 88.60%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:19:11
#       Timestamp: 2017/10/17 11:28:33
# -------------- EPOCH  156/1001 --------------
#      Train loss: 0.25975055, accuracy: 93.27%
# Validation loss: 0.46461034, accuracy: 88.54%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:20:50
#       Timestamp: 2017/10/17 11:30:11
# -------------- EPOCH  157/1001 --------------
#      Train loss: 0.25895950, accuracy: 93.26%
# Validation loss: 0.46426663, accuracy: 88.62%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:22:28
#       Timestamp: 2017/10/17 11:31:49
# -------------- EPOCH  158/1001 --------------
#      Train loss: 0.26005217, accuracy: 93.30%
# Validation loss: 0.46439311, accuracy: 88.57%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:24:06
#       Timestamp: 2017/10/17 11:33:27
# -------------- EPOCH  159/1001 --------------
#      Train loss: 0.25888962, accuracy: 93.30%
# Validation loss: 0.45824042, accuracy: 88.68%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:25:44
#       Timestamp: 2017/10/17 11:35:06
# -------------- EPOCH  160/1001 --------------
#      Train loss: 0.25863373, accuracy: 93.32%
# Validation loss: 0.46121654, accuracy: 88.63%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:27:22
#       Timestamp: 2017/10/17 11:36:44
# -------------- EPOCH  161/1001 --------------
#      Train loss: 0.25883287, accuracy: 93.35%
# Validation loss: 0.45989901, accuracy: 88.79%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:29:00
#       Timestamp: 2017/10/17 11:38:22
# -------------- EPOCH  162/1001 --------------
#      Train loss: 0.25858134, accuracy: 93.33%
# Validation loss: 0.46624279, accuracy: 88.61%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:30:39
#       Timestamp: 2017/10/17 11:40:00
# -------------- EPOCH  163/1001 --------------
#      Train loss: 0.25836650, accuracy: 93.34%
# Validation loss: 0.46312389, accuracy: 88.68%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:32:17
#       Timestamp: 2017/10/17 11:41:38
# -------------- EPOCH  164/1001 --------------
#      Train loss: 0.25833267, accuracy: 93.33%
# Validation loss: 0.46136126, accuracy: 88.63%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:33:55
#       Timestamp: 2017/10/17 11:43:17
# -------------- EPOCH  165/1001 --------------
#      Train loss: 0.25680926, accuracy: 93.37%
# Validation loss: 0.46014300, accuracy: 88.73%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:35:33
#       Timestamp: 2017/10/17 11:44:55
# -------------- EPOCH  166/1001 --------------
#      Train loss: 0.25635034, accuracy: 93.37%
# Validation loss: 0.46004418, accuracy: 88.71%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:37:12
#       Timestamp: 2017/10/17 11:46:34
# -------------- EPOCH  167/1001 --------------
#      Train loss: 0.25551087, accuracy: 93.37%
# Validation loss: 0.46605569, accuracy: 88.68%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:38:50
#       Timestamp: 2017/10/17 11:48:12
# -------------- EPOCH  168/1001 --------------
#      Train loss: 0.25564444, accuracy: 93.38%
# Validation loss: 0.46070492, accuracy: 88.80%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:40:28
#       Timestamp: 2017/10/17 11:49:50
# -------------- EPOCH  169/1001 --------------
#      Train loss: 0.25545084, accuracy: 93.36%
# Validation loss: 0.46515447, accuracy: 88.57%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:42:06
#       Timestamp: 2017/10/17 11:51:28
# -------------- EPOCH  170/1001 --------------
#      Train loss: 0.25594842, accuracy: 93.37%
# Validation loss: 0.46385938, accuracy: 88.79%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:43:44
#       Timestamp: 2017/10/17 11:53:06
# -------------- EPOCH  171/1001 --------------
#      Train loss: 0.25572321, accuracy: 93.37%
# Validation loss: 0.46118835, accuracy: 88.79%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:45:23
#       Timestamp: 2017/10/17 11:54:44
# -------------- EPOCH  172/1001 --------------
#      Train loss: 0.25402018, accuracy: 93.40%
# Validation loss: 0.47068447, accuracy: 88.69%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:47:01
#       Timestamp: 2017/10/17 11:56:23
# -------------- EPOCH  173/1001 --------------
#      Train loss: 0.25486884, accuracy: 93.39%
# Validation loss: 0.46931449, accuracy: 88.66%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:48:39
#       Timestamp: 2017/10/17 11:58:01
# -------------- EPOCH  174/1001 --------------
#      Train loss: 0.25436565, accuracy: 93.39%
# Validation loss: 0.46995842, accuracy: 88.71%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:50:18
#       Timestamp: 2017/10/17 11:59:39
# -------------- EPOCH  175/1001 --------------
#      Train loss: 0.25378564, accuracy: 93.40%
# Validation loss: 0.46805486, accuracy: 88.72%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:51:56
#       Timestamp: 2017/10/17 12:01:17
# -------------- EPOCH  176/1001 --------------
#      Train loss: 0.25420350, accuracy: 93.42%
# Validation loss: 0.46449891, accuracy: 88.73%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:53:34
#       Timestamp: 2017/10/17 12:02:56
# -------------- EPOCH  177/1001 --------------
#      Train loss: 0.25352111, accuracy: 93.41%
# Validation loss: 0.46425027, accuracy: 88.75%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:55:12
#       Timestamp: 2017/10/17 12:04:34
# -------------- EPOCH  178/1001 --------------
#      Train loss: 0.25347668, accuracy: 93.43%
# Validation loss: 0.47198319, accuracy: 88.51%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:56:50
#       Timestamp: 2017/10/17 12:06:12
# -------------- EPOCH  179/1001 --------------
#      Train loss: 0.25157475, accuracy: 93.44%
# Validation loss: 0.46905494, accuracy: 88.65%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 04:58:28
#       Timestamp: 2017/10/17 12:07:50
# -------------- EPOCH  180/1001 --------------
#      Train loss: 0.25167572, accuracy: 93.45%
# Validation loss: 0.46859935, accuracy: 88.71%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 05:00:06
#       Timestamp: 2017/10/17 12:09:28
# -------------- EPOCH  181/1001 --------------
#      Train loss: 0.25109187, accuracy: 93.45%
# Validation loss: 0.47172591, accuracy: 88.66%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 05:01:44
#       Timestamp: 2017/10/17 12:11:05
# -------------- EPOCH  182/1001 --------------
#      Train loss: 0.25250477, accuracy: 93.46%
# Validation loss: 0.46864128, accuracy: 88.64%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 05:03:21
#       Timestamp: 2017/10/17 12:12:43
# -------------- EPOCH  183/1001 --------------
#      Train loss: 0.25130564, accuracy: 93.45%
# Validation loss: 0.46909896, accuracy: 88.75%
#       Best loss: 0.44669998 at epoch 102
#    Elapsed time: 05:04:59
#       Timestamp: 2017/10/17 12:14:21
# INFO:tensorflow:Restoring parameters from /home/wastaljoey/TSC1/early_stopping_checkpoint
# Early stopping.
# Best monitored loss was 0.44669998 at epoch 102.
# =============================================
#  Valid loss: 0.44669998, accuracy = 88.24%)
#  Test loss: 2.35605693, accuracy = 45.73%)
#  Total time: 05:05:14
#   Timestamp: 2017/10/17 12:14:35
# Model file: /home/wastaljoey/TSC1/models/k5d32p0.9_k5d64p0.8_k5d128p0.7_fc1024p0.5_no-lrdec_l2_30%_perturbed/model.ckpt
# Train history file: /home/wastaljoey/TSC1/models/k5d32p0.9_k5d64p0.8_k5d128p0.7_fc1024p0.5_no-lrdec_l2_30%_perturbed/train_history

# %%
def get_top_k_predictions(params, X, k = 5):
    """
    Evaluates `X` on a model defined by `params` and returns top 5 predictions.

    Parameters
    ----------
    params    : Parameters
                Structure (`namedtuple`) containing model parameters.
    X         : 
                Testing dataset. 
    k         : 
                Number of top predictions we are interested in.
                
    Returns
    -------
    An array of top k softmax predictions for each example.
    """
    
    # Initialisation routines: generate variable scope, create logger, note start time.
    paths = Paths(params)
    
    # Build the graph
    graph = tf.Graph()
    with graph.as_default():
        # Input data. For the training data, we use a placeholder that will be fed at run time with a training minibatch.
        tf_x = tf.placeholder(tf.float32, shape = (None, params.image_size[0], params.image_size[1], 1))
        is_training = tf.constant(False)
        with tf.variable_scope(paths.var_scope):
            predictions = tf.nn.softmax(model_pass(tf_x, params, is_training))
            top_k_predictions = tf.nn.top_k(predictions, k)

    with tf.Session(graph = graph) as session:
        session.run(tf.global_variables_initializer())
        tf.train.Saver().restore(session, paths.model_path)
        [p] = session.run([top_k_predictions], feed_dict = {
                tf_x : X
            }
        )
        return np.array(p)

# %% [markdown]
# ### Get Accuracy and Loss

# %%
def get_accuracy_and_loss(params,X,y):
    
    #Initialize the path
    paths=Paths(params)
    
    #Build the graph
    graph=tf.Graph()
    with graph.as_default():
        # Input data. For the training data, we use a placeholder that will be fed at run time with a training minibatch.
        tf_x= tf.placeholder(tf.float32, shape = (None, params.image_size[0], params.image_size[1], 1))
        tf_y = tf.placeholder(tf.float32, shape = (None, params.num_classes))
        is_training = tf.constant(False)
        with tf.variable_scope(paths.var_scope):
            logits = model_pass(tf_x, params, is_training)
            predictions = tf.nn.softmax(logits)
            softmax_cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_y)
            
    with tf.Session(graph = graph) as session:
        session.run(tf.global_variables_initializer())  
        tf.train.Saver().restore(session, paths.model_path)
        p = []
        sce = []
        batch_iterator = BatchIterator(batch_size = 128)
        for x_batch, y_batch in batch_iterator(X, y):
            [p_batch, sce_batch] = session.run([predictions, softmax_cross_entropy], feed_dict = {
                    tf_x : x_batch, 
                    tf_y : y_batch,
                    is_training : False
                }
            )
            p.extend(p_batch)
            sce.extend(sce_batch)
        p = np.array(p)
        sce = np.array(sce)
        accuracy = 100.0 * np.sum(np.argmax(p, 1) == np.argmax(y, 1)) / p.shape[0]
        loss = np.mean(sce)
        return (accuracy, loss)

# %% [markdown]
# ### Test Accuracy

# %%
import pickle

test_processed_dataset_file="data/adv_image_4_layers.p"
X_test,y_test=load_pickled_data(test_processed_dataset_file,['features','labels'])


adv_para = Parameters(
    # Data parameters
    num_classes = 43,
    image_size = (32, 32),
    # Training parameters
    batch_size = 256,
    max_epochs = 500,
    log_epoch = 1,
    print_epoch = 1,
    # Optimisations
    learning_rate_decay = False,
    learning_rate = 0.001,
    l2_reg_enabled = True,
    l2_lambda = 0.0001,
    early_stopping_enabled = True,
    early_stopping_patience = 50,
    resume_training = True,
    # Layers architecture
    conv1_k = 7, conv1_d = 16, conv1_p = 0.9,
    conv2_k = 7, conv2_d = 32, conv2_p = 0.8,
    conv3_k = 5, conv3_d = 64, conv3_p = 0.7,
    conv4_k = 3, conv4_d = 128, conv4_p = 0.6,
    fc4_size = 1024, fc4_p = 0.5,
    adv_training=None,
    perturbed_ratio= None
)



accuracy,loss=get_accuracy_and_loss(adv_para,X_test,y_test)
print('Accuracy of pure data on advesarial model',accuracy)
print(loss)
# Out:
# INFO:tensorflow:Restoring parameters from /home/wastaljoey/TSC1/models/4layers_k7d16p0.9_k7d32p0.8_k5d64p0.7_fc1024p0.5_no-lrdec_l2/model.ckpt
# Accuracy of pure data on advesarial model 42.4197131893
# 3.15729

# %% [markdown]
# #  FGDM to fool the model

# %%
def fgm(x, preds, grad, y=None, eps=0.007, ord=2,
        clip_min=None, clip_max=None,
        targeted=False):
    """
    TensorFlow implementation of the Fast Gradient Method.
    :param x: the input placeholder
    :param preds: the model's output tensor (the attack expects the
                  probabilities, i.e., the output of the softmax)
    :param y: (optional) A placeholder for the model labels. If targeted
              is true, then provide the target label. Otherwise, only provide
              this parameter if you'd like to use true labels when crafting
              adversarial samples. Otherwise, model predictions are used as
              labels to avoid the "label leaking" effect (explained in this
              paper: https://arxiv.org/abs/1611.01236). Default is None.
              Labels should be one-hot-encoded.
    :param eps: the epsilon (input variation parameter)
    :param ord: (optional) Order of the norm (mimics NumPy).
                Possible values: np.inf, 1 or 2.
    :param clip_min: Minimum float value for adversarial example components
    :param clip_max: Maximum float value for adversarial example components
    :param targeted: Is the attack targeted or untargeted? Untargeted, the
                     default, will try to make the label incorrect. Targeted
                     will instead try to move in the direction of being more
                     like y.
    :return: a tensor for the adversarial example
    """

    if y is None:
        # Using model predictions as ground truth to avoid label leaking
        preds_max = tf.reduce_max(preds, 1, keep_dims=True)
        y = tf.to_float(tf.equal(preds, preds_max))
    y = y / tf.reduce_sum(y, 1, keep_dims=True)

    # Compute loss
    #$loss = loss
    #if targeted:
        #loss = -loss

    # Define gradient of loss wrt input
    grad=grad

    if ord == np.inf:
        # Take sign of gradient
        normalized_grad = tf.sign(grad)
        # The following line should not change the numerical results.
        # It applies only because `normalized_grad` is the output of
        # a `sign` op, which has zero derivative anyway.
        # It should not be applied for the other norms, where the
        # perturbation has a non-zero derivative.
        normalized_grad = tf.stop_gradient(normalized_grad)
    elif ord == 1:
        red_ind = list(xrange(1, len(x.get_shape())))
        normalized_grad = grad / tf.reduce_sum(tf.abs(grad),
                                               reduction_indices=red_ind,
                                               keep_dims=True)
    elif ord == 2:
        red_ind = list(xrange(1, len(x.get_shape())))
        square = tf.reduce_sum(tf.square(grad),
                               reduction_indices=red_ind,
                               keep_dims=True)
        normalized_grad = grad / tf.sqrt(square)
    else:
        raise NotImplementedError("Only L-inf, L1 and L2 norms are "
                                  "currently implemented.")

    # Multiply by constant epsilon
    scaled_grad = eps * normalized_grad

    # Add perturbation to original example to obtain adversarial example
    adv_x = x + scaled_grad

    # If clipping is needed, reset all values outside of [clip_min, clip_max]
    if (clip_min is not None) and (clip_max is not None):
        adv_x = tf.clip_by_value(adv_x, clip_min, clip_max)

    return adv_x

# %%
def get_loss(params, X,y):
     # Initialisation routines: generate variable scope, create logger, note start time.
    paths = Paths(params)
    
    # Build the graph
    graph = tf.Graph()
    with graph.as_default():
        # Input data. For the training data, we use a placeholder that will be fed at run time with a training minibatch.
        tf_x = tf.placeholder(tf.float32, shape = (None, params.image_size[0], params.image_size[1], 1))
        is_training = tf.constant(False)
        with tf.variable_scope(paths.var_scope):
            logits=model_pass(tf_x, params, is_training)
            loss=tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y)
            grad = tf.gradients(loss, tf_x)
            predictions = tf.nn.softmax(logits)
            
        with tf.Session(graph=graph) as sess:
            sess.run(tf.global_variables_initializer())
            tf.train.Saver().restore(sess, paths.model_path)
            [l,p,g]=sess.run([loss,predictions,grad],feed_dict={tf_x:X})
            
            return l,p,np.array(g)

# %%
import matplotlib.gridspec as gridspec
from skimage import io
import os

def plot_image_statistics(ori_predictions,adv_predictions, index):
    """
    Plots prediction statistics for a single example.

    Parameters
    ----------
    predictions   : 
                    Array of predictions.
    index         : 
                    Index of the example we need to plot statistics for
    """
    # Prepare original and preprocessed images
    original = io.imread(os.getcwd() + '/data/Example/' + "example_{0:0>5}".format(i + 1) + '.png')
    preprocessed = X_custom[index].reshape(32, 32)
        
    # Prepare the grid
    pyplot.figure(figsize = (6, 4))
    gridspec.GridSpec(2, 2)
    
    # Plot original image
    pyplot.subplot2grid((2, 2), (0, 0), colspan=1, rowspan=1)
    pyplot.imshow(original)
    pyplot.axis('off')

    # Plot preprocessed image
    pyplot.subplot2grid((2, 2), (1, 0), colspan=1, rowspan=1)
    pyplot.imshow(preprocessed, cmap='gray')
    pyplot.axis('off')
    
    #Plot original predictions
    pyplot.subplot2grid((2, 2), (0, 1), colspan=1, rowspan=1)
    pyplot.barh(np.arange(5)+.5, ori_predictions[0][index], align='center')
    pyplot.yticks(np.arange(5)+.5, signnames[ori_predictions[1][index].astype(int)])
    pyplot.tick_params(axis='both', which='both', labelleft='off', labelright='on', labeltop='off', labelbottom='off')
    

    # Plot adversarial predictions
    pyplot.subplot2grid((2, 2), (1, 1), colspan=1, rowspan=1)
    pyplot.barh(np.arange(5)+.5, adv_predictions[0][index], align='center')
    pyplot.yticks(np.arange(5)+.5, signnames[adv_predictions[1][index].astype(int)])
    pyplot.tick_params(axis='both', which='both', labelleft='off', labelright='on', labeltop='off', labelbottom='off')
    
    pyplot.show()



parameters = Parameters(
    # Data parameters
    num_classes = 43,
    image_size = (32, 32),
    # Training parameters
    batch_size = 256,
    max_epochs = 1001,
    log_epoch = 1,
    print_epoch = 1,
    # Optimisations
    learning_rate_decay = False,
    learning_rate = 0.0001,
    l2_reg_enabled = True,
    l2_lambda = 0.0001,
    early_stopping_enabled = True,
    early_stopping_patience = 100,
    resume_training = True,
    # Layers architecture
    conv1_k = 5, conv1_d = 32, conv1_p = 0.9,
    conv2_k = 5, conv2_d = 64, conv2_p = 0.8,
    conv3_k = 5, conv3_d = 128, conv3_p = 0.7,
    fc4_size = 1024, fc4_p = 0.5
)
    
# Load images from .png files to `X_custom` NumPy array
X_custom = np.empty([0, 32, 32, 3], dtype = np.int32)
for i in range(35):
    image = io.imread(os.getcwd() + '/data/Example/' + "example_{0:0>5}".format(i + 1) + '.png')
    X_custom = np.append(X_custom, [image[:, :, :3]], axis = 0)

# Provide labels of the captured images:
y_custom = np.array([
    21, # "example_00001"
    39, # "example_00002"
    17, # "example_00003"
    17, # "example_00004"
    17, # "example_00005"
    39, # "example_00006"
    39, # "example_00007"
    40, # "example_00008"
    40, # "example_00009"
    34, # "example_00010"
    28, # "example_00011"
    39, # "example_00012"
    0, # "example_00013"
    17, # "example_00014"
    38, # "example_00015"
    13, # "example_00016"
    40, # "example_00017"
    13, # "example_00018"
    38, # "example_00019"
    38, # "example_00020"
    11, # "example_00021"
    0, # "example_00022"
    28, # "example_00023"
    0, # "example_00024"
    32, # "example_00028"
    40, # "example_00029"
    28, # "example_00030"
    40, # "example_00031"
    40, # "example_00032"
    28, # "example_00033"
    24, # "example_00034"
    0, # "example_00035"
    0, # "example_00036"
    0, # "example_00037"
    0 # "example_00038"
])

# Preprocess and get predictions based on the current model
X_custom, y_custom_p = preprocess_dataset(X_custom,y_custom,shuffle=None)
loss,preds,grad=get_loss(parameters,X_custom,y_custom_p)
adv_x=fgm(x=X_custom,preds=preds,grad=grad, y=None, eps=0.07, ord=np.inf,
        clip_min=None, clip_max=None,
        targeted=False)

sess=tf.Session()
adv_image=sess.run(adv_x)
sess.close()
print(adv_image.shape)
adv_predictions=get_top_k_predictions(parameters,adv_image.reshape(35,32,32,1),k=5)
ori_predictions=get_top_k_predictions(parameters,X_custom,k=5)
#print(predictions[1])
# Out:
# Preprocessing dataset with 35 examples:
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100%
# INFO:tensorflow:Restoring parameters from C:\Users\wasta\Desktop\TSC/models/k5d32p0.9_k5d64p0.8_k5d128p0.7_fc1024p0.5_no-lrdec_l2/model.ckpt
# (1, 35, 32, 32, 1)
# INFO:tensorflow:Restoring parameters from C:\Users\wasta\Desktop\TSC/models/k5d32p0.9_k5d64p0.8_k5d128p0.7_fc1024p0.5_no-lrdec_l2/model.ckpt
# INFO:tensorflow:Restoring parameters from C:\Users\wasta\Desktop\TSC/models/k5d32p0.9_k5d64p0.8_k5d128p0.7_fc1024p0.5_no-lrdec_l2/model.ckpt

# %%
# For every example plot original image, preprocessed image, and model predictions.
for i in range(35):
    print("Actual class: ", signnames[y_custom[i]] if y_custom[i] != 99 else "None")
    plot_image_statistics(ori_predictions,adv_predictions, i)
    print("---------------------------------------------------------------------------------------------------\n")
# Out:
# Actual class:  Double curve
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Keep left
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  No entry
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  No entry
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  No entry
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Keep left
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Keep left
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Roundabout mandatory
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Roundabout mandatory
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Turn left ahead
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Children crossing
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Keep left
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Speed limit (20km/h)
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  No entry
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Keep right
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Yield
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Roundabout mandatory
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Yield
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Keep right
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Keep right
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Right-of-way at the next intersection
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Speed limit (20km/h)
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Children crossing
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Speed limit (20km/h)
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  End of all speed and passing limits
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Roundabout mandatory
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Children crossing
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Roundabout mandatory
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Roundabout mandatory
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Children crossing
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Road narrows on the right
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Speed limit (20km/h)
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Speed limit (20km/h)
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Speed limit (20km/h)
# ---------------------------------------------------------------------------------------------------
#
# Actual class:  Speed limit (20km/h)
# ---------------------------------------------------------------------------------------------------

# %%
# adv_images_dataset_file="data/adv_images.p"
X_adv,y_adv=load_pickled_data(adv_images_dataset_file,['features','labels'])

parameters = Parameters(
    # Data parameters
    num_classes = 43,
    image_size = (32, 32),
    # Training parameters
    batch_size = 256,
    max_epochs = 1001,
    log_epoch = 1,
    print_epoch = 1,
    # Optimisations
    learning_rate_decay = False,
    learning_rate = 0.0001,
    l2_reg_enabled = True,
    l2_lambda = 0.0001,
    early_stopping_enabled = True,
    early_stopping_patience = 100,
    resume_training = True,
    # Layers architecture
    conv1_k = 5, conv1_d = 32, conv1_p = 0.9,
    conv2_k = 5, conv2_d = 64, conv2_p = 0.8,
    conv3_k = 5, conv3_d = 128, conv3_p = 0.7,
    fc4_size = 1024, fc4_p = 0.5
)

batch_iterator=BatchIterator(batch_size=2500)
f=0
for X_batch,y_batch in batch_iterator(X_adv,y_adv):
    f=f+1
    print(f)
    loss,preds,grad=get_loss(parameters,X_batch,y_batch)
    adv_x=fgm(x=X_batch,preds=preds,grad=grad, y=None, eps=0.3, ord=np.inf,clip_min=None, clip_max=None,targeted=False)
    sess=tf.Session()
    adv_image_batch=sess.run(adv_x)
    sess.close()
    if f==1:
        adv_image=adv_image_batch
    else:
        adv_image=np.concatenate((adv_image,adv_image_batch),axis=1)

print(adv_image.shape)
adv_predictions=get_top_k_predictions(parameters,adv_image.reshape(4952,32,32,1),k=1)
ori_predictions=get_top_k_predictions(parameters,X_adv,k=1)
print(adv_predictions.shape[1])
accuracy=100*np.sum(adv_predictions[1]==ori_predictions[1])/adv_predictions.shape[1]
print("Accuracy=",accuracy)
# Out:
# 1
# INFO:tensorflow:Restoring parameters from C:\Users\wasta\Desktop\TSC/models/k5d32p0.9_k5d64p0.8_k5d128p0.7_fc1024p0.5_no-lrdec_l2/model.ckpt
# 2
# INFO:tensorflow:Restoring parameters from C:\Users\wasta\Desktop\TSC/models/k5d32p0.9_k5d64p0.8_k5d128p0.7_fc1024p0.5_no-lrdec_l2/model.ckpt
# (1, 4952, 32, 32, 1)
# INFO:tensorflow:Restoring parameters from C:\Users\wasta\Desktop\TSC/models/k5d32p0.9_k5d64p0.8_k5d128p0.7_fc1024p0.5_no-lrdec_l2/model.ckpt
# INFO:tensorflow:Restoring parameters from C:\Users\wasta\Desktop\TSC/models/k5d32p0.9_k5d64p0.8_k5d128p0.7_fc1024p0.5_no-lrdec_l2/model.ckpt
# 4952
# Accuracy= 7.69386106624

# %% [markdown]
# #  Deepfool Method

# %%
def jacobian_graph(predictions, x, nb_classes):
    """
    Create the Jacobian graph to be ran later in a TF session
    :param predictions: the model's symbolic output (linear output,
        pre-softmax)
    :param x: the input placeholder
    :param nb_classes: the number of classes the model has
    :return:
    """
    # This function will return a list of TF gradients
    list_derivatives = []

    # Define the TF graph elements to compute our derivatives for each class
    for class_ind in range(nb_classes):
        derivatives, = tf.gradients(predictions[:, class_ind], x)
        list_derivatives.append(derivatives)

    return list_derivatives

# %%
def model_argmax(sess, x, predictions, samples, feed):
    """
    Helper function that computes the current class prediction
    :param sess: TF session
    :param x: the input placeholder
    :param predictions: the model's symbolic output
    :param samples: numpy array with input samples (dims must match x)
    :param feed: An optional dictionary that is appended to the feeding
             dictionary before the session runs. Can be used to feed
             the learning phase of a Keras model for instance.
    :return: the argmax output of predictions, i.e. the current predicted class
    """
    feed_dict = {x: samples}
    if feed is not None:
        feed_dict.update(feed)
    probabilities = sess.run(predictions, feed_dict)

    if samples.shape[0] == 1:
        return np.argmax(probabilities)
    else:
        return np.argmax(probabilities, axis=1)

# %%
def deepfool_attack(sess, x, predictions, logits, grads, sample, nb_candidate,
                    overshoot, max_iter, clip_min, clip_max, feed=None):
    """
    TensorFlow implementation of DeepFool.
    Paper link: see https://arxiv.org/pdf/1511.04599.pdf
    :param sess: TF session
    :param x: The input placeholder
    :param predictions: The model's sorted symbolic output of logits, only the
                       top nb_candidate classes are contained
    :param logits: The model's unnormalized output tensor (the input to
                   the softmax layer)
    :param grads: Symbolic gradients of the top nb_candidate classes, procuded
                 from gradient_graph
    :param sample: Numpy array with sample input
    :param nb_candidate: The number of classes to test against, i.e.,
                         deepfool only consider nb_candidate classes when
                         attacking(thus accelerate speed). The nb_candidate
                         classes are chosen according to the prediction
                         confidence during implementation.
    :param overshoot: A termination criterion to prevent vanishing updates
    :param max_iter: Maximum number of iteration for DeepFool
    :param clip_min: Minimum value for components of the example returned
    :param clip_max: Maximum value for components of the example returned
    :return: Adversarial examples
    """
    import copy

    adv_x = copy.copy(sample)
    # Initialize the loop variables
    iteration = 0
    current = model_argmax(sess, x, logits, adv_x, feed)
    if current.shape == ():
        current = np.array([current])
    w = np.squeeze(np.zeros(sample.shape[1:]))  # same shape as original image
    r_tot = np.zeros(sample.shape)
    original = current  # use original label as the reference

    #_logger.debug("Starting DeepFool attack up to {} iterations".
     #             format(max_iter))
    # Repeat this main loop until we have achieved misclassification
    while (np.any(current == original) and iteration < max_iter):

        #if iteration % 5 == 0 and iteration > 0:
           # _logger.info("Attack result at iteration {} is {}".format(
            #    iteration,
             #   current))
        gradients = sess.run(grads, feed_dict={x: adv_x})
        predictions_val = sess.run(predictions, feed_dict={x: adv_x})
        #print(gradients)
        for idx in range(sample.shape[0]):
            pert = np.inf
            if current[idx] != original[idx]:
                continue
            for k in range(1, nb_candidate):
                w_k = gradients[idx, k,...] - gradients[idx, 0,...]
                f_k = predictions_val[idx, k] - predictions_val[idx, 0]
                # adding value 0.00001 to prevent f_k = 0
                pert_k = (abs(f_k) + 0.00001) / np.linalg.norm(w_k.flatten())
                if pert_k < pert:
                    pert = pert_k
                    w = w_k
            r_i = pert*w/np.linalg.norm(w)
            r_tot[idx, ...] = r_tot[idx, ...] + r_i

        adv_x = np.clip(r_tot + sample, clip_min, clip_max)
        current = model_argmax(sess, x, logits, adv_x, feed)
        if current.shape == ():
            current = np.array([current])
        # Update loop variables
        iteration = iteration + 1

    # need more revision, including info like how many succeed
   # _logger.info("Attack result at iteration {} is {}".format(iteration,
    #             current))
    #_logger.info("{} out of {}".format(sum(current != original),
     #                                  sample.shape[0]) +
      #           " becomes adversarial examples at iteration {}".format(
       #              iteration))
    # need to clip this image into the given range
    adv_x = np.clip((1+overshoot)*r_tot + sample, clip_min, clip_max)
    return adv_x

# %%
import matplotlib.gridspec as gridspec
from skimage import io
import os

def plot_image_statistics(ori_predictions,adv_predictions, index):
    """
    Plots prediction statistics for a single example.

    Parameters
    ----------
    predictions   : 
                    Array of predictions.
    index         : 
                    Index of the example we need to plot statistics for
    """
    # Prepare original and preprocessed images
    original = io.imread(os.getcwd() + '/data/Example/' + "example_{0:0>5}".format(i + 1) + '.png')
    preprocessed = X_custom[index].reshape(32, 32)
        
    # Prepare the grid
    pyplot.figure(figsize = (6, 4))
    gridspec.GridSpec(2, 2)
    
    # Plot original image
    pyplot.subplot2grid((2, 2), (0, 0), colspan=1, rowspan=1)
    pyplot.imshow(original)
    pyplot.axis('off')

    # Plot preprocessed image
    pyplot.subplot2grid((2, 2), (1, 0), colspan=1, rowspan=1)
    pyplot.imshow(preprocessed, cmap='gray')
    pyplot.axis('off')
    
    #Plot original predictions
    pyplot.subplot2grid((2, 2), (0, 1), colspan=1, rowspan=1)
    pyplot.barh(np.arange(5)+.5, ori_predictions[0][index], align='center')
    pyplot.yticks(np.arange(5)+.5, signnames[ori_predictions[1][index].astype(int)])
    pyplot.tick_params(axis='both', which='both', labelleft='off', labelright='on', labeltop='off', labelbottom='off')
    

    # Plot adversarial predictions
    pyplot.subplot2grid((2, 2), (1, 1), colspan=1, rowspan=1)
    pyplot.barh(np.arange(5)+.5, adv_predictions[0][index], align='center')
    pyplot.yticks(np.arange(5)+.5, signnames[adv_predictions[1][index].astype(int)])
    pyplot.tick_params(axis='both', which='both', labelleft='off', labelright='on', labeltop='off', labelbottom='off')
    
    pyplot.show()



parameters = Parameters(
    # Data parameters
    num_classes = 43,
    image_size = (32, 32),
    # Training parameters
    batch_size = 256,
    max_epochs = 1001,
    log_epoch = 1,
    print_epoch = 1,
    # Optimisations
    learning_rate_decay = False,
    learning_rate = 0.0001,
    l2_reg_enabled = True,
    l2_lambda = 0.0001,
    early_stopping_enabled = True,
    early_stopping_patience = 100,
    resume_training = True,
    # Layers architecture
    conv1_k = 5, conv1_d = 32, conv1_p = 0.9,
    conv2_k = 5, conv2_d = 64, conv2_p = 0.8,
    conv3_k = 5, conv3_d = 128, conv3_p = 0.7,
    fc4_size = 1024, fc4_p = 0.5
)

# Load images from .png files to `X_custom` NumPy array
X_custom = np.empty([0, 32, 32, 3], dtype = np.int32)
for i in range(35):
    image = io.imread(os.getcwd() + '/data/Example/' + "example_{0:0>5}".format(i + 1) + '.png')
    X_custom = np.append(X_custom, [image[:, :, :3]], axis = 0)

# Provide labels of the captured images:
y_custom = np.array([
    21, # "example_00001"
    39, # "example_00002"
    17, # "example_00003"
    17, # "example_00004"
    17, # "example_00005"
    39, # "example_00006"
    39, # "example_00007"
    40, # "example_00008"
    40, # "example_00009"
    34, # "example_00010"
    28, # "example_00011"
    39, # "example_00012"
    0, # "example_00013"
    17, # "example_00014"
    38, # "example_00015"
    13, # "example_00016"
    40, # "example_00017"
    13, # "example_00018"
    38, # "example_00019"
    38, # "example_00020"
    11, # "example_00021"
    0, # "example_00022"
    28, # "example_00023"
    0, # "example_00024"
    32, # "example_00028"
    40, # "example_00029"
    28, # "example_00030"
    40, # "example_00031"
    40, # "example_00032"
    28, # "example_00033"
    24, # "example_00034"
    0, # "example_00035"
    0, # "example_00036"
    0, # "example_00037"
    0 # "example_00038"
])

# Preprocess and get predictions based on the current model
X_custom, _ = preprocess_dataset(X_custom)


paths = Paths(parameters)
    
    # Build the graph

graph = tf.Graph()
with graph.as_default():
    # Input data. For the training data, we use a placeholder that will be fed at run time with a training minibatch.
    tf_x = tf.placeholder(tf.float32, shape = (None, parameters.image_size[0], parameters.image_size[1], 1))
    is_training = tf.constant(False)
        
    with tf.variable_scope(paths.var_scope):
        
        adv_logits=model_pass(tf_x, parameters, is_training)
        adv_preds = tf.reshape(tf.nn.top_k(adv_logits, k=10)[0],[-1, 10])
        adv_grads = tf.stack(jacobian_graph(adv_preds, tf_x, 10), axis=1)
            
    with tf.Session(graph=graph) as sess:
        sess.run(tf.global_variables_initializer())
        tf.train.Saver().restore(sess, paths.model_path)
        adv_image=deepfool_attack(sess, tf_x, adv_preds, adv_logits, adv_grads, X_custom, nb_candidate=10,overshoot=0.02, max_iter=50, clip_min=0, clip_max=1, feed=None)

print(adv_image.shape)
adv_predictions=get_top_k_predictions(parameters,adv_image,k=1)
ori_predictions=get_top_k_predictions(parameters,X_custom)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-424c9545da7d> in <module>()
#      70     conv2_k = 5, conv2_d = 64, conv2_p = 0.8,
#      71     conv3_k = 5, conv3_d = 128, conv3_p = 0.7,
# ---> 72     fc4_size = 1024, fc4_p = 0.5
#      73 )
#      74
#
# TypeError: __new__() missing 5 required positional arguments: 'conv4_k', 'conv4_d', 'conv4_p', 'adv_training', and 'perturbed_ratio'

# %%
# For every example plot original image, preprocessed image, and model predictions.
for i in range(35):
    print("Actual class: ", signnames[y_custom[i]] if y_custom[i] != 99 else "None")
    plot_image_statistics(ori_predictions, adv_predictions, i)
    print("---------------------------------------------------------------------------------------------------\n")
# Out:
# Actual class:  Double curve
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-2de004949c70> in <module>()
#       2 for i in range(35):
#       3     print("Actual class: ", signnames[y_custom[i]] if y_custom[i] != 99 else "None")
# ----> 4     plot_image_statistics(ori_predictions, adv_predictions, i)
#       5     print("---------------------------------------------------------------------------------------------------\n")
#
# <ipython-input-20-424c9545da7d> in plot_image_statistics(ori_predictions, adv_predictions, index)
#      41     # Plot adversarial predictions
#      42     pyplot.subplot2grid((2, 2), (1, 1), colspan=1, rowspan=1)
# ---> 43     pyplot.barh(np.arange(5)+.5, adv_predictions[0][index], align='center')
#      44     pyplot.yticks(np.arange(5)+.5, signnames[adv_predictions[1][index].astype(int)])
#      45     pyplot.tick_params(axis='both', which='both', labelleft='off', labelright='on', labeltop='off', labelbottom='off')
#
# /home/wastaljoey/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in barh(bottom, width, height, left, hold, **kwargs)
#    2723                       mplDeprecation)
#    2724     try:
# -> 2725         ret = ax.barh(bottom, width, height=height, left=left, **kwargs)
#    2726     finally:
#    2727         ax._hold = washold
#
# /home/wastaljoey/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in barh(self, bottom, width, height, left, **kwargs)
#    2283
#    2284         patches = self.bar(left=left, height=height, width=width,
# -> 2285                            bottom=bottom, orientation='horizontal', **kwargs)
#    2286         return patches
#    2287
#
# /home/wastaljoey/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /home/wastaljoey/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, left, height, width, bottom, **kwargs)
#    2080         if len(width) != nbars:
#    2081             raise ValueError("incompatible sizes: argument 'width' "
# -> 2082                              "must be length %d or scalar" % nbars)
#    2083         if len(bottom) != nbars:
#    2084             raise ValueError("incompatible sizes: argument 'bottom' "
#
# ValueError: incompatible sizes: argument 'width' must be length 5 or scalar

# %%
import pickle

train_processed_dataset_file="data/test_processed.p"
adv_image_dataset_file="data/adv_image_test.p"
X_adv,y_adv=load_pickled_data(train_processed_dataset_file,['features','labels'])


parameters = Parameters(
    # Data parameters
    num_classes = 43,
    image_size = (32, 32),
    # Training parameters
    batch_size = 256,
    max_epochs = 1001,
    log_epoch = 1,
    print_epoch = 1, 
    # Optimisations
    learning_rate_decay = False,
    learning_rate = 0.0001,
    l2_reg_enabled = True,
    l2_lambda = 0.0001,
    early_stopping_enabled = True,
    early_stopping_patience = 100,
    resume_training = True,
    # Layers architecture
    conv1_k = 5, conv1_d = 32, conv1_p = 0.9,
    conv2_k = 5, conv2_d = 64, conv2_p = 0.8,
    conv3_k = 5, conv3_d = 128, conv3_p = 0.7,
    fc4_size = 1024, fc4_p = 0.5
)

paths = Paths(parameters)

# Build the graph
graph = tf.Graph()
with graph.as_default():
    # Input data. For the training data, we use a placeholder that will be fed at run time with a training minibatch.
    tf_x = tf.placeholder(tf.float32, shape = (None, parameters.image_size[0], parameters.image_size[1], 1))
    is_training = tf.constant(False)
        
    with tf.variable_scope(paths.var_scope):
        
        adv_logits=model_pass(tf_x, parameters, is_training)
        adv_preds = tf.reshape(tf.nn.top_k(adv_logits, k=10)[0],[-1, 10])
        adv_grads = tf.stack(jacobian_graph(adv_preds, tf_x, 10), axis=1)
            
    with tf.Session(graph=graph) as sess:
        sess.run(tf.global_variables_initializer())
        tf.train.Saver().restore(sess, paths.model_path)
        batch_iterator=BatchIterator(batch_size=128)
        f=0
        for X_batch,y_batch in batch_iterator(X_adv,y_adv):
            f=f+1
            if f%10==0:
                print(f)
            adv_image_batch=deepfool_attack(sess, tf_x, adv_preds, adv_logits, adv_grads, X_batch, nb_candidate=10,overshoot=0.02, max_iter=50, clip_min=0, clip_max=1, feed=None)
            if f==1:
                adv_image=adv_image_batch
            else:
                adv_image=np.concatenate((adv_image,adv_image_batch),axis=0)

print(adv_image.shape)
pickle.dump({
        "features" : adv_image,
        "labels" : y_adv
    }, open(adv_image_dataset_file, "wb" ) )
print("Adversarial images dataset saved in", adv_image_dataset_file)

adv_predictions=get_top_k_predictions(parameters,adv_image,k=1)
ori_predictions=get_top_k_predictions(parameters,X_adv,k=1)
print(adv_predictions.shape[1])
#accuracy=100*np.sum(adv_predictions[1]==ori_predictions[1])/adv_predictions.shape[1]
# Out:
# INFO:tensorflow:Restoring parameters from /home/wastaljoey/TSC1/models/k5d32p0.9_k5d64p0.8_k5d128p0.7_fc1024p0.5_no-lrdec_l2/model.ckpt
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# 90
# (12630, 32, 32, 1)
# Adversarial images dataset saved in data/adv_image_test.p
# INFO:tensorflow:Restoring parameters from /home/wastaljoey/TSC1/models/k5d32p0.9_k5d64p0.8_k5d128p0.7_fc1024p0.5_no-lrdec_l2/model.ckpt
# INFO:tensorflow:Restoring parameters from /home/wastaljoey/TSC1/models/k5d32p0.9_k5d64p0.8_k5d128p0.7_fc1024p0.5_no-lrdec_l2/model.ckpt
# 12630

# %%
print(adv_image.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c021e9f73d8b> in <module>()
# ----> 1 print(adv_image.shape)
#
# NameError: name 'adv_image' is not defined

# %% [markdown]
# ### Test accuracy

# %%
import pickle

test_processed_dataset_file="data/adv_image_test_4_layers.p"
X_test,y_test=load_pickled_data(test_processed_dataset_file,['features','labels'])


adv_para = Parameters(
    # Data parameters
    num_classes = 43,
    image_size = (32, 32),
    # Training parameters
    batch_size = 128,
    max_epochs = 10,
    log_epoch = 1,
    print_epoch = 1,
    # Optimisations
    learning_rate_decay = False,
    learning_rate = 0.001,
    l2_reg_enabled = True,
    l2_lambda = 0.0001,
    early_stopping_enabled = True,
    early_stopping_patience = 80,
    resume_training = True,
    # Layers architecture
    conv1_k = 5, conv1_d = 16, conv1_p = 0.9,
    conv2_k = 5, conv2_d = 32, conv2_p = 0.8,
    conv3_k = 5, conv3_d = 64, conv3_p = 0.7,
    conv4_k = 3, conv4_d = 128, conv4_p = 0.6,
    fc4_size = 1024, fc4_p = 0.5,
    adv_training=None,
    perturbed_ratio= 50
)



accuracy,loss=get_accuracy_and_loss(adv_para,X_test,y_test)
print('Accuracy of pure data on advesarial model',accuracy)
print(loss)
# Out:
# INFO:tensorflow:Restoring parameters from /home/wastaljoey/TSC1/models/k5d16p0.9_k5d32p0.8_k5d64p0.7_fc1024p0.5_no-lrdec_l2_50%_perturbed/model.ckpt
# Accuracy of pure data on advesarial model 49.5249406176
# 2.06637

# %%
import random

train_preprocessed_file="data/train_processed.p"
X_train,y_train=load_pickled_data(train_preprocessed_file,['features','labels'])

index=random.randint(0,len(X_train))
X_adv=[X_train[index]]
y_adv=[y_train[index]]
adv_len=0.1*len(X_train)

for i in range(int(adv_len)):
    index=random.randint(0,len(X_train))
    X_adv=np.concatenate((X_adv,[X_train[index]]),axis=0)
    y_adv=np.concatenate((y_adv,[y_train[index]]),axis=0)
    
print(y_adv.shape)
print(X_adv.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3dd273ccb43d> in <module>()
#       2
#       3 train_preprocessed_file="data/train_processed.p"
# ----> 4 X_train,y_train=load_pickled_data(train_preprocessed_file,['features','labels'])
#       5
#       6 index=random.randint(0,len(X_train))
#
# NameError: name 'load_pickled_data' is not defined

# %%
import pickle

adv_dataset_file="data/adv_images.p"
pickle.dump({
    "features":X_adv,
    "labels":y_adv
},open(adv_dataset_file,"wb"))
print("adv_images saved")

# %% [markdown]
# ### Generate 10% perturbed dataset

# %%
from sklearn.utils import shuffle
import pickle

train_preprocessed_file="data/train_processed.p"
X_train,y_train=load_pickled_data(train_preprocessed_file,['features','labels'])

X_train,y_train=shuffle(X_train,y_train)
perturbed_ratio=0.75
cut_off_index=int(perturbed_ratio*len(X_train))

X_per_train=X_train[0:cut_off_index]
y_per_train=y_train[0:cut_off_index]

parameters = Parameters(
    # Data parameters
    num_classes = 43,
    image_size = (32, 32),
    # Training parameters
    batch_size = 256,
    max_epochs = 1001,
    log_epoch = 1,
    print_epoch = 1, 
    # Optimisations
    learning_rate_decay = False,
    learning_rate = 0.0001,
    l2_reg_enabled = True,
    l2_lambda = 0.0001,
    early_stopping_enabled = True,
    early_stopping_patience = 100,
    resume_training = True,
    # Layers architecture
    conv1_k = 5, conv1_d = 32, conv1_p = 0.9,
    conv2_k = 5, conv2_d = 64, conv2_p = 0.8,
    conv3_k = 5, conv3_d = 128, conv3_p = 0.7,
    fc4_size = 1024, fc4_p = 0.5,
    adv_training=False,
    perturbed_ratio= None
)

paths = Paths(parameters)

# Build the graph
graph = tf.Graph()
with graph.as_default():
    # Input data. For the training data, we use a placeholder that will be fed at run time with a training minibatch.
    tf_x = tf.placeholder(tf.float32, shape = (None, parameters.image_size[0], parameters.image_size[1], 1))
    is_training = tf.constant(False)
        
    with tf.variable_scope(paths.var_scope):
        
        adv_logits=model_pass(tf_x, parameters, is_training)
        adv_preds = tf.reshape(tf.nn.top_k(adv_logits, k=10)[0],[-1, 10])
        adv_grads = tf.stack(jacobian_graph(adv_preds, tf_x, 10), axis=1)
            
    with tf.Session(graph=graph) as sess:
        sess.run(tf.global_variables_initializer())
        tf.train.Saver().restore(sess, paths.model_path)
        adv_image_10=deepfool_attack(sess, tf_x, adv_preds, adv_logits, adv_grads, X_per_train, nb_candidate=10,overshoot=0.02, max_iter=50, clip_min=0, clip_max=1, feed=None)
        
adv_image_10_train=np.concatenate((adv_image_10,X_train[cut_off_index:]),axis=0)
adv_image_10_train,y_train=shuffle(adv_image_10_train,y_train)

adv_dataset_file="data/75%_perturbed_adv_image.p"
pickle.dump({
    "features":adv_image_10_train,
    "labels":y_train
},open(adv_dataset_file,"wb"))
print("adv_images saved")
# Out:
# INFO:tensorflow:Restoring parameters from /home/wastaljoey/TSC1/models/k5d32p0.9_k5d64p0.8_k5d128p0.7_fc1024p0.5_no-lrdec_l2/model.ckpt

# %%
from sklearn.utils import shuffle
import pickle

train_preprocessed_file="data/train_processed.p"
X_train,y_train=load_pickled_data(train_preprocessed_file,['features','labels'])

X_train,y_train=shuffle(X_train,y_train)
perturbed_ratio=0.75
cut_off_index=int(perturbed_ratio*len(X_train))

X_per_train=X_train[0:cut_off_index]
y_per_train=y_train[0:cut_off_index]

parameters = Parameters(
    # Data parameters
    num_classes = 43,
    image_size = (32, 32),
    # Training parameters
    batch_size = 256,
    max_epochs = 1001,
    log_epoch = 1,
    print_epoch = 1, 
    # Optimisations
    learning_rate_decay = False,
    learning_rate = 0.0001,
    l2_reg_enabled = True,
    l2_lambda = 0.0001,
    early_stopping_enabled = True,
    early_stopping_patience = 100,
    resume_training = True,
    # Layers architecture
    conv1_k = 5, conv1_d = 32, conv1_p = 0.9,
    conv2_k = 5, conv2_d = 64, conv2_p = 0.8,
    conv3_k = 5, conv3_d = 128, conv3_p = 0.7,
    fc4_size = 1024, fc4_p = 0.5,
    adv_training=False,
    perturbed_ratio=None
)

paths = Paths(parameters)

# Build the graph
graph = tf.Graph()
with graph.as_default():
    # Input data. For the training data, we use a placeholder that will be fed at run time with a training minibatch.
    tf_x = tf.placeholder(tf.float32, shape = (None, parameters.image_size[0], parameters.image_size[1], 1))
    is_training = tf.constant(False)
        
    with tf.variable_scope(paths.var_scope):
        
        adv_logits=model_pass(tf_x, parameters, is_training)
        adv_preds = tf.reshape(tf.nn.top_k(adv_logits, k=10)[0],[-1, 10])
        adv_grads = tf.stack(jacobian_graph(adv_preds, tf_x, 10), axis=1)
            
    with tf.Session(graph=graph) as sess:
        sess.run(tf.global_variables_initializer())
        tf.train.Saver().restore(sess, paths.model_path)
        adv_image_10=deepfool_attack(sess, tf_x, adv_preds, adv_logits, adv_grads, X_per_train, nb_candidate=10,overshoot=0.02, max_iter=50, clip_min=0, clip_max=1, feed=None)
        
adv_image_10_train=np.concatenate((adv_image_10,X_train[cut_off_index:]),axis=0)
adv_image_10_train,y_train=shuffle(adv_image_10_train,y_train)

adv_dataset_file="data/75%_perturbed_adv_image.p"
pickle.dump({
    "features":adv_image_10_train,
    "labels":y_train
},open(adv_dataset_file,"wb"))
print("adv_images saved")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3fd6cc53b121> in <module>()
#       3
#       4 train_preprocessed_file="data/train_processed.p"
# ----> 5 X_train,y_train=load_pickled_data(train_preprocessed_file,['features','labels'])
#       6
#       7 X_train,y_train=shuffle(X_train,y_train)
#
# NameError: name 'load_pickled_data' is not defined

# %%
import pickle
from sklearn.model_selection import train_test_split

#train_extended_preprocessed_dataset_file = "data/train_extended_preprocessed.p"
train_balanced_preprocessed_dataset_file = "data/75%_perturbed_adv_image.p"
test_preprocessed_dataset_file = "data/adv_image_test.p"


parameters = Parameters(
    # Data parameters
    num_classes = 43,
    image_size = (32, 32),
    # Training parameters
    batch_size = 256,
    max_epochs = 1001,
    log_epoch = 1,
    print_epoch = 1,
    # Optimisations
    learning_rate_decay = False,
    learning_rate = 0.0001,
    l2_reg_enabled = True,
    l2_lambda = 0.0001,
    early_stopping_enabled = True,
    early_stopping_patience = 80,
    resume_training = True,
    # Layers architecture
    conv1_k = 5, conv1_d = 32, conv1_p = 0.9,
    conv2_k = 5, conv2_d = 64, conv2_p = 0.8,
    conv3_k = 5, conv3_d = 128, conv3_p = 0.7,
    fc4_size = 1024, fc4_p = 0.5,
    adv_training=None,
    perturbed_ratio= 75
    
)

X_train, y_train = load_pickled_data(train_balanced_preprocessed_dataset_file, columns = ['features', 'labels'])
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.25)
X_test, y_test = load_pickled_data(test_preprocessed_dataset_file, columns = ['features', 'labels'])
train_model(parameters, X_train, y_train, X_valid, y_valid, X_test, y_test)

# %%
print(adv_image.shape)
print(adv_image_batch.shape)
accuracy=100*np.sum(adv_predictions[1]==ori_predictions[1])/adv_predictions.shape[1]
print(accuracy)
# Out:
# (4952, 32, 32, 1)
# (88, 32, 32, 1)
# 3.1098546042
